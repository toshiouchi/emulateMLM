# %%
# -*- coding: utf-8 -*-

#
# Pytorchで用いるDatasetの定義
#

#!pip install janome

# sysモジュールをインポート
import sys
import os

import matplotlib.pyplot as plt
import pandas as pd
import torch
import random
from torch import nn, Tensor
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import numpy as np
import math
import janome
from janome.tokenizer import Tokenizer
from collections import Counter
from torch.utils.data.sampler import SubsetRandomSampler
import time
import levenshtein
import pickle
from timm.scheduler import CosineLRScheduler
from nltk import bleu_score
#from tqdm import tqdm
from tqdm.notebook import tqdm
from torch import autocast, GradScaler
from typing import Sequence, Dict, Tuple, Union
from transformers import  get_linear_schedule_with_warmup, BertTokenizer
from sklearn.metrics import accuracy_score
from datasets import load_dataset

#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device( "cpu")
use_amp = False
use_saved_pth = True

# %%
path = "../../python_image_recognition-main/6_img_captioning/6_7_ImgCap_pre_trained_Feature_extractor/CLIP_ENCODER/models--google-bert--bert-large-uncased/snapshots/6da4b6a26a1877e173fca3225479512db81a5e5b"
tokenizer = BertTokenizer.from_pretrained(pretrained_model_name_or_path = path)

vocab_size = len(tokenizer)
print(vocab_size)
# Out:
# 30522

# %%
class MyDataset(Dataset):
    def __init__(self, mode, tokenizer, pad_token_id, max_length ):

        #dataset = load_dataset("yelp_review_full") 
        #dataset = load_dataset("imdb")
        #dataset = load_dataset("kunishou/databricks-dolly-15k-ja")  
        # Dataset id from huggingface.co/dataset
        dataset_id = "argilla/synthetic-domain-text-classification"
        dataset = load_dataset(dataset_id, split='train')
 
        ## Load raw dataset
        #train_dataset = load_dataset(dataset_id, split='train')
        
        if mode == "train":
            dataset = dataset[:900]
        elif mode == "val":
            dataset = dataset[900:950]
        else:
            dataset = dataset[950:1000]
        self.dataset = dataset
        #print( "self.dataset[1]:", self.dataset['label'][1])
            
        #self.encoded_texts = [ tokenizer.encode(text, max_length = max_length, truncation = True ) for text in dataset['text']]
        self.encoded_texts = [ tokenizer.encode(text ) for text in dataset['text']]
        
        if max_length is None:
            self.max_length = self._longest_encoded_length()
        else:
            self.max_length = max_length
            # Truncate sequences if they are longer than max_length
            self.encoded_texts = [
                encoded_text[:self.max_length]
                for encoded_text in self.encoded_texts
            ]

        # Pad sequences to the longest sequence
        self.encoded_texts = [
            encoded_text + [pad_token_id] * (self.max_length - len(encoded_text))
            for encoded_text in self.encoded_texts
        ]
        
    def __getitem__(self, index):
        encoded = self.encoded_texts[index]
        label = self.dataset["label"][index]
        return (
            torch.tensor(encoded, dtype=torch.long),
            torch.tensor(label, dtype=torch.long)
        )

    def __len__(self):
        return len(self.encoded_texts)

    def _longest_encoded_length(self):
        max_length = 0
        for encoded_text in self.encoded_texts:
            encoded_length = len(encoded_text)
            if encoded_length > max_length:
                max_length = encoded_length
        return max_length
        # Note: A more pythonic version to implement this method
        # is the following, which is also used in the next chapter:
        # return max(len(encoded_text) for encoded_text in self.encoded_texts)

# %%
train_dataset = MyDataset(
    mode="train",
    tokenizer=tokenizer,
    pad_token_id = tokenizer.pad_token_id,
    max_length=None,
)

print(train_dataset.max_length)
print( len( train_dataset ))
# Out:
# 408
# 900

# %%
val_dataset = MyDataset(
    mode="val",
    tokenizer=tokenizer,
    pad_token_id = tokenizer.pad_token_id,
    max_length=512,
)
test_dataset = MyDataset(
    mode="test",
    tokenizer=tokenizer,
    pad_token_id = tokenizer.pad_token_id,
    max_length=512,
)

# %%
#num_workers = 0 if device == torch.device( 'cpu' ) else 8
num_workers = 0 if device == torch.device( 'cpu' ) else 8
batch_size = 4

train_loader = DataLoader(train_dataset,
                            batch_size=batch_size,
                            shuffle=True,
                            num_workers=num_workers,
                            pin_memory=True,)
                            #collate_fn = collate_func_lambda)
print( "train_loader defiend" )
# 開発データのDataLoaderを呼び出す
# 開発データはデータはシャッフルしない
val_loader = DataLoader(val_dataset,
                        batch_size=batch_size,
                        shuffle=False,
                        num_workers=num_workers,)
                        #collate_fn = collate_func_lambda)
print( "val_loader defined" )
print( len( train_loader ))
print( len( val_loader ))

inputs, labels = next(iter(val_loader))
print( inputs )
print( labels )
#print(text[0], target[0], text_len[0],target_len[0], sep="\n")
#print( "text:", text )
#print( "text_len:", text_len )
# Out:
# train_loader defiend
# val_loader defined
# 225
# 13
# tensor([[ 101, 5983, 2092,  ...,    0,    0,    0],
#         [ 101, 1996, 3795,  ...,    0,    0,    0],
#         [ 101, 2023, 3720,  ...,    0,    0,    0],
#         [ 101, 3795, 3119,  ...,    0,    0,    0]])
# tensor([17,  9,  4,  0])

# %%
print( len( inputs ))
print( len( labels ))
print( batch_size )
# Out:
# 4
# 4
# 4

# %%
class PositionalEmbedding(nn.Module):
    '''
    位置埋め込み （Positional embedding）
    dim_embedding: 埋込み次元
    max_len      : 入力の最大系列長
    '''
    def __init__(self, dim_embedding: int, max_len: int=2048):
        super().__init__()

        self.pos_emb = nn.Embedding(max_len, dim_embedding)

    '''
    位置エンコーディングの順伝播
    x: 位置エンコーディングを埋め込む対象のテンソル,
       [バッチサイズ, 系列長, 埋め込み次元]
    '''
    def forward(self, x: torch.Tensor):
        seq = x.shape[1]
        positions = torch.arange(start=0, end=seq, step=1, device=x.device).to(torch.long)
        positions = self.pos_emb(positions)[:seq,:]
        
        return positions

# %%
class TransformerEncoder(nn.Module):
    '''
    CaptioningTransformerのコンストラクタ
    dim_embedding  : 埋め込み次元
    dim_feedforward: FNNの中間特徴次元
    num_heads      : マルチヘッドアテンションのヘッド数
    num_layers     : Transformerデコーダ層の数
    vocab_size     : 辞書の次元
    pad_index      : PADのID
    dropout        : ドロップアウト確率
    '''
    def __init__(self, vocab_size: int, dim_embedding: int, dim_feedforward: int,
                 num_heads: int, num_layers: int ):
        super().__init__()

        self.encoder_layers = nn.ModuleList([
            nn.TransformerEncoderLayer(d_model=dim_embedding, nhead=num_heads, batch_first=True, activation='gelu', norm_first=True)
            for _ in range(num_layers)
        ])

    ''' CaptioningTransformerの順伝播処理
    features: 画像特徴量 [バッチサイズ, 埋め込み次元]
    captions: 正解キャプション [バッチサイズ, 系列長]

    '''
    def forward(self, src: torch.Tensor, src_mask: torch.Tensor=None, \
                src_key_padding_mask: torch.Tensor=None ):


        for layer in self.encoder_layers:
            src = layer( src, src_mask = src_mask, src_key_padding_mask = src_key_padding_mask,\
                        #is_causal= True )
                        is_causal= False )

        return src

# %%
class Transformer(nn.Module):
    def __init__(self, dim_embedding: int, dim_feedforward: int,
                 num_heads: int, num_layers: int, vocab_size: int,
                 pad_index: int, dropout: float=0.5, us_rate: float=2.0 ):
        super().__init__()

        # 単語埋め込み
        self.embed = nn.Embedding(
            vocab_size, dim_embedding, padding_idx=pad_index)

        # 位置エンコーディング
        self.pos_emb = PositionalEmbedding(dim_embedding)        
        
        # dropout
        self.dropout = nn.Dropout( dropout )
        
        self.encoder = TransformerEncoder(vocab_size, dim_embedding, dim_feedforward, num_heads, num_layers)

        # 単語出力分布計算
        self.ln = nn.LayerNorm( dim_embedding )
        self.linear = nn.Linear(dim_embedding, vocab_size)

        self.pad_index = pad_index
        
    ''' CaptioningTransformerの順伝播処理
    features: 画像特徴量 [バッチサイズ, 埋め込み次元]
    captions: 正解キャプション [バッチサイズ, 系列長]

    '''
    def forward(self, text):

        device = text.device

        src = self.embed( text )
        
        src += self.pos_emb( src )
        src = self.dropout( src )
        src_key_padding_mask = torch.eq(text, self.pad_index)

        #ones = torch.ones( text.size(1) ).to( device = device )
        #src_mask = torch.diag( ones ).bool()
        src_mask = None
        
        preds = self.encoder( src, src_mask, src_key_padding_mask )
        
        preds = self.ln( preds )
        preds = preds[:,0,:]
        logits = self.linear( preds )

        return logits

# %%
epoch_num = 5
model = Transformer(768, 3072, 12, 6, vocab_size, tokenizer.pad_token_id ).to(device)
#criterion = nn.BCEWithLogitsLoss()
criterion = nn.CrossEntropyLoss()
#lr = 1e-4
lr = 5e-5
optimizer = optim.AdamW( model.parameters(), lr = lr )
# 全ステップ数
num_global_steps = len( train_loader ) * epoch_num
print( "num_global_steps:", num_global_steps )
num_warmup_steps = num_global_steps * 0.1
print( "num_warmup_steps:", num_warmup_steps )
#スケジューラーの定義
scheduler = get_linear_schedule_with_warmup( optimizer, num_warmup_steps, num_global_steps )
eps = 1e-4

PATH = 'Diag_Mask3_curr.pt'
if use_saved_pth and os.path.isfile(PATH):
    print( "loaded Diag_Mask6_curr.pt")
    checkpoint = torch.load(PATH)
    model.load_state_dict(checkpoint['model_state_dict'])

#model.linear = nn.Linear( 768, 5 ) 
model.linear = nn.Linear( 768, 26 )
# Out:
# num_global_steps: 1125
# num_warmup_steps: 112.5
# loaded Diag_Mask6_curr.pt

# %%
# WarmupとCosine Decayを行うスケジューラを利用
#scheduler = CosineLRScheduler(
#    optimizer, t_initial=epoch_num, lr_min=1e-1,
#    warmup_t=5, warmup_lr_init=5e-2, warmup_prefix=True)

#tr_print_coef = 64000
#tr_save_coef = 1000
#val_print_coef = 240
len_tr_loader = len( train_loader )
len_val_loader = len( val_loader )
tr_print_coef = len_tr_loader // 3
tr_save_coef = len_tr_loader // 30
val_print_coef = len_val_loader // 3
print( "len( train_loader ):", len_tr_loader )
print( "len( val_loader ):", len_val_loader )
print( "tr_print_coef:", tr_print_coef )
print( "tr_save_coef:", tr_save_coef )
print( "val_print_coef:", val_print_coef )
#tr_print_coef = 1
#tr_save_coef = 1
#val_print_coef = 1
#train_length = len(train_loader)
#train_int = train_length // tr_print_coef
#print( train_int )
#print( train_length )
#val_length = len(val_loader)
#val_int = val_length // val_print_coef
#print( val_int )
#print( val_length )

history = {"len_tr_loader":[],"len_val_loader":[], "train_loss":[], "val_loss": [], "train_acc": [], "val_acc": [] }
history["len_tr_loader"].append( len_tr_loader )
history["len_val_loader"].append( len_val_loader )
with open("Diag_Mask3_FT_argilla.pkl", "wb") as f:
    pickle.dump( history, f )      
n = 0
train_loss = 0
val_loss = 0


# 学習率の減衰やEarly stoppingの
# 判定を開始するエポック数
# (= 最低限このエポックまではどれだけ
# validation結果が悪くても学習を続ける)
lr_decay_start_epoch = 5

# 学習率を減衰する割合
# (減衰後学習率 <- 現在の学習率*lr_decay_factor)
# 1.0以上なら，減衰させない
lr_decay_factor = 0.5

# Early stoppingの閾値
# 最低損失値を更新しない場合が
# 何エポック続けば学習を打ち切るか
early_stop_threshold = 3

# 最も低い損失値，
# そのときのモデルとエポック数を記憶しておく
best_loss = -1
best_model = None
best_epoch = 0

# Early stoppingフラグ．Trueになると学習を打ち切る
early_stop_flag = False
# Early stopping判定用(損失値の最低値が
# 更新されないエポックが何回続いているか)のカウンタ
counter_for_early_stop = 0

fn = bleu_score.SmoothingFunction().method7

# AMP用のスケーラー
scaler = GradScaler(enabled=use_amp)

for epoch in range(epoch_num):
    # early stopフラグが立っている場合は，
    # 学習を打ち切る
    if early_stop_flag:
        print('    Early stopping.'\
            ' (early_stop_threshold = %d)' \
            % (early_stop_threshold))
        #log_file.write('\n    Early stopping.'\
        #        ' (early_stop_threshold = %d)' \
        #        % (early_stop_threshold))
        break

    with tqdm(train_loader) as pbar:
    #with tqdm(val_loader) as pbar:
        pbar.set_description(f'[Train エポック {epoch + 1}]')
    
        model.train()
        #scheduler.step(epoch)
        #print( "Train")
        train_loss = 0
        total_acc = 0
        n3 = 0
        for i, ( inputs, labels ) in enumerate( pbar ):
            optimizer.zero_grad()
            inputs = inputs.to(device)
            y_true = labels.tolist()
            labels = labels.to(device)
            #labels = nn.functional.one_hot(labels.to(device).long(), num_classes = 5 ).float()
            #labels = labels.to(device).long()
            
            with autocast(str(device),enabled=use_amp):
                logits = model( inputs )
                #print( "logits size:", logits.size() )
                y_pred = torch.argmax( logits, dim = 1 )
                # 損失の計算
                loss = criterion( logits, labels )

                
            # 誤差逆伝播
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            clip_grad_threshold = 5.0
            torch.nn.utils.clip_grad_norm_(\
                    model.parameters(),
                    clip_grad_threshold)
            # オプティマイザにより，パラメータを更新する
            scaler.step(optimizer)
            scaler.update()            
            
            scheduler.step()
            
            #lr = optimizer.param_groups[0]['lr']
            #print( "lr:", lr )
            
            n2 = 0
            input_sentence = []
            target_label = []
            pred_label = []
            for input_id, label, pred in zip( inputs, y_true, y_pred ):
                #print( "label:", label )
                #print( "pred:",pred )
                if n2 < 2 and ( i % tr_print_coef == tr_print_coef -1 ) :
                    input_s = tokenizer.decode( input_id, skip_special_tokens = True )
                    input_sentence.append( input_s )
                    target_label.append( label )
                    pred_label.append( pred.item() )
                
                n2 += 1

            #print( "y_true size:", torch.tensor( y_true).size() )
            #print( "y_pred size:", y_pred.size() )
            accuracy = accuracy_score(y_true, y_pred.detach().cpu() )
            total_acc += accuracy
            n3 += 1
    
            train_loss += loss.item()
            history["train_loss"].append( loss.item() )
            history["train_acc"].append( accuracy )
            if i % tr_save_coef == tr_save_coef - 1:
                with open("Diag_Mask3_FT_argilla.pkl", "wb") as f:
                    pickle.dump( history, f )            
            if i % tr_print_coef == tr_print_coef - 1:
                lr = optimizer.param_groups[0]['lr']
                print(f"Train epoch:{epoch+1}  index:{i+1} loss:{train_loss/n3:.10f} ACC:{ total_acc / n3 } lr:{lr:.10f}")
            #if i == len( train_loader ) - 1:
            for (input_s, target_lbl, pred_lbl ) in zip( input_sentence, target_label, pred_label ):
                print( "index:", i+1, "input :", input_s)
                print( "index:", i+1, "target:", target_lbl)
                print( "index:", i+1, "pred  :", pred_lbl )
            pbar.set_postfix({
                    'loss': train_loss / n3,
                    'acc': total_acc / n3,
                })

    with tqdm(val_loader) as pbar:
        pbar.set_description(f'[検証]')
        model.eval()
        #for i, ( text, target, text_len, target_len ) in enumerate(val_loader):
        val_loss = 0
        total_acc = 0
        n3 = 0
        for i, ( inputs, labels ) in enumerate( pbar ):
            inputs = inputs.to(device)
            y_true = labels.tolist()
            labels = labels.to(device)
            #labels = nn.functional.one_hot(labels.to(device).long(), num_classes = 2 ).float()
            #labels = labels.to(device).long()

            with torch.no_grad():
                logits = model( inputs )
                y_pred = torch.argmax( logits, dim = 1 )
                # 損失の計算
                loss = criterion( logits, labels )
           

            n2 = 0
            input_sentence = []
            target_label = []
            pred_label = []
            for input_id, label, pred in zip( inputs, y_true, y_pred ):
                if n2 < 2 and ( i % val_print_coef == val_print_coef -1 ) :
                    input_s = tokenizer.decode( input_id, skip_special_tokens = True )
                    input_sentence.append( input_s )
                    target_label.append( label )
                    pred_label.append( pred.item() )
                
                n2 += 1
                
            #print( "y_true size:", torch.tensor( y_true).size() )
            #print( "y_pred size:", y_pred.size() )
            accuracy = accuracy_score(y_true, y_pred.detach().cpu() )
            total_acc += accuracy
            n3 += 1
            
            val_loss += loss.item()
            history["val_loss"].append( loss.item() )
            history["val_acc"].append( accuracy )

            if i % val_print_coef == val_print_coef - 1:
                lr = optimizer.param_groups[0]['lr']
                print(f"Val epoch:{epoch+1}  index:{i+1} loss:{val_loss/n3:.10f} ACC:{total_acc / n3 } lr:{lr:.10f}")
                PATH = './Diag_Mask3_FT_argilla_curr.pt'
                torch.save({'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'loss': loss,},
                     PATH)
                with open("Diag_Mask3_FT_argilla.pkl", "wb") as f:
                    pickle.dump( history, f )
            #if i == len( train_loader ) - 1:
            for (input_s, target_lbl, pred_lbl ) in zip( input_sentence, target_label, pred_label ):
                print( "index:", i+1, "input :", input_s)
                print( "index:", i+1, "target:", target_lbl)
                print( "index:", i+1, "pred  :", pred_lbl )
            pbar.set_postfix({
                    'loss': val_loss / n3,
                    'acc': total_acc / n3,
                })
    
    epoch_loss = val_loss/n3
    if epoch == 0 or best_loss > epoch_loss:
        # 損失値が最低値を更新した場合は，
        # その時のモデルを保存する
        best_loss = epoch_loss
        torch.save(model.state_dict(), 
                    './best_model_Mask3_FT_argilla.pt')
        best_epoch = epoch
        # Early stopping判定用の
        # カウンタをリセットする
        counter_for_early_stop = 0
    else:
        # 最低値を更新しておらず，
        if epoch+1 >= lr_decay_start_epoch:
            # かつlr_decay_start_epoch以上の
            # エポックに達している場合
            if counter_for_early_stop+1 \
                    >= early_stop_threshold:
                # 更新していないエポックが，
                # 閾値回数以上続いている場合，
                # Early stopping フラグを立てる
                early_stop_flag = True
            else:
                # Early stopping条件に
                # 達していない場合は
                # 学習率を減衰させて学習続行
                if lr_decay_factor < 1.0:
                    for i, param_group \
                            in enumerate(\
                            optimizer.param_groups):
                        if i == 0:
                            lr = param_group['lr']
                            dlr = lr_decay_factor \
                                * lr
                            print('    (Decay '\
                                'learning rate:'\
                                ' %f -> %f)' \
                                % (lr, dlr))
                        param_group['lr'] = dlr
                # Early stopping判定用の
                # カウンタを増やす
                counter_for_early_stop += 1
#torch.cuda.synchronize()
# Out:
# len( train_loader ): 225
# len( val_loader ): 13
# tr_print_coef: 75
# tr_save_coef: 7
# val_print_coef: 4
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:1  index:75 loss:3.5368045362 ACC:0.03 lr:0.0000333333
# index: 75 input : traveling through the bustling streets of tokyo, one can't help but notice the harmonious blend of traditional and modern architecture. the skyscrapers adorned with neon lights stand proudly beside centuries - old temples, each telling a unique story about japan's rich history. whether visiting during the vibrant cherry blossom season or exploring the city ’ s hidden culinary gems, there is always something new to discover in this dynamic metropolis.
# index: 75 target: 22
# index: 75 pred  : 4
# index: 75 input : a balanced diet is essential for maintaining good health. it should include a variety of fruits, vegetables, whole grains, and lean proteins. eating a wide range of nutrients helps the body to function properly and can help prevent chronic diseases such as heart disease, diabetes, and some forms of cancer. additionally, regular physical activity contributes to overall well - being by keeping muscles strong, improving cardiovascular health, and promoting mental health.
# index: 75 target: 17
# index: 75 pred  : 17
# Train epoch:1  index:150 loss:3.4570067803 ACC:0.041666666666666664 lr:0.0000481481
# index: 150 input : today's focus on consumer electronics highlights the latest gadgets available in the marketplace. the new smartphone from xyz offers enhanced camera capabilities, extended battery life, and an intuitive user interface. meanwhile, a popular online retailer is currently offering significant discounts on the latest laptops, making it an ideal time for tech enthusiasts to upgrade their computing devices. additionally, there are mentions of various accessories like protective cases, high - quality headphones, and portable chargers that complement these electronic purchases. reviews in this article emphasize product features, performance improvements over previous models, and price comparisons across different vendors.
# index: 150 target: 20
# index: 150 pred  : 10
# index: 150 input : in this article, we will explore the diverse world of pets and animals. from their behavior in domestic settings to their roles in wildlife conservation efforts, animals have a unique impact on our lives. cats, for example, are known not only as beloved household companions but also for their innate hunting abilities which can help control pest populations. on the other hand, dogs serve various purposes such as therapy and assistance for disabled individuals. this article delves into these roles along with other aspects of animal behavior and care, making it essential reading for anyone interested in learning more about our furry friends.
# index: 150 target: 8
# index: 150 pred  : 1
# Train epoch:1  index:225 loss:3.4154414993 ACC:0.04666666666666667 lr:0.0000444444
# index: 225 input : skiing offers a thrilling winter experience that brings together adventure, athleticism, and the natural beauty of snowy landscapes. from beginners learning basic turns on gentle slopes to experienced skiers conquering steep descents, there are challenges for all skill levels. the equipment has evolved significantly over time, with modern boots, bindings, and skis offering improved performance and safety. skiiers often share a camaraderie that stems from the shared passion for this exhilarating winter sport.
# index: 225 target: 5
# index: 225 pred  : 22
# index: 225 input : the recent world cup in qatar has seen some of the most exciting matches, with teams from all over the world showcasing their skills and athleticism. goals have been thrilling to watch, especially those last - minute victories that keep fans on edge until the final whistle. the tournament not only highlights exceptional individual talent but also demonstrates the power of teamwork and strategy. in addition, the event's organization has set new standards for managing international sports events.
# index: 225 target: 5
# index: 225 pred  : 17
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:1  index:4 loss:3.4479880333 ACC:0.0625 lr:0.0000444444
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 12
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 12
# Val epoch:1  index:8 loss:3.2794463038 ACC:0.125 lr:0.0000444444
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 17
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 17
# Val epoch:1  index:12 loss:3.3591150641 ACC:0.125 lr:0.0000444444
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 12
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 17
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:2  index:75 loss:3.2211459637 ACC:0.09666666666666666 lr:0.0000407407
# index: 75 input : in this article, we explore the complex interplay between human behavior and societal norms across different cultures. from ancient civilizations in mesopotamia to contemporary societies like those in scandinavia, it is crucial to understand how these behaviors are shaped by underlying social constructs. we discuss various case studies that highlight both positive and negative impacts of such influences on individuals and communities. the focus here is also on how education plays a pivotal role in shaping perspectives and fostering a more inclusive society.
# index: 75 target: 4
# index: 75 pred  : 17
# index: 75 input : rock climbing has been a popular activity for many years due to its combination of physical challenge and scenic beauty. from beginner - friendly routes to advanced climbs that require expert skills, rock climbing offers something for everyone. this sport is not just about strength ; it also requires mental discipline and strategic thinking to navigate different types of rock surfaces. climbers often engage in the sport as a way to explore remote areas and enjoy nature's stunning landscapes. whether climbing indoors on artificial walls or outdoors at natural sites, climbers appreciate the sense of adventure and personal achievement that comes with every ascent.
# index: 75 target: 5
# index: 75 pred  : 16
# Train epoch:2  index:150 loss:3.1891317002 ACC:0.08166666666666667 lr:0.0000370370
# index: 150 input : sourdough bread has been a staple in many cultures for centuries, known not only for its unique tangy flavor but also for the health benefits associated with it. the process of making sourdough involves natural yeasts and bacteria found in the air, which give the bread its distinct texture and flavor. this traditional method of baking is gaining popularity again as people seek out more natural and preservative - free foods.
# index: 150 target: 13
# index: 150 pred  : 5
# index: 150 input : the formation of governments and their functions have varied greatly throughout history. from the ancient city - states of greece and rome to modern democratic nations such as the united states and canada, each has evolved its own legal systems to manage internal affairs and international relations. this article examines the structures of governance in various countries, highlighting how laws are made, who makes them, and how these laws affect society on different levels.
# index: 150 target: 24
# index: 150 pred  : 8
# Train epoch:2  index:225 loss:3.1756845315 ACC:0.09222222222222222 lr:0.0000333333
# index: 225 input : the recent world cup in qatar has seen some of the most exciting matches, with teams from all over the world showcasing their skills and athleticism. goals have been thrilling to watch, especially those last - minute victories that keep fans on edge until the final whistle. the tournament not only highlights exceptional individual talent but also demonstrates the power of teamwork and strategy. in addition, the event's organization has set new standards for managing international sports events.
# index: 225 target: 5
# index: 225 pred  : 23
# index: 225 input : recent advancements in fiber optic technology have significantly increased the speed of internet connectivity worldwide. this development has also opened new opportunities for telecommunication services that now offer high - definition video calls and virtual reality experiences to consumers. the widespread adoption of these technologies is expected to revolutionize how people communicate, learn, and work from remote locations.
# index: 225 target: 9
# index: 225 pred  : 4
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:2  index:4 loss:2.8523067236 ACC:0.1875 lr:0.0000333333
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 24
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 4
# Val epoch:2  index:8 loss:2.8618798852 ACC:0.15625 lr:0.0000333333
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 17
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 23
# Val epoch:2  index:12 loss:3.0018347502 ACC:0.14583333333333334 lr:0.0000333333
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 24
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 4
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:3  index:75 loss:2.9821140893 ACC:0.16333333333333333 lr:0.0000296296
# index: 75 input : the processor is the brain of your computer, executing instructions provided by software programs. modern processors can contain billions of transistors and operate at speeds up to several gigahertz. understanding the architecture of a motherboard is also critical for building or upgrading your personal pc. additionally, advancements in graphics processing units have greatly enhanced the capabilities of gaming and professional applications.
# index: 75 target: 20
# index: 75 pred  : 13
# index: 75 input : the concept of employment has evolved over the decades, influenced by technological advancements and societal changes. in today's job market, employers seek versatile employees who can adapt to different roles and functions within an organization. educational institutions have responded by offering interdisciplinary programs that combine various fields such as computer science, business management, and communication studies to prepare students for a dynamic workforce. additionally, the rise of remote work has created opportunities for individuals from diverse geographical locations, leading to a more globalized job market.
# index: 75 target: 16
# index: 75 pred  : 10
# Train epoch:3  index:150 loss:2.9379713003 ACC:0.16833333333333333 lr:0.0000259259
# index: 150 input : the new smartphone model from xyz tech has been receiving rave reviews for its high - resolution display and long - lasting battery life. the device runs on an advanced chipset that supports the latest mobile operating system updates, ensuring users get the best performance possible. additionally, it comes equipped with multiple lenses in a rear camera setup, enabling superior photography capabilities even in low light conditions. moreover, the sleek design of the phone has made it a favorite among tech enthusiasts, who appreciate both form and function.
# index: 150 target: 20
# index: 150 pred  : 24
# index: 150 input : the constitution of the united states serves as the supreme law of the land, laying out the framework for federal governance and outlining individual rights protected from governmental infringement. it is composed of seven articles that detail the three primary branches of government : legislative ( congress ), executive ( the presidency ), and judicial ( supreme court ). the document also includes a series of amendments designed to further define citizens'rights and the responsibilities of the state. this foundational text has been interpreted over centuries through judicial review, a power granted by the landmark case marbury v. madison, establishing the supreme court as the ultimate arbiter of constitutional interpretation.
# index: 150 target: 24
# index: 150 pred  : 24
# Train epoch:3  index:225 loss:2.8914580541 ACC:0.18444444444444444 lr:0.0000222222
# index: 225 input : the real estate market in los angeles has been experiencing significant fluctuations over the past few years. housing prices have soared due to low interest rates and high demand from both local residents and foreign investors. many first - time buyers are finding it difficult to secure mortgages with traditional lenders, leading them to explore alternative financing options like private loans or crowdfunding platforms. in addition, the construction of new housing developments has been slow, partly due to regulatory hurdles and zoning laws that restrict building density in certain areas. the median price for a single - family home is now over $ 800, 000, making homeownership less accessible for middle - class families. meanwhile, the rental market remains competitive with an average rent of $ 2, 500 per month for a two - bedroom apartment.
# index: 225 target: 14
# index: 225 pred  : 0
# index: 225 input : the advent of 5g technology has brought about revolutionary changes in the telecommunications sector. it enables ultra - fast internet speeds and low latency, which are crucial for advanced applications like autonomous driving and augmented reality. the implementation of 5g also requires new infrastructure to support its higher frequency bands, such as small cells and macro cell towers, necessitating collaboration between telecom companies and local governments.
# index: 225 target: 9
# index: 225 pred  : 13
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:3  index:4 loss:2.8460687995 ACC:0.25 lr:0.0000222222
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 12
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 12
# Val epoch:3  index:8 loss:2.5552038997 ACC:0.21875 lr:0.0000222222
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 17
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 0
# Val epoch:3  index:12 loss:2.6923161546 ACC:0.20833333333333334 lr:0.0000222222
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 24
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 5
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:4  index:75 loss:2.6529095952 ACC:0.2733333333333333 lr:0.0000185185
# index: 75 input : the yangtze river, also known as the chang jiang, is the longest river in asia and flows from west to east across southern china. it originates at an altitude of over 5000 meters on the qinghai - tibet plateau and runs through numerous cities such as chongqing, wuhan, nanjing and shanghai before emptying into the east china sea near shanghai. this article also covers its rich cultural and ecological significance, including its importance in ancient chinese history and its role in modern transportation and industry.
# index: 75 target: 22
# index: 75 pred  : 1
# index: 75 input : according to recent reports from international health organizations, the global vaccination rate has significantly increased in the past six months, thanks to accelerated production and distribution of vaccines. this upward trend is most notable in regions that previously faced significant challenges with vaccine accessibility.
# index: 75 target: 17
# index: 75 pred  : 17
# Train epoch:4  index:150 loss:2.6011212238 ACC:0.27166666666666667 lr:0.0000148148
# index: 150 input : exploring the hidden gems of southeast asia has been an adventure that i will never forget. from the bustling streets of bangkok filled with vibrant street food to the serene beaches of phuket and bali, each destination offers a unique experience. the cultural richness is unparalleled as one can witness traditional dances in cambodia or hike through lush rainforests in indonesia.
# index: 150 target: 22
# index: 150 pred  : 12
# index: 150 input : in this section of the article, we will discuss various aspects of property investment in urban areas. we'll explore how rising population densities and economic growth affect real estate prices in metropolitan cities like new york and shanghai. additionally, the piece delves into innovative financing methods for aspiring homeowners and first - time buyers looking to enter the market.
# index: 150 target: 14
# index: 150 pred  : 12
# Train epoch:4  index:225 loss:2.5661308363 ACC:0.27555555555555555 lr:0.0000111111
# index: 225 input : the development of modern literature has seen significant changes in narrative techniques and themes over the past century. authors like james joyce and virginia woolf introduced stream - of - consciousness storytelling, while others focused on social issues like poverty and war. in recent years, genres such as magical realism and dystopian fiction have gained popularity. these works often explore complex human emotions and societal structures through imaginative settings.
# index: 225 target: 1
# index: 225 pred  : 24
# index: 225 input : the rapid advancement of wireless technology has led to the creation of a new ecosystem for information sharing. from the early days of pager networks to today's 5g infrastructure, the evolution in telecom technology has dramatically transformed how people communicate globally. in addition to voice calls and text messaging, we now have access to high - speed internet on our mobile devices, enabling live video streaming, web browsing, and other data - intensive applications. the backbone of these services often relies on complex networks that include satellites, cell towers, and fiber - optic cables.
# index: 225 target: 9
# index: 225 pred  : 21
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:4  index:4 loss:2.8067047894 ACC:0.25 lr:0.0000111111
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 24
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 1
# Val epoch:4  index:8 loss:2.5172059387 ACC:0.28125 lr:0.0000111111
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 17
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 0
# Val epoch:4  index:12 loss:2.5754617353 ACC:0.2708333333333333 lr:0.0000111111
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 24
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 14
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:5  index:75 loss:2.4020772521 ACC:0.3433333333333333 lr:0.0000074074
# index: 75 input : the recent drop in oil prices has sent shockwaves through the global market, impacting economies worldwide. analysts suggest that this is due to an oversupply of crude oil from producers such as saudi arabia and russia, who have increased production despite a decrease in demand. the situation could potentially lead to economic downturns if not addressed properly by major oil - consuming countries like china and the united states.
# index: 75 target: 0
# index: 75 pred  : 23
# index: 75 input : the text delves into the intricate storytelling mechanisms of video games across various genres. it explores how developers use narrative techniques such as branching storylines and non - linear progression to engage players deeply in their gaming experience. the analysis includes a comparison with traditional forms of storytelling, like novels and films, highlighting unique features found only in interactive media.
# index: 75 target: 19
# index: 75 pred  : 19
# Train epoch:5  index:150 loss:2.3768572934 ACC:0.325 lr:0.0000037037
# index: 150 input : the game starts with the player character in a vast open world where they can explore ruins, forests, and towns. the plot revolves around discovering the origins of an ancient civilization that vanished mysteriously centuries ago. alongside exploring the environment, players engage in combat against various mythical creatures to progress through the story. interaction with non - playable characters allows for quest completion, trading goods, and gathering information essential to unraveling the mystery.
# index: 150 target: 19
# index: 150 pred  : 12
# index: 150 input : recently, automotive engineers have developed an innovative engine design that significantly improves fuel efficiency while maintaining power output. this design utilizes advanced materials and aerodynamics to reduce weight and wind resistance, respectively. the new vehicle models equipped with this technology are expected to achieve a notable reduction in emissions, contributing positively to environmental conservation efforts. car enthusiasts can look forward to a blend of eco - friendliness and performance in the upcoming lineup.
# index: 150 target: 3
# index: 150 pred  : 4
# Train epoch:5  index:225 loss:2.3270018554 ACC:0.3377777777777778 lr:0.0000000000
# index: 225 input : this article discusses various properties in the central region of beijing, ranging from luxurious penthouses to compact apartments suitable for young professionals. the text includes descriptions of the living environments around each property and reviews of nearby facilities such as schools, shopping malls, and hospitals. it also analyzes the investment potential of different real estate projects based on current market trends and future development plans.
# index: 225 target: 14
# index: 225 pred  : 12
# index: 225 input : throughout history, human societies have developed various systems of governance designed to manage internal conflicts and promote social stability. from the early forms of monarchy in ancient civilizations to modern democratic republics, each system carries its own unique principles that guide how power is distributed among individuals or groups within a society. democratic institutions such as parliaments, elections, and constitutions provide frameworks for ensuring that all citizens have a say in how they are governed. these elements play crucial roles not only in shaping the legal landscape but also in fostering cultural values such as freedom of speech, equality before the law, and human rights.
# index: 225 target: 24
# index: 225 pred  : 4
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:5  index:4 loss:2.7012521923 ACC:0.1875 lr:0.0000000000
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 24
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 1
# Val epoch:5  index:8 loss:2.4145709127 ACC:0.25 lr:0.0000000000
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 17
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 0
# Val epoch:5  index:12 loss:2.5289184252 ACC:0.2708333333333333 lr:0.0000000000
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 24
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 14

# %%
PATH = 'Diag_Mask3_FT_argilla_curr.pt'
if use_saved_pth and os.path.isfile(PATH):
    print( "loaded Diag_Mask3_curr.pt")
    checkpoint = torch.load(PATH)
    model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# loaded Diag_Mask6_curr.pt

# %%
test_loader = DataLoader(test_dataset,
                        batch_size=1,
                        shuffle=False,
                        num_workers=num_workers,)
                        #collate_fn = collate_func_lambda)
print( "test_loader defined" )
print( len( test_loader ))
# Out:
# test_loader defined
# 50

# %%
model.eval()
print("Test")

n = 0
total_acc = 0
total_loss = 0
test_print_coef = len( test_loader ) // 10

for i, ( inputs, labels ) in enumerate( test_loader ):
    inputs = inputs.to(device)
    y_true = labels
    labels = labels.to(device)
    #labels = nn.functional.one_hot(labels.to(device).long(), num_classes = 2 ).float()

    with torch.no_grad():
        logits = model( inputs )
        y_pred = torch.argmax( logits, dim = 1 )
        # 損失の計算
        loss = criterion( logits, labels )
           
    total_loss += loss.item()
    n2 = 0
    input_sentence = []
    target_label = []
    pred_label = []
    for input_id, label, pred in zip( inputs, y_true, y_pred ):
        if n2 < 2 and ( i % test_print_coef == test_print_coef -1 ) :
            input_s = tokenizer.decode( input_id, skip_special_tokens = True )
            input_sentence.append( input_s )
            target_label.append( label )
            pred_label.append( pred.item() )
                
        n2 += 1

    accuracy = accuracy_score(y_true, y_pred.detach().cpu() )
    total_acc += accuracy

print(f"index:{i+1} loss: {total_loss / i}")        
print(f"index:{i+1}  ACC: {total_acc / i}")
# Out:
# Test
# index:50 loss: 2.5472865250075656
# index:50  ACC: 0.22448979591836735
