# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
#import json
import pickle

# %%
with open('Diag_Mask3_FT_argilla.pkl', 'rb') as f:
    history = pickle.load(f)
    
len_tr_loader = history["len_tr_loader"][0]
#print( len_tr_loader)
len_val_loader = history["len_val_loader"][0] 
#print( len_val_loader)

x = []
y = []
y_acc = []
#print( len( history["train_loss"] ))
for i in range( len( history["train_loss"] )):
    #print( i )
    #print( i // len_tr_loader )
    x.append( i / len_tr_loader )
    y.append( np.mean(history['train_loss'][i-len_tr_loader:i]) )
    y_acc.append( np.mean(history['train_acc'][i-len_tr_loader:i]))
    
v_x = []
v_y = []
v_y_acc = []
#print( len( history["val_loss"]) )
for i in range( len( history["val_loss"]) ):
    v_x.append( i / len_val_loader )
    v_y.append( np.mean(history['val_loss'][i-len_val_loader:i]))
    v_y_acc.append( np.mean( history['val_acc'][i-len_val_loader:i]))

plt.title( "Loss")
plt.xlabel( "Epochs")
plt.ylabel( "Loss")
#plt.plot(x, history["train_loss"], label="train_loss")
#plt.plot( v_x, history["val_loss"], label="val_loss")
plt.plot( x, y, label="train_loss mean ")
plt.plot( v_x, v_y, label="val_loss mean")
             
#plt.xlim( 84000, 100000 )
plt.legend()
plt.show()
'''
plt.title( "Accuracy")
plt.xlabel( "Epochs")
plt.ylabel( "Accuracy")
plt.plot(x, history["train_acc"], label="train_acc")
plt.plot( v_x, history["val_acc"], label="val_acc")
plt.legend()
plt.show()
'''
plt.title( "ACC")
plt.xlabel( "Epochs")
plt.ylabel( "ACC")
#plt.plot(x, history["train_acc"], label="train_acc")
#plt.plot( v_x, history["val_acc"] , label="val_acc")
plt.plot( x, y_acc, label="train_acc mean ")
plt.plot( v_x, v_y_acc, label="val_acc mean")
#plt.xlim( 84000, 100000 )
plt.legend()
plt.show()

#plt.title( "BLEU")
#plt.xlabel( "Epochs")
#plt.ylabel( "BLEU")
#plt.plot(x, history["train_bleu"], label="train_bleu")
#plt.plot( v_x, history["val_bleu"] , label="val_bleu")
##plt.xlim( 84000, 100000 )
#plt.legend()
#plt.show()

# %%
with open('Diag_Mask5_FT_argilla.pkl', 'rb') as f:
    history5 = pickle.load(f)
    
len_tr_loader5 = history["len_tr_loader"][0]
#print( len_tr_loader)
len_val_loader5 = history["len_val_loader"][0] 
#print( len_val_loader)


x5 = []
y5 = []
y_acc5 = []
#print( len( history["train_loss"] ))
for i in range( len( history5["train_loss"] )):
    #print( i )
    #print( i // len_tr_loader )
    x5.append( i / len_tr_loader5 )
    y5.append( np.mean(history5['train_loss'][i-len_tr_loader5:i]) )
    y_acc5.append( np.mean(history5['train_acc'][i-len_tr_loader5:i]))
    
v_x5 = []
v_y5 = []
v_y_acc5 = []
#print( len( history["val_loss"]) )
for i in range( len( history5["val_loss"]) ):
    v_x5.append( i / len_val_loader5 )
    v_y5.append( np.mean(history5['val_loss'][i-len_val_loader5:i]))
    v_y_acc5.append( np.mean( history5['val_acc'][i-len_val_loader5:i]))

plt.title( "Loss")
plt.xlabel( "Epochs")
plt.ylabel( "Loss")
#plt.plot(x, history["train_loss"], label="train_loss")
#plt.plot( v_x, history["val_loss"], label="val_loss")
plt.plot( x5, y5, label="5 train_loss mean ")
plt.plot( v_x5, v_y5, label="5 val_loss mean")
plt.plot( x, y, label="train_loss mean ")
plt.plot( v_x, v_y, label="val_loss mean")
#plt.xlim( 84000, 100000 )
plt.legend()
plt.show()
'''
plt.title( "Accuracy")
plt.xlabel( "Epochs")
plt.ylabel( "Accuracy")
plt.plot(x, history["train_acc"], label="train_acc")
plt.plot( v_x, history["val_acc"], label="val_acc")
plt.legend()
plt.show()
'''
plt.title( "ACC")
plt.xlabel( "Epochs")
plt.ylabel( "ACC")
#plt.plot(x, history["train_acc"], label="train_acc")
#plt.plot( v_x, history["val_acc"] , label="val_acc")
plt.plot( x5, y_acc5, label="5 train_acc mean ")
plt.plot( v_x5, v_y_acc5, label="5 val_acc mean")
plt.plot( x, y_acc, label="train_acc mean ")
plt.plot( v_x, v_y_acc, label="val_acc mean")
#plt.xlim( 84000, 100000 )
plt.legend()
plt.show()

#plt.title( "BLEU")
#plt.xlabel( "Epochs")
#plt.ylabel( "BLEU")
#plt.plot(x, history["train_bleu"], label="train_bleu")
#plt.plot( v_x, history["val_bleu"] , label="val_bleu")
##plt.xlim( 84000, 100000 )
#plt.legend()
#plt.show()

# %%
with open('Diag_Mask6_FT_argilla.pkl', 'rb') as f:
    history6 = pickle.load(f)
    
len_tr_loader6 = history6["len_tr_loader"][0]
#print( len_tr_loader)
len_val_loader6 = history6["len_val_loader"][0] 
#print( len_val_loader)


x6 = []
y6 = []
y_acc6 = []
#print( len( history["train_loss"] ))
for i in range( len( history6["train_loss"] )):
    #print( i )
    #print( i // len_tr_loader )
    x6.append( i / len_tr_loader6 )
    y6.append( np.mean(history6['train_loss'][i-len_tr_loader6:i]) )
    y_acc6.append( np.mean(history6['train_acc'][i-len_tr_loader6:i]))
    
v_x6 = []
v_y6 = []
v_y_acc6 = []
#print( len( history["val_loss"]) )
for i in range( len( history6["val_loss"]) ):
    v_x6.append( i / len_val_loader6 )
    v_y6.append( np.mean(history6['val_loss'][i-len_val_loader6:i]))
    v_y_acc6.append( np.mean( history6['val_acc'][i-len_val_loader6:i]))

#print( x )
#print( x6 )

plt.title( "Train Loss")
plt.xlabel( "Epochs")
plt.ylabel( "Loss")
plt.plot( x5, y5, label="no pretrain train_loss mean ")
plt.plot( x, y, label="emulatemask train_loss")
plt.plot(x6, y6, label="realmask train_loss")
#plt.xlim( 84000, 100000 )
#plt.ylim( 0, 2 )
plt.legend()
plt.show()

plt.title( "Val Loss")
plt.xlabel( "Epochs")
plt.ylabel( "Loss")
plt.plot( v_x5, v_y5, label="no pretrain val_loss")
plt.plot( v_x, v_y, label="emulatemask val_loss")
plt.plot( v_x6, v_y6, label="realmask val_loss")
#plt.xlim( 84000, 100000 )
#plt.ylim( 0, 2 )
plt.legend()
plt.show()

plt.title( "Train ACC")
plt.xlabel( "Epochs")
plt.ylabel( "ACC")
plt.plot(x5, y_acc5, label="no pretrain train_acc")
plt.plot(x, y_acc, label="enumlatemask train_acc")
plt.plot(x6, y_acc6, label="realmask train_acc")
#plt.xlim( 84000, 100000 )
#plt.ylim( 0, 40 )
plt.legend()
plt.show()
          
plt.title( "Val ACC")
plt.xlabel( "Epochs")
plt.ylabel( "ACC")
plt.plot( v_x5, v_y_acc5, label="no pretrain val_acc")
plt.plot( v_x, v_y_acc, label="emulatemask val_acc")
plt.plot( v_x6, v_y_acc6, label="realmask val_acc")
#plt.xlim( 84000, 100000 )
#plt.ylim( 0, 40 )
plt.legend()
plt.show()
