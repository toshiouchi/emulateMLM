# %%
# -*- coding: utf-8 -*-

#
# Pytorchで用いるDatasetの定義
#

#!pip install janome

# sysモジュールをインポート
import sys
import os

import matplotlib.pyplot as plt
import pandas as pd
import torch
import random
from torch import nn, Tensor
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import numpy as np
import math
import janome
from janome.tokenizer import Tokenizer
from collections import Counter
from torch.utils.data.sampler import SubsetRandomSampler
import time
import levenshtein
import pickle
from timm.scheduler import CosineLRScheduler
from nltk import bleu_score
#from tqdm import tqdm
from tqdm.notebook import tqdm
from torch import autocast, GradScaler
from typing import Sequence, Dict, Tuple, Union
from transformers import  get_linear_schedule_with_warmup, BertTokenizer
from sklearn.metrics import accuracy_score
from datasets import load_dataset

#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device( "cpu")
use_amp = False
use_saved_pth = True

# %%
path = "../../python_image_recognition-main/6_img_captioning/6_7_ImgCap_pre_trained_Feature_extractor/CLIP_ENCODER/models--google-bert--bert-large-uncased/snapshots/6da4b6a26a1877e173fca3225479512db81a5e5b"
tokenizer = BertTokenizer.from_pretrained(pretrained_model_name_or_path = path)

vocab_size = len(tokenizer)
print(vocab_size)
# Out:
# 30522

# %%
class MyDataset(Dataset):
    def __init__(self, mode, tokenizer, pad_token_id, max_length ):

        #dataset = load_dataset("yelp_review_full") 
        #dataset = load_dataset("imdb")
        #dataset = load_dataset("kunishou/databricks-dolly-15k-ja")  
        # Dataset id from huggingface.co/dataset
        dataset_id = "argilla/synthetic-domain-text-classification"
        dataset = load_dataset(dataset_id, split='train')
 
        ## Load raw dataset
        #train_dataset = load_dataset(dataset_id, split='train')
        
        if mode == "train":
            dataset = dataset[:900]
        elif mode == "val":
            dataset = dataset[900:950]
        else:
            dataset = dataset[950:1000]
        self.dataset = dataset
        #print( "self.dataset[1]:", self.dataset['label'][1])
            
        #self.encoded_texts = [ tokenizer.encode(text, max_length = max_length, truncation = True ) for text in dataset['text']]
        self.encoded_texts = [ tokenizer.encode(text ) for text in dataset['text']]
        
        if max_length is None:
            self.max_length = self._longest_encoded_length()
        else:
            self.max_length = max_length
            # Truncate sequences if they are longer than max_length
            self.encoded_texts = [
                encoded_text[:self.max_length]
                for encoded_text in self.encoded_texts
            ]

        # Pad sequences to the longest sequence
        self.encoded_texts = [
            encoded_text + [pad_token_id] * (self.max_length - len(encoded_text))
            for encoded_text in self.encoded_texts
        ]
        
    def __getitem__(self, index):
        encoded = self.encoded_texts[index]
        label = self.dataset["label"][index]
        return (
            torch.tensor(encoded, dtype=torch.long),
            torch.tensor(label, dtype=torch.long)
        )

    def __len__(self):
        return len(self.encoded_texts)

    def _longest_encoded_length(self):
        max_length = 0
        for encoded_text in self.encoded_texts:
            encoded_length = len(encoded_text)
            if encoded_length > max_length:
                max_length = encoded_length
        return max_length
        # Note: A more pythonic version to implement this method
        # is the following, which is also used in the next chapter:
        # return max(len(encoded_text) for encoded_text in self.encoded_texts)

# %%
train_dataset = MyDataset(
    mode="train",
    tokenizer=tokenizer,
    pad_token_id = tokenizer.pad_token_id,
    max_length=None,
)

print(train_dataset.max_length)
print( len( train_dataset ))
# Out:
# 408
# 900

# %%
val_dataset = MyDataset(
    mode="val",
    tokenizer=tokenizer,
    pad_token_id = tokenizer.pad_token_id,
    max_length=512,
)
test_dataset = MyDataset(
    mode="test",
    tokenizer=tokenizer,
    pad_token_id = tokenizer.pad_token_id,
    max_length=512,
)

# %%
#num_workers = 0 if device == torch.device( 'cpu' ) else 8
num_workers = 0 if device == torch.device( 'cpu' ) else 8
batch_size = 4

train_loader = DataLoader(train_dataset,
                            batch_size=batch_size,
                            shuffle=True,
                            num_workers=num_workers,
                            pin_memory=True,)
                            #collate_fn = collate_func_lambda)
print( "train_loader defiend" )
# 開発データのDataLoaderを呼び出す
# 開発データはデータはシャッフルしない
val_loader = DataLoader(val_dataset,
                        batch_size=batch_size,
                        shuffle=False,
                        num_workers=num_workers,)
                        #collate_fn = collate_func_lambda)
print( "val_loader defined" )
print( len( train_loader ))
print( len( val_loader ))

inputs, labels = next(iter(val_loader))
print( inputs )
print( labels )
#print(text[0], target[0], text_len[0],target_len[0], sep="\n")
#print( "text:", text )
#print( "text_len:", text_len )
# Out:
# train_loader defiend
# val_loader defined
# 225
# 13
# tensor([[ 101, 5983, 2092,  ...,    0,    0,    0],
#         [ 101, 1996, 3795,  ...,    0,    0,    0],
#         [ 101, 2023, 3720,  ...,    0,    0,    0],
#         [ 101, 3795, 3119,  ...,    0,    0,    0]])
# tensor([17,  9,  4,  0])

# %%
print( len( inputs ))
print( len( labels ))
print( batch_size )
# Out:
# 4
# 4
# 4

# %%
class PositionalEmbedding(nn.Module):
    '''
    位置埋め込み （Positional embedding）
    dim_embedding: 埋込み次元
    max_len      : 入力の最大系列長
    '''
    def __init__(self, dim_embedding: int, max_len: int=2048):
        super().__init__()

        self.pos_emb = nn.Embedding(max_len, dim_embedding)

    '''
    位置エンコーディングの順伝播
    x: 位置エンコーディングを埋め込む対象のテンソル,
       [バッチサイズ, 系列長, 埋め込み次元]
    '''
    def forward(self, x: torch.Tensor):
        seq = x.shape[1]
        positions = torch.arange(start=0, end=seq, step=1, device=x.device).to(torch.long)
        positions = self.pos_emb(positions)[:seq,:]
        
        return positions

# %%
class TransformerEncoder(nn.Module):
    '''
    CaptioningTransformerのコンストラクタ
    dim_embedding  : 埋め込み次元
    dim_feedforward: FNNの中間特徴次元
    num_heads      : マルチヘッドアテンションのヘッド数
    num_layers     : Transformerデコーダ層の数
    vocab_size     : 辞書の次元
    pad_index      : PADのID
    dropout        : ドロップアウト確率
    '''
    def __init__(self, vocab_size: int, dim_embedding: int, dim_feedforward: int,
                 num_heads: int, num_layers: int ):
        super().__init__()

        self.encoder_layers = nn.ModuleList([
            nn.TransformerEncoderLayer(d_model=dim_embedding, nhead=num_heads, batch_first=True, activation='gelu', norm_first=True)
            for _ in range(num_layers)
        ])

    ''' CaptioningTransformerの順伝播処理
    features: 画像特徴量 [バッチサイズ, 埋め込み次元]
    captions: 正解キャプション [バッチサイズ, 系列長]

    '''
    def forward(self, src: torch.Tensor, src_mask: torch.Tensor=None, \
                src_key_padding_mask: torch.Tensor=None ):


        for layer in self.encoder_layers:
            src = layer( src, src_mask = src_mask, src_key_padding_mask = src_key_padding_mask,\
                        #is_causal= True )
                        is_causal= False )

        return src

# %%
class Transformer(nn.Module):
    def __init__(self, dim_embedding: int, dim_feedforward: int,
                 num_heads: int, num_layers: int, vocab_size: int,
                 pad_index: int, dropout: float=0.5, us_rate: float=2.0 ):
        super().__init__()

        # 単語埋め込み
        self.embed = nn.Embedding(
            vocab_size, dim_embedding, padding_idx=pad_index)

        # 位置エンコーディング
        self.pos_emb = PositionalEmbedding(dim_embedding)        
        
        # dropout
        self.dropout = nn.Dropout( dropout )
        
        self.encoder = TransformerEncoder(vocab_size, dim_embedding, dim_feedforward, num_heads, num_layers)

        # 単語出力分布計算
        self.ln = nn.LayerNorm( dim_embedding )
        self.linear = nn.Linear(dim_embedding, vocab_size)

        self.pad_index = pad_index
        
    ''' CaptioningTransformerの順伝播処理
    features: 画像特徴量 [バッチサイズ, 埋め込み次元]
    captions: 正解キャプション [バッチサイズ, 系列長]

    '''
    def forward(self, text):

        device = text.device

        src = self.embed( text )
        
        src += self.pos_emb( src )
        src = self.dropout( src )
        src_key_padding_mask = torch.eq(text, self.pad_index)

        #ones = torch.ones( text.size(1) ).to( device = device )
        #src_mask = torch.diag( ones ).bool()
        src_mask = None
        
        preds = self.encoder( src, src_mask, src_key_padding_mask )
        
        preds = self.ln( preds )
        preds = preds[:,0,:]
        logits = self.linear( preds )

        return logits

# %%
epoch_num = 5
model = Transformer(768, 3072, 12, 6, vocab_size, tokenizer.pad_token_id ).to(device)
#criterion = nn.BCEWithLogitsLoss()
criterion = nn.CrossEntropyLoss()
#lr = 1e-4
lr = 5e-5
optimizer = optim.AdamW( model.parameters(), lr = lr )
# 全ステップ数
num_global_steps = len( train_loader ) * epoch_num
print( "num_global_steps:", num_global_steps )
num_warmup_steps = num_global_steps * 0.1
print( "num_warmup_steps:", num_warmup_steps )
#スケジューラーの定義
scheduler = get_linear_schedule_with_warmup( optimizer, num_warmup_steps, num_global_steps )
eps = 1e-4

#PATH = 'Diag_Mask3_curr.pt'
#if use_saved_pth and os.path.isfile(PATH):
#    print( "loaded Diag_Mask6_curr.pt")
#    checkpoint = torch.load(PATH)
#    model.load_state_dict(checkpoint['model_state_dict'])

#model.linear = nn.Linear( 768, 5 ) 
model.linear = nn.Linear( 768, 26 )
# Out:
# num_global_steps: 1125
# num_warmup_steps: 112.5

# %%
# WarmupとCosine Decayを行うスケジューラを利用
#scheduler = CosineLRScheduler(
#    optimizer, t_initial=epoch_num, lr_min=1e-1,
#    warmup_t=5, warmup_lr_init=5e-2, warmup_prefix=True)

#tr_print_coef = 64000
#tr_save_coef = 1000
#val_print_coef = 240
len_tr_loader = len( train_loader )
len_val_loader = len( val_loader )
tr_print_coef = len_tr_loader // 3
tr_save_coef = len_tr_loader // 30
val_print_coef = len_val_loader // 3
print( "len( train_loader ):", len_tr_loader )
print( "len( val_loader ):", len_val_loader )
print( "tr_print_coef:", tr_print_coef )
print( "tr_save_coef:", tr_save_coef )
print( "val_print_coef:", val_print_coef )
#tr_print_coef = 1
#tr_save_coef = 1
#val_print_coef = 1
#train_length = len(train_loader)
#train_int = train_length // tr_print_coef
#print( train_int )
#print( train_length )
#val_length = len(val_loader)
#val_int = val_length // val_print_coef
#print( val_int )
#print( val_length )

history = {"len_tr_loader":[],"len_val_loader":[], "train_loss":[], "val_loss": [], "train_acc": [], "val_acc": [] }
history["len_tr_loader"].append( len_tr_loader )
history["len_val_loader"].append( len_val_loader )
with open("Diag_Mask5_FT_argilla.pkl", "wb") as f:
    pickle.dump( history, f )      
n = 0
train_loss = 0
val_loss = 0


# 学習率の減衰やEarly stoppingの
# 判定を開始するエポック数
# (= 最低限このエポックまではどれだけ
# validation結果が悪くても学習を続ける)
lr_decay_start_epoch = 5

# 学習率を減衰する割合
# (減衰後学習率 <- 現在の学習率*lr_decay_factor)
# 1.0以上なら，減衰させない
lr_decay_factor = 0.5

# Early stoppingの閾値
# 最低損失値を更新しない場合が
# 何エポック続けば学習を打ち切るか
early_stop_threshold = 3

# 最も低い損失値，
# そのときのモデルとエポック数を記憶しておく
best_loss = -1
best_model = None
best_epoch = 0

# Early stoppingフラグ．Trueになると学習を打ち切る
early_stop_flag = False
# Early stopping判定用(損失値の最低値が
# 更新されないエポックが何回続いているか)のカウンタ
counter_for_early_stop = 0

fn = bleu_score.SmoothingFunction().method7

# AMP用のスケーラー
scaler = GradScaler(enabled=use_amp)

for epoch in range(epoch_num):
    # early stopフラグが立っている場合は，
    # 学習を打ち切る
    if early_stop_flag:
        print('    Early stopping.'\
            ' (early_stop_threshold = %d)' \
            % (early_stop_threshold))
        #log_file.write('\n    Early stopping.'\
        #        ' (early_stop_threshold = %d)' \
        #        % (early_stop_threshold))
        break

    with tqdm(train_loader) as pbar:
    #with tqdm(val_loader) as pbar:
        pbar.set_description(f'[Train エポック {epoch + 1}]')
    
        model.train()
        #scheduler.step(epoch)
        #print( "Train")
        train_loss = 0
        total_acc = 0
        n3 = 0
        for i, ( inputs, labels ) in enumerate( pbar ):
            optimizer.zero_grad()
            inputs = inputs.to(device)
            y_true = labels.tolist()
            labels = labels.to(device)
            #labels = nn.functional.one_hot(labels.to(device).long(), num_classes = 5 ).float()
            #labels = labels.to(device).long()
            
            with autocast(str(device),enabled=use_amp):
                logits = model( inputs )
                #print( "logits size:", logits.size() )
                y_pred = torch.argmax( logits, dim = 1 )
                # 損失の計算
                loss = criterion( logits, labels )

                
            # 誤差逆伝播
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            clip_grad_threshold = 5.0
            torch.nn.utils.clip_grad_norm_(\
                    model.parameters(),
                    clip_grad_threshold)
            # オプティマイザにより，パラメータを更新する
            scaler.step(optimizer)
            scaler.update()            
            
            scheduler.step()
            
            #lr = optimizer.param_groups[0]['lr']
            #print( "lr:", lr )
            
            n2 = 0
            input_sentence = []
            target_label = []
            pred_label = []
            for input_id, label, pred in zip( inputs, y_true, y_pred ):
                #print( "label:", label )
                #print( "pred:",pred )
                if n2 < 2 and ( i % tr_print_coef == tr_print_coef -1 ) :
                    input_s = tokenizer.decode( input_id, skip_special_tokens = True )
                    input_sentence.append( input_s )
                    target_label.append( label )
                    pred_label.append( pred.item() )
                
                n2 += 1

            #print( "y_true size:", torch.tensor( y_true).size() )
            #print( "y_pred size:", y_pred.size() )
            accuracy = accuracy_score(y_true, y_pred.detach().cpu() )
            total_acc += accuracy
            n3 += 1
    
            train_loss += loss.item()
            history["train_loss"].append( loss.item() )
            history["train_acc"].append( accuracy )
            if i % tr_save_coef == tr_save_coef - 1:
                with open("Diag_Mask5_FT_argilla.pkl", "wb") as f:
                    pickle.dump( history, f )            
            if i % tr_print_coef == tr_print_coef - 1:
                lr = optimizer.param_groups[0]['lr']
                print(f"Train epoch:{epoch+1}  index:{i+1} loss:{train_loss/n3:.10f} ACC:{ total_acc / n3 } lr:{lr:.10f}")
            #if i == len( train_loader ) - 1:
            for (input_s, target_lbl, pred_lbl ) in zip( input_sentence, target_label, pred_label ):
                print( "index:", i+1, "input :", input_s)
                print( "index:", i+1, "target:", target_lbl)
                print( "index:", i+1, "pred  :", pred_lbl )
            pbar.set_postfix({
                    'loss': train_loss / n3,
                    'acc': total_acc / n3,
                })

    with tqdm(val_loader) as pbar:
        pbar.set_description(f'[検証]')
        model.eval()
        #for i, ( text, target, text_len, target_len ) in enumerate(val_loader):
        val_loss = 0
        total_acc = 0
        n3 = 0
        for i, ( inputs, labels ) in enumerate( pbar ):
            inputs = inputs.to(device)
            y_true = labels.tolist()
            labels = labels.to(device)
            #labels = nn.functional.one_hot(labels.to(device).long(), num_classes = 2 ).float()
            #labels = labels.to(device).long()

            with torch.no_grad():
                logits = model( inputs )
                y_pred = torch.argmax( logits, dim = 1 )
                # 損失の計算
                loss = criterion( logits, labels )
           

            n2 = 0
            input_sentence = []
            target_label = []
            pred_label = []
            for input_id, label, pred in zip( inputs, y_true, y_pred ):
                if n2 < 2 and ( i % val_print_coef == val_print_coef -1 ) :
                    input_s = tokenizer.decode( input_id, skip_special_tokens = True )
                    input_sentence.append( input_s )
                    target_label.append( label )
                    pred_label.append( pred.item() )
                
                n2 += 1
                
            #print( "y_true size:", torch.tensor( y_true).size() )
            #print( "y_pred size:", y_pred.size() )
            accuracy = accuracy_score(y_true, y_pred.detach().cpu() )
            total_acc += accuracy
            n3 += 1
            
            val_loss += loss.item()
            history["val_loss"].append( loss.item() )
            history["val_acc"].append( accuracy )

            if i % val_print_coef == val_print_coef - 1:
                lr = optimizer.param_groups[0]['lr']
                print(f"Val epoch:{epoch+1}  index:{i+1} loss:{val_loss/n3:.10f} ACC:{total_acc / n3 } lr:{lr:.10f}")
                PATH = './Diag_Mask5_FT_argilla_curr.pt'
                torch.save({'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'loss': loss,},
                     PATH)
                with open("Diag_Mask5_FT_argilla.pkl", "wb") as f:
                    pickle.dump( history, f )
            #if i == len( train_loader ) - 1:
            for (input_s, target_lbl, pred_lbl ) in zip( input_sentence, target_label, pred_label ):
                print( "index:", i+1, "input :", input_s)
                print( "index:", i+1, "target:", target_lbl)
                print( "index:", i+1, "pred  :", pred_lbl )
            pbar.set_postfix({
                    'loss': val_loss / n3,
                    'acc': total_acc / n3,
                })
    
    epoch_loss = val_loss/n3
    if epoch == 0 or best_loss > epoch_loss:
        # 損失値が最低値を更新した場合は，
        # その時のモデルを保存する
        best_loss = epoch_loss
        torch.save(model.state_dict(), 
                    './best_model_Mask5_FT_argilla.pt')
        best_epoch = epoch
        # Early stopping判定用の
        # カウンタをリセットする
        counter_for_early_stop = 0
    else:
        # 最低値を更新しておらず，
        if epoch+1 >= lr_decay_start_epoch:
            # かつlr_decay_start_epoch以上の
            # エポックに達している場合
            if counter_for_early_stop+1 \
                    >= early_stop_threshold:
                # 更新していないエポックが，
                # 閾値回数以上続いている場合，
                # Early stopping フラグを立てる
                early_stop_flag = True
            else:
                # Early stopping条件に
                # 達していない場合は
                # 学習率を減衰させて学習続行
                if lr_decay_factor < 1.0:
                    for i, param_group \
                            in enumerate(\
                            optimizer.param_groups):
                        if i == 0:
                            lr = param_group['lr']
                            dlr = lr_decay_factor \
                                * lr
                            print('    (Decay '\
                                'learning rate:'\
                                ' %f -> %f)' \
                                % (lr, dlr))
                        param_group['lr'] = dlr
                # Early stopping判定用の
                # カウンタを増やす
                counter_for_early_stop += 1
#torch.cuda.synchronize()
# Out:
# len( train_loader ): 225
# len( val_loader ): 13
# tr_print_coef: 75
# tr_save_coef: 7
# val_print_coef: 4
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:1  index:75 loss:3.3305014356 ACC:0.056666666666666664 lr:0.0000333333
# index: 75 input : a recent forum discussion on various online communities has highlighted the unique characteristics of these platforms. users engage in diverse activities ranging from video gaming and anime discussions to more niche topics like diy woodworking projects. one particular thread caught my attention, where a user sought advice for creating a community - based website for garden enthusiasts. the responses were varied, offering tips on using wordpress or squarespace as a platform, emphasizing the importance of community guidelines to ensure respectful interactions, and even suggesting ways to monetize through affiliate marketing or sponsored content.
# index: 75 target: 7
# index: 75 pred  : 20
# index: 75 input : the legal system in many countries operates through courts that interpret laws created by government bodies. these systems ensure fairness, justice, and the protection of rights. in recent years, there has been a growing emphasis on digital privacy laws to protect personal information online, reflecting society's increasing reliance on technology.
# index: 75 target: 24
# index: 75 pred  : 17
# Train epoch:1  index:150 loss:3.3162276268 ACC:0.056666666666666664 lr:0.0000481481
# index: 150 input : the social impact of urbanization has been widely studied in the last few decades. as cities expand, they often experience significant demographic changes, including an increase in population density and diversity. these shifts can lead to both positive outcomes, such as enhanced cultural exchanges and economic opportunities, and negative consequences like overcrowding, pollution, and strain on infrastructure. sociologists have found that urban environments play a pivotal role in shaping community dynamics and individual behaviors.
# index: 150 target: 4
# index: 150 pred  : 17
# index: 150 input : recent studies have shown an increase in pet ownership among urban dwellers, particularly in the form of cats and small dogs. these animals serve as companions and provide emotional support to their owners. the benefits of owning a pet extend beyond just emotional well - being ; they can improve physical health by encouraging exercise and social interaction.
# index: 150 target: 8
# index: 150 pred  : 8
# Train epoch:1  index:225 loss:3.3227077876 ACC:0.06111111111111111 lr:0.0000444444
# index: 225 input : in recent years, there has been an increasing trend in the study of social networks within various communities around the world. sociologists have found that these networks play a crucial role in shaping individual behaviors and societal norms. from small towns to large metropolitan areas, community bonds can be seen in how people interact, support one another, and share resources. for example, in many rural areas, local groups organize events such as harvest festivals or communal meals which strengthen social ties within the population. in contrast, urban settings often rely on formal organizations like non - profit groups and charities to foster a sense of community among residents who may not have the same level of face - to - face interaction.
# index: 225 target: 4
# index: 225 pred  : 17
# index: 225 input : italian cuisine is renowned worldwide for its simplicity and the use of fresh ingredients. pasta dishes like spaghetti carbonara, with its creamy sauce made from eggs, pecorino romano cheese, guanciale ( cured pork cheek ), and black pepper, exemplify this approach. in addition to pasta, italy offers an array of regional specialties such as risotto in milanese cuisine, known for the use of saffron and local wine, giving it a rich flavor and golden hue. italian desserts also vary widely depending on the region, from the famous tiramisu with mascarpone cheese and coffee - soaked ladyfingers to simple yet delightful gelato flavors like stracciatella or pistachio.
# index: 225 target: 13
# index: 225 pred  : 10
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:1  index:4 loss:3.4758304358 ACC:0.0625 lr:0.0000444444
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 17
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 17
# Val epoch:1  index:8 loss:3.2733103037 ACC:0.09375 lr:0.0000444444
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 17
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 17
# Val epoch:1  index:12 loss:3.3406275511 ACC:0.08333333333333333 lr:0.0000444444
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 17
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 17
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:2  index:75 loss:3.2178145854 ACC:0.09666666666666666 lr:0.0000407407
# index: 75 input : the rise of digital privacy concerns has prompted governments worldwide to consider new legislation aimed at regulating data collection practices. this includes measures that would require companies to disclose their methods for gathering user information and implement stricter controls on how this data is used and shared. the implications extend beyond just consumer protection, influencing international trade agreements and the framework under which businesses operate globally.
# index: 75 target: 24
# index: 75 pred  : 24
# index: 75 input : the supreme court of the united states has been at the center of many historic decisions that have shaped american jurisprudence over the years. from civil rights cases like brown v. board of education to recent debates on healthcare reform with the affordable care act, the role of the court in interpreting the constitution and impacting national policy is undeniable.
# index: 75 target: 24
# index: 75 pred  : 0
# Train epoch:2  index:150 loss:3.2096661917 ACC:0.08666666666666667 lr:0.0000370370
# index: 150 input : the constitution of the united states was drafted in 1787 and has since served as the supreme law of the land. it outlines the framework for the federal government, dividing powers among the legislative, executive, and judicial branches. the document includes a system of checks and balances to ensure no one branch becomes too powerful. additionally, it establishes a bicameral legislature with members elected from constituent states, aiming to represent both small and large population centers effectively.
# index: 150 target: 24
# index: 150 pred  : 8
# index: 150 input : the influence of postmodernist art on contemporary film cannot be overstated. filmmakers increasingly draw from the fragmented narrative techniques and ironic juxtapositions characteristic of postmodern art to create a unique cinematic experience. the intertextual references in quentin tarantino's films are particularly notable, where pastiche and collage elements abound. music plays an equally significant role in these films, often using old songs to evoke nostalgia or contrast with the violent action on screen.
# index: 150 target: 21
# index: 150 pred  : 24
# Train epoch:2  index:225 loss:3.2036610381 ACC:0.08 lr:0.0000333333
# index: 225 input : the federal government plays a crucial role in upholding the constitutional rights of its citizens by enacting laws that protect individuals from unfair treatment and discrimination based on race, gender, religion, national origin, disability, age, and genetic information. additionally, it ensures that these laws are enforced through various agencies such as the equal employment opportunity commission ( eeoc ) and the department of justice ( doj ). the government also oversees the legislative process by which new laws can be passed or existing ones amended in response to changes in societal values and norms.
# index: 225 target: 24
# index: 225 pred  : 17
# index: 225 input : throughout history, dogs have played significant roles in human society as companions, protectors, and workers. from the ancient egyptians who honored them with sacred status to modern - day assistance dogs, their versatility is unmatched. dogs are often celebrated for their loyalty, but they also exhibit a wide range of complex behaviors that are still being studied by animal behaviorists today. meanwhile, various breeds have been developed specifically for different environments and tasks, showcasing humans'long - standing relationship with these animals.
# index: 225 target: 8
# index: 225 pred  : 17
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:2  index:4 loss:3.1430642009 ACC:0.125 lr:0.0000333333
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 17
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 21
# Val epoch:2  index:8 loss:3.0940390527 ACC:0.125 lr:0.0000333333
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 17
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 0
# Val epoch:2  index:12 loss:3.1929897865 ACC:0.10416666666666667 lr:0.0000333333
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 21
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 17
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:3  index:75 loss:3.1156349659 ACC:0.11 lr:0.0000296296
# index: 75 input : the siberian tiger is one of the largest cats in the world, known for its distinctive orange fur with black stripes and white underbelly. these powerful predators inhabit the dense forests of eastern russia, particularly in areas like sikhote - alin. they have a rich history dating back thousands of years, deeply intertwined with the myths and legends of the local people. siberian tigers are not only majestic but also play a crucial role in their ecosystem by maintaining balance among prey species, which is why conservation efforts for this endangered subspecies are vital.
# index: 75 target: 8
# index: 75 pred  : 4
# index: 75 input : the market for luxury properties in downtown manhattan continues to rise, with many new developments featuring cutting - edge technology and sustainable materials. developers are focusing on high - end amenities such as private rooftop terraces, state - of - the - art fitness centers, and 24 / 7 concierge services. this trend is particularly strong among younger buyers looking to invest not just for the short term but also in a location that promises long - term appreciation. additionally, there has been an increase in demand for properties with solar panels and smart home systems as more individuals are concerned about energy efficiency.
# index: 75 target: 14
# index: 75 pred  : 4
# Train epoch:3  index:150 loss:3.0126920295 ACC:0.13833333333333334 lr:0.0000259259
# index: 150 input : the game started with an intense match between the two teams. the stadium was filled with spectators who were enthusiastic about the upcoming competition. each team showcased their skills in different areas of the field ; one excelled in defense while the other had a strong offense. in the second half, there was a crucial point where a player from team a scored a goal, which shifted the momentum of the game. the final whistle blew with a narrow victory for team a. this match demonstrated the essence and excitement that comes with sports.
# index: 150 target: 5
# index: 150 pred  : 21
# index: 150 input : in recent years, the rapid development of social media platforms has significantly transformed how people communicate and share information on a daily basis. these changes have led to discussions on their impact on mental health, privacy, and interpersonal relationships. moreover, the rise of e - commerce has revolutionized shopping habits by providing convenient access to a wide variety of products at competitive prices. the expansion of online marketplaces is reshaping not only consumer behavior but also traditional retail sectors. as these technological advancements continue to evolve, they are increasingly becoming central topics in discussions surrounding societal changes and challenges.
# index: 150 target: 7
# index: 150 pred  : 8
# Train epoch:3  index:225 loss:2.9959371625 ACC:0.13 lr:0.0000222222
# index: 225 input : today's technological advancements have revolutionized how we interact with computers and electronics in daily life. from smartphones that fit comfortably into our pockets to high - definition tvs displaying crisp images, technology has become an integral part of modern society. smart homes now manage temperature, security systems, and lighting through a network of interconnected devices controlled by voice commands or smartphone apps. in the realm of personal computing, laptops have evolved into sleek machines with powerful processors that allow users to perform complex tasks like video editing and 3d rendering from almost anywhere. additionally, innovations in wearable technology have led to smartwatches capable of monitoring health metrics and even making mobile payments.
# index: 225 target: 20
# index: 225 pred  : 17
# index: 225 input : the societal norms across different cultures dictate the roles people play within their communities. in many traditional societies, women are expected to take care of household chores and raise children, while men work outside the home. these roles can vary widely depending on cultural context, but they often reflect the values and expectations that a society holds for its members.
# index: 225 target: 4
# index: 225 pred  : 24
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:3  index:4 loss:2.8422745168 ACC:0.125 lr:0.0000222222
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 21
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 21
# Val epoch:3  index:8 loss:2.7238519341 ACC:0.15625 lr:0.0000222222
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 17
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 0
# Val epoch:3  index:12 loss:2.9639882942 ACC:0.16666666666666666 lr:0.0000222222
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 21
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 21
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:4  index:75 loss:2.8150397635 ACC:0.18666666666666668 lr:0.0000185185
# index: 75 input : the global financial crisis of 2008 had profound impacts on various economies worldwide. in the united states, it led to widespread unemployment and decreased consumer spending. this period saw significant changes in banking regulations, including the dodd - frank act aimed at preventing future crises. financial experts point out that factors such as subprime mortgage lending played a key role in initiating the crisis. despite the measures taken post - crisis, many economists still believe that risks remain within certain financial sectors.
# index: 75 target: 23
# index: 75 pred  : 5
# index: 75 input : the theory of relativity proposed by albert einstein changed our understanding of space and time. it suggests that the observed velocity of light in vacuum has the same value for all observers regardless of their relative motion. this revolutionary concept also implies that events can appear simultaneous to one observer but not another, dependent upon their individual velocities.
# index: 75 target: 12
# index: 75 pred  : 20
# Train epoch:4  index:150 loss:2.7996899438 ACC:0.19833333333333333 lr:0.0000148148
# index: 150 input : in this extensive forum discussion, users from around the world are sharing their experiences and tips on how to cultivate mindfulness in everyday life despite busy schedules. the posts range from personal anecdotes of successfully integrating meditation into daily routines to questions about finding time for mindful practices amidst professional demands. there is a lively debate on whether it's possible to achieve meaningful progress without dedicated time blocks, and suggestions for micro - meditations during routine activities like brushing teeth or waiting in lines.
# index: 150 target: 18
# index: 150 pred  : 10
# index: 150 input : intel has announced its latest line of processors for the upcoming year, which includes significant improvements in power efficiency and performance. these new chips will feature advanced manufacturing processes that reduce energy consumption while boosting computational capabilities. additionally, a leading expert in electronics engineering believes that these advancements could pave the way for more efficient data centers and consumer devices alike.
# index: 150 target: 20
# index: 150 pred  : 12
# Train epoch:4  index:225 loss:2.7259631422 ACC:0.2222222222222222 lr:0.0000111111
# index: 225 input : the evolution of communication technology has been rapid over the last few decades. from simple telephones that could only make voice calls to smartphones capable of browsing the internet and sending emails instantly from anywhere in the world, the changes are immense. one notable aspect is how mobile networks have expanded beyond just allowing people to call each other to offering high - speed internet services virtually everywhere. this has made it possible for remote areas to also access online resources previously only available in urban centers. the impact on education and business cannot be overstated, with students able to access vast digital libraries and entrepreneurs capable of reaching out to customers across the globe.
# index: 225 target: 9
# index: 225 pred  : 24
# index: 225 input : diabetes is a chronic condition that affects the way your body turns food into energy. most of the food you eat is broken down into sugar and released into the bloodstream. when blood sugar goes up, it signals the pancreas to release insulin. insulin acts like a key, letting blood sugar into our body's cells for use as energy. with diabetes, this system doesn't work properly leading to high blood glucose levels which can cause serious health problems over time.
# index: 225 target: 17
# index: 225 pred  : 13
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:4  index:4 loss:2.8851913214 ACC:0.125 lr:0.0000111111
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 24
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 24
# Val epoch:4  index:8 loss:2.7869106233 ACC:0.1875 lr:0.0000111111
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 17
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 0
# Val epoch:4  index:12 loss:3.0434944828 ACC:0.20833333333333334 lr:0.0000111111
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 24
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 24
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:5  index:75 loss:2.5677829965 ACC:0.3 lr:0.0000074074
# index: 75 input : the pet store was bustling with activity as people came in to purchase various supplies for their pets. among the items available were dog toys, cat treats, bird cages, and fish tanks full of colorful tropical fish. the staff at the counter helped a customer pick out suitable bedding material for her rabbit while explaining the importance of proper hygiene and nutrition for small mammals. nearby, an article in the local newspaper highlighted recent research showing how interaction with pets can improve mental health among older adults. online forums featured discussions about the best ways to train puppies using positive reinforcement techniques and the benefits of regular veterinary check - ups for maintaining pet health.
# index: 75 target: 8
# index: 75 pred  : 13
# index: 75 input : the human body is an intricate system that relies on various nutrients for optimal performance. recent studies have shown that consuming certain types of foods can significantly improve brain function and reduce the risk of diseases such as alzheimer's and parkinson's. for instance, eating fatty fish like salmon and mackerel has been linked to improved mental health due to their high content in omega - 3 fatty acids. similarly, incorporating whole grains into one ’ s diet provides a steady flow of energy throughout the day. however, it is crucial to balance these benefits with the consumption of vitamins through natural sources, as excessive intake from supplements can sometimes lead to imbalances or other issues.
# index: 75 target: 17
# index: 75 pred  : 10
# Train epoch:5  index:150 loss:2.5388609115 ACC:0.29 lr:0.0000037037
# index: 150 input : the world championship tournament has attracted athletes from over fifty countries, each vying for supremacy in the arena of soccer. as we delve into the strategies and techniques used by these elite players, it's clear that both physical prowess and mental acuity play crucial roles. beyond the sport itself, the economic implications are profound ; stadiums across nations have been rebuilt or expanded to accommodate the influx of passionate fans who travel from far and wide for the event. this global event not only fosters international camaraderie but also exposes cultural differences in athletic training and team dynamics.
# index: 150 target: 5
# index: 150 pred  : 13
# index: 150 input : the article discusses the latest advancements in heart disease treatment, focusing on new surgical techniques such as minimally invasive valve replacement and the use of robotic technology for more precise surgeries. additionally, it reviews current research on medication that can help prevent arterial plaque buildup and reduce cholesterol levels to mitigate future health risks associated with cardiovascular diseases.
# index: 150 target: 17
# index: 150 pred  : 17
# Train epoch:5  index:225 loss:2.5043719684 ACC:0.3088888888888889 lr:0.0000000000
# index: 225 input : today's discussion on the forum has been quite lively with members sharing their experiences using various gaming setups. user'gamer123'shared an in - depth guide on how to set up a dual monitor system for better gaming immersion, which received numerous upvotes and replies. another member discussed the latest trends in virtual reality games, while a third debated the merits of different game genres. the thread also featured several heated arguments over the best gaming hardware and software tools.
# index: 225 target: 19
# index: 225 pred  : 0
# index: 225 input : the concept of evolution by natural selection was proposed in the mid - 19th century by charles darwin, who presented evidence that all species of life have descended over time from common ancestors and that natural selection causes changes in populations. evolutionary theory has since become a fundamental component of modern biology. in recent decades, molecular biologists have provided strong support for evolutionary relationships between different groups of organisms through genetic evidence. this field also encompasses studies on biodiversity, including the various ecosystems found across the planet. these ecosystems vary greatly from tropical rainforests to arctic tundra and play crucial roles in maintaining global climate balance.
# index: 225 target: 12
# index: 225 pred  : 12
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:5  index:4 loss:2.6451095343 ACC:0.25 lr:0.0000000000
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 24
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 21
# Val epoch:5  index:8 loss:2.5871884823 ACC:0.28125 lr:0.0000000000
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 17
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 0
# Val epoch:5  index:12 loss:2.8141756058 ACC:0.2708333333333333 lr:0.0000000000
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 24
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 24

# %%
PATH = 'Diag_Mask5_FT_argilla_curr.pt'
if use_saved_pth and os.path.isfile(PATH):
    print( "loaded Diag_Mask5_curr.pt")
    checkpoint = torch.load(PATH)
    model.load_state_dict(checkpoint['model_state_dict'])

# %%
test_loader = DataLoader(test_dataset,
                        batch_size=1,
                        shuffle=False,
                        num_workers=num_workers,)
                        #collate_fn = collate_func_lambda)
print( "test_loader defined" )
print( len( test_loader ))
# Out:
# test_loader defined
# 50

# %%
model.eval()
print("Test")

n = 0
total_acc = 0
total_loss = 0
test_print_coef = len( test_loader ) // 10

for i, ( inputs, labels ) in enumerate( test_loader ):
    inputs = inputs.to(device)
    y_true = labels
    labels = labels.to(device)
    #labels = nn.functional.one_hot(labels.to(device).long(), num_classes = 2 ).float()

    with torch.no_grad():
        logits = model( inputs )
        y_pred = torch.argmax( logits, dim = 1 )
        # 損失の計算
        loss = criterion( logits, labels )
           
    total_loss += loss.item()
    n2 = 0
    input_sentence = []
    target_label = []
    pred_label = []
    for input_id, label, pred in zip( inputs, y_true, y_pred ):
        if n2 < 2 and ( i % test_print_coef == test_print_coef -1 ) :
            input_s = tokenizer.decode( input_id, skip_special_tokens = True )
            input_sentence.append( input_s )
            target_label.append( label )
            pred_label.append( pred.item() )
                
        n2 += 1

    n3 += 1
    accuracy = accuracy_score(y_true, y_pred.detach().cpu() )
    total_acc += accuracy

print(f"index:{i+1} loss: {total_loss / i}")        
print(f"index:{i+1}  ACC: {total_acc / i}")
# Out:
# Test
# index:50 loss: 2.5006457012222736
# index:50  ACC: 0.32653061224489793
