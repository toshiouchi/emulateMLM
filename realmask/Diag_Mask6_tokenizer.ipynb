# %%
# -*- coding: utf-8 -*-

#
# Pytorchで用いるDatasetの定義
#

#!pip install janome

# sysモジュールをインポート
import sys

import matplotlib.pyplot as plt
import pandas as pd
import torch
import random
from torch import nn, Tensor
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import numpy as np
import math
import janome
from janome.tokenizer import Tokenizer
from collections import Counter
from torch.utils.data.sampler import SubsetRandomSampler
import time
import levenshtein
import pickle
from timm.scheduler import CosineLRScheduler
from nltk import bleu_score
#from tqdm import tqdm
from tqdm.notebook import tqdm
from torch import autocast, GradScaler
from typing import Sequence, Dict, Tuple, Union
from transformers import  get_linear_schedule_with_warmup
from transformers import  CLIPVisionModel, get_linear_schedule_with_warmup, BertTokenizer

#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device( "cpu")
use_amp = False

# %%
path = "../../python_image_recognition-main/6_img_captioning/6_7_ImgCap_pre_trained_Feature_extractor/CLIP_ENCODER/models--google-bert--bert-large-uncased/snapshots/6da4b6a26a1877e173fca3225479512db81a5e5b"
tokenizer = BertTokenizer.from_pretrained(pretrained_model_name_or_path = path)

vocab_size = len(tokenizer)
print(vocab_size)
# Out:
# 30522

# %%
'''
BERT tokenizers utilize specific special tokens for various purposes, primarily to structure input sequences for the BERT model. These tokens are typically added automatically when processing text with a BERT tokenizer, especially when using methods like encode_plus or __call__ from the Hugging Face Transformers library.
The most common special tokens in a BERT tokenizer are:
[CLS] (Classifier Token):
This token is placed at the beginning of the input sequence. Its corresponding final hidden state is used as the aggregate representation of the entire sequence for classification tasks.
[SEP] (Separator Token):
This token is used to separate different segments within an input sequence, such as separating a question from an answer in question-answering tasks, or to mark the end of a single sentence.
[PAD] (Padding Token):
This token is used to pad sequences to a uniform length, ensuring that all sequences in a batch have the same dimensions for efficient processing by the model.
[UNK] (Unknown Token):
This token represents words or subwords that are not found in the tokenizer's vocabulary.
[MASK] (Mask Token):
This token is used during the pre-training phase of BERT for the Masked Language Model (MLM) objective, where a percentage of input tokens are randomly replaced with [MASK], and the model predicts the original token.
When you tokenize text and request the return of special tokens, these tokens will be included in the output token IDs and can be viewed by decoding the token IDs back to strings. For example, if you tokenize a sentence like "Hello world," the output might look something like ['[CLS]', 'Hello', 'world', '[SEP]'] when decoded.
'''
# Out:
# '\nBERT tokenizers utilize specific special tokens for various purposes, primarily to structure input sequences for the BERT model. These tokens are typically added automatically when processing text with a BERT tokenizer, especially when using methods like encode_plus or __call__ from the Hugging Face Transformers library.\nThe most common special tokens in a BERT tokenizer are:\n[CLS] (Classifier Token):\nThis token is placed at the beginning of the input sequence. Its corresponding final hidden state is used as the aggregate representation of the entire sequence for classification tasks.\n[SEP] (Separator Token):\nThis token is used to separate different segments within an input sequence, such as separating a question from an answer in question-answering tasks, or to mark the end of a single sentence.\n[PAD] (Padding Token):\nThis token is used to pad sequences to a uniform length, ensuring that all sequences in a batch have the same dimensions for efficient processing by the model.\n[UNK] (Unknown Token):\nThis token represents words or subwords that are not found in the tokenizer\'s vocabulary.\n[MASK] (Mask Token):\nThis token is used during the pre-training phase of BERT for the Masked Language Model (MLM) objective, where a percentage of input tokens are randomly replaced with [MASK], and the model predicts the original token.\nWhen you tokenize text and request the return of special tokens, these tokens will be included in the output token IDs and can be viewed by decoding the token IDs back to strings. For example, if you tokenize a sentence like "Hello world," the output might look something like [\'[CLS]\', \'Hello\', \'world\', \'[SEP]\'] when decoded.\n'

# %%
class SequenceDataset(Dataset):
    ''' ミニバッチデータを作成するクラス
        torch.utils.data.Datasetクラスを継承し，
        以下の関数を定義する
        __len__: 総サンプル数を出力する関数
        __getitem__: 1サンプルのデータを出力する関数
    feat_scp:  特徴量リストファイル
    label_scp: ラベルファイル
    feat_mean: 特徴量の平均値ベクトル
    feat_std:  特徴量の次元毎の標準偏差を並べたベクトル 
    pad_index: バッチ化の際にフレーム数を合わせる
               ためにpaddingする整数値
    splice:    前後(splice)フレームを特徴量を結合する
               splice=1とすると，前後1フレーム分結合
               するので次元数は3倍になる．
               splice=0の場合は何もしない
    '''
    def __init__(self, 
                 filename,
                 tokenizer,
                 mask_prob = 0.15 * 0.8,
                 arbi_prob = 0.15 * 0.1,
                 ):

        self.mask_token_id = tokenizer.mask_token_id
        self.pad_token_id = tokenizer.pad_token_id
        #print( "self.mask_value:", self.mask_value)
        self.max_idx_en = len( tokenizer )
        #self.device = device
        self.mask_prob = mask_prob
        self.arbi_prob = arbi_prob
        # 元のtoken の mask_prob = 15%を置き換える。

        with open(filename, mode='r', encoding="utf-8") as file_f:
            for n, line in enumerate( file_f ):
                pass
        
        file_max = n
        
        # 特徴量リスト，ラベルを1行ずつ
        # 読み込みながら情報を取得する
        self.input_ids = []
        self.input_lens = []
        self.target_ids = []
        self.target_lens = []
        self.num_data = 0
        with open(filename, mode='r', encoding="utf-8") as file_f:
            for n, line in enumerate( file_f ):
                if n % 100000 == 0:
                    print( "n:", n )
                if n > file_max // 50:
                    break
                en1 = torch.tensor( tokenizer.encode(line), dtype=torch.int, requires_grad = False  )
                #print( "en1:", en1 )
                self.input_ids.append( en1 )
                self.input_lens.append( len( en1 ) )
                en2 = self.masking( en1 )
                self.target_ids.append( en2 )
                self.target_lens.append( len( en2 ) )
                #self.target_ids.append( en1 )
                #self.target_lens.append( len( en1 ) )

                self.num_data += 1

    def __len__(self):
        ''' 学習データの総サンプル数を返す関数
        本実装では発話単位でバッチを作成するため，
        総サンプル数=発話数である．
        '''
        #return self.num_data // 100
        return self.num_data


    def __getitem__(self, idx):
        ''' サンプルデータを返す関数
        本実装では発話単位でバッチを作成するため，
        idx=発話番号である．
        '''
        # 特徴量系列のフレーム数
        input_len = self.input_lens[idx]
        # ラベルの長さ
        target_len = self.target_lens[idx]

        # ラベル
        input = self.input_ids[idx]

        # 発話ID
        target = self.target_ids[idx]

        # 特徴量，ラベル，フレーム数，
        # ラベル長，発話IDを返す
        return (input, target, input_len, target_len )
    
    def masking(self, input_x: torch.Tensor) -> torch.Tensor:

        masks = torch.zeros( input_x.shape[0], device = input_x.device, dtype=torch.bool )
        #pad_length = torch.sum( torch.eq( input_x, self.pad_token_id ).int() )
        pad_length = 0
        #print( input_ids.shape )
        masks[1:-1-pad_length] = torch.rand( (input_x.shape[0] - 2 - pad_length), device=input_x.device ) < self.mask_prob
        #print( masks )
        #mask = (torch.rand( input_ids.shape) < mask_prob )
        masked_input_ids = input_x.clone()
        masked_input_ids[masks] = self.mask_token_id
        while True:
            arbi1 = torch.zeros( input_x.shape[0], device = input_x.device, dtype=torch.bool )
            arbi1[1:-1-pad_length] = torch.rand( ( input_x.shape[0] - 2 - pad_length), device=input_x.device ) < self.arbi_prob
            num_arbi1 = torch.sum( torch.eq( arbi1, True ).int() )
            arbi2 = [ a if m == False else False for a, m in zip( arbi1, masks )]
            num_arbi2 = torch.sum( torch.eq( torch.tensor( arbi2 ), True ).int() )
            if num_arbi1 == num_arbi2:
                break
        #print( num_arbi2 / len( masked_input_ids))
        for i, arbi in enumerate( arbi2 ):
            if arbi == True:
                masked_input_ids[i] = torch.randint( 0, len( tokenizer), size=(1,) )
        
        
        #mlm_labels = input_x.clone()
        #mlm_labels[~masks] = -100
        
        return masked_input_ids

# %%
def collate_func(batch: Sequence[Tuple[Union[torch.Tensor, str]]], pad_index ):
    inputs0, targets0, input_lens, target_lens = zip(*batch)

    inputs = []
    targets = []
    for input1, target1, input_len, target_len in zip( inputs0, targets0, input_lens, target_lens ):
        pad_len = max( input_lens ) - input_len 
        input2= F.pad( input1, (0, pad_len), mode='constant', value = pad_index)
        inputs.append( input2 )
        pad_len = max( target_lens ) - target_len
        target2= F.pad( target1, (0, pad_len), mode='constant', value = pad_index)
        targets.append( target2 )

    
    inputs = torch.stack( inputs, dim = 0 )
    targets = torch.stack( targets, dim = 0 )
    input_lens = torch.tensor( input_lens )
    target_lens = torch.tensor( target_lens )
    
    return inputs, targets, input_lens, target_lens

# %%
collate_func_lambda = lambda x: collate_func(x, tokenizer.pad_token_id)

# %%
train_dataset = SequenceDataset( "train.txt", tokenizer )
print( "train dataset defiened, len( train_dataset):", len( train_dataset) )

# 訓練データのDataLoaderを呼び出す
# 訓練データはシャッフルして用いる
#  (num_workerは大きい程処理が速くなりますが，
#   PCに負担が出ます．PCのスペックに応じて
#   設定してください)
# Out:
# n: 0
# train dataset defiened, len( train_dataset): 35439

# %%
val_dataset = SequenceDataset( "val.txt", tokenizer  )
print( "val dataset defiened, len( val_dataset):", len( val_dataset ) )
# Out:
# n: 0
# val dataset defiened, len( val_dataset): 3938

# %%
batch_size = 16

num_workers = 0 if device == torch.device( 'cpu' ) else 8

train_loader = DataLoader(train_dataset,
                            batch_size=batch_size,
                            shuffle=True,
                            num_workers=num_workers,
                            pin_memory=True,
                            collate_fn = collate_func_lambda)
print( "train_loader defiend" )
# 開発データのDataLoaderを呼び出す
# 開発データはデータはシャッフルしない
val_loader = DataLoader(val_dataset,
                        batch_size=batch_size,
                        shuffle=False,
                        num_workers=num_workers,
                        collate_fn = collate_func_lambda)
print( "val_loader defined" )
print( len( train_loader ))
print( len( val_loader ))

text, target, text_len, target_len = next(iter(train_loader))
#print(text[0], target[0], text_len[0],target_len[0], sep="\n")
print( "text:", text )
#print( "text_len:", text_len )
# Out:
# train_loader defiend
# val_loader defined
# 2215
# 247
# text: tensor([[  101,  2178,  2391,  ...,     0,     0,     0],
#         [  101,  1997,  2607,  ...,     0,     0,     0],
#         [  101,  2000, 16519,  ...,     0,     0,     0],
#         ...,
#         [  101, 15847,  1010,  ...,     0,     0,     0],
#         [  101,  2612,  2009,  ...,     0,     0,     0],
#         [  101,  2009,  2036,  ...,     0,     0,     0]], dtype=torch.int32)

# %%
n_word = 0
n_mask = 0
n_arbi = 0
n = 0
for text, target, _, _ in val_loader:
    for te, ta in zip( text, target ):
        n += 1
        #reference0 = []
        #for m in te:
        #    reference0.append( token_list_en[m.item()])
        #    if m == idx_list_en['<end>']:
        #        break
        ##print( "n:", n, "input :", ' '.join(reference ) )
        #reference0 = tokenizer.decode( te)
        #reference0 = tokenizer.tokenize( reference0 )
        
        #reference1 = []
        #for m in ta:
        #    reference1.append( token_list_en[m.item()])
        #    if m == idx_list_en['<end>']:
        #        break
        ##print( "n:", n, "target:", ' '.join(reference ) )
        #reference1 = tokenizer.decode( ta)
        #reference1 = tokenizer.tokenize( reference1 )
        
        for ref0, ref1 in zip( te, ta ):
            if ref0 != tokenizer.pad_token_id and ref1 != tokenizer.pad_token_id:
                n_word += 1
                if ref0 != ref1:
                    if ref1 == tokenizer.mask_token_id:
                        n_mask += 1    
                    if ref1 != tokenizer.mask_token_id:
                        n_arbi += 1
                        #print(" ref0:", ref0, "ref1:",ref1 )
                        #print( "ref0:", ref0, "ref1:", ref1 )
print( "n:", n )
print( "mask ratio:", n_mask / n_word )
print( "arbi ratio:", n_arbi / n_word )
print( "input: ", reference0 )
print( "target:", reference1 )
# Out:
# n: 3938
# mask ratio: 0.11199696279422931
# arbi ratio: 0.012000264104849626
# input:  ['[CLS]', 'these', 'issues', 'will', 'be', 'discussed', 'with', 'israel', 'and', 'considered', 'by', 'the', 'council', 'in', 'coming', 'weeks', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]']
# target: ['[CLS]', 'these', 'issues', 'will', 'be', 'discussed', 'with', 'israel', 'and', 'considered', 'by', 'the', 'council', 'in', 'coming', 'weeks', '.', '[SEP]', '[PAD]', '[PAD]', '[PAD]']

# %%
class PositionalEmbedding(nn.Module):
    '''
    位置埋め込み （Positional embedding）
    dim_embedding: 埋込み次元
    max_len      : 入力の最大系列長
    '''
    def __init__(self, dim_embedding: int, max_len: int=2048):
        super().__init__()

        self.pos_emb = nn.Embedding(max_len, dim_embedding)

    '''
    位置エンコーディングの順伝播
    x: 位置エンコーディングを埋め込む対象のテンソル,
       [バッチサイズ, 系列長, 埋め込み次元]
    '''
    def forward(self, x: torch.Tensor):
        seq = x.shape[1]
        positions = torch.arange(start=0, end=seq, step=1, device=x.device).to(torch.long)
        positions = self.pos_emb(positions)[:seq,:]
        
        return positions

# %%
class TransformerEncoder(nn.Module):
    '''
    CaptioningTransformerのコンストラクタ
    dim_embedding  : 埋め込み次元
    dim_feedforward: FNNの中間特徴次元
    num_heads      : マルチヘッドアテンションのヘッド数
    num_layers     : Transformerデコーダ層の数
    vocab_size     : 辞書の次元
    pad_index      : PADのID
    dropout        : ドロップアウト確率
    '''
    def __init__(self, vocab_size: int, dim_embedding: int, dim_feedforward: int,
                 num_heads: int, num_layers: int ):
        super().__init__()

        self.encoder_layers = nn.ModuleList([
            nn.TransformerEncoderLayer(d_model=dim_embedding, nhead=num_heads, batch_first=True, activation='gelu', norm_first=True)
            for _ in range(num_layers)
        ])

    ''' CaptioningTransformerの順伝播処理
    features: 画像特徴量 [バッチサイズ, 埋め込み次元]
    captions: 正解キャプション [バッチサイズ, 系列長]

    '''
    def forward(self, src: torch.Tensor, src_mask: torch.Tensor=None, \
                src_key_padding_mask: torch.Tensor=None ):


        for layer in self.encoder_layers:
            src = layer( src, src_mask = src_mask, src_key_padding_mask = src_key_padding_mask,\
                        #is_causal= True )
                        is_causal= False )

        return src

# %%
class Transformer(nn.Module):
    def __init__(self, dim_embedding: int, dim_feedforward: int,
                 num_heads: int, num_layers: int, vocab_size: int,
                 pad_index: int, dropout: float=0.5, us_rate: float=2.0 ):
        super().__init__()

        # 単語埋め込み
        self.embed = nn.Embedding(
            vocab_size, dim_embedding, padding_idx=pad_index)

        # 位置エンコーディング
        self.pos_emb = PositionalEmbedding(dim_embedding)        
        
        # dropout
        self.dropout = nn.Dropout( dropout )
        
        self.encoder = TransformerEncoder(vocab_size, dim_embedding, dim_feedforward, num_heads, num_layers)

        # 単語出力分布計算
        self.ln = nn.LayerNorm( dim_embedding )
        self.linear = nn.Linear(dim_embedding, vocab_size)

        self.pad_index = pad_index
        self.num_heads = num_heads
        
    ''' CaptioningTransformerの順伝播処理
    features: 画像特徴量 [バッチサイズ, 埋め込み次元]
    captions: 正解キャプション [バッチサイズ, 系列長]

    '''
    def forward(self, text):

        device = text.device

        src = self.embed( text )
        
        src += self.pos_emb( src )
        src = self.dropout( src )
        src_key_padding_mask = torch.eq(text, self.pad_index)

        #ones = torch.ones( text.size(1) ).to( device = device )
        #src_mask = torch.diag( ones ).bool()
        src_mask = None

        preds = self.encoder( src, src_mask, src_key_padding_mask )
        
        preds = self.ln( preds )
        logits = self.linear( preds )

        return logits

# %%
print( device )
# Out:
# cpu

# %%
epoch_num = 10
model = Transformer(768, 3072, 12, 6, vocab_size, tokenizer.pad_token_id ).to(device)

input_texts = torch.randint( 0, vocab_size, size=(16, 45))
outputs_logits = model( input_texts )

#criterion = nn.CrossEntropyLoss(ignore_index = tokenizer.pad_token_id )
criterion = nn.CrossEntropyLoss( )
#criterion = nn.CTCLoss(blank=idx_list_en['<blank>'], reduction='mean', zero_infinity = True )
#optimizer = optim.Adam(model.parameters(), lr=0.0001 )
#optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay = 0.005 )
#optimizer = optim.AdamW(model.parameters(), lr=0.0001, weight_decay = 0.001 )
#optimizer = optim.Adadelta(model.parameters(), lr = 1.0, weight_decay = 0.0 )
#optimizer = optim.Adadelta(model.parameters(),lr=1.0,rho=0.95,eps=1e-8,weight_decay=0.0)
#optimizer = optim.AdamW( model.parameters(), lr = 1e-4 )
lr = 1e-4
#lr = 1e-3
optimizer = optim.AdamW( model.parameters(), lr = lr )
# 全ステップ数
num_global_steps = len( train_loader ) * epoch_num
print( "num_global_steps:", num_global_steps )
num_warmup_steps = num_global_steps * 0.1
print( "num_warmup_steps:", num_warmup_steps )
#スケジューラーの定義
scheduler = get_linear_schedule_with_warmup( optimizer, num_warmup_steps, num_global_steps )
eps = 1e-4
# Out:
# num_global_steps: 22150
# num_warmup_steps: 2215.0

# %%
# WarmupとCosine Decayを行うスケジューラを利用
#scheduler = CosineLRScheduler(
#    optimizer, t_initial=epoch_num, lr_min=1e-1,
#    warmup_t=5, warmup_lr_init=5e-2, warmup_prefix=True)

#tr_print_coef = 64000
#tr_save_coef = 1000
#val_print_coef = 240
len_tr_loader = len( train_loader )
len_val_loader = len( val_loader )
tr_print_coef = len_tr_loader // 10
tr_save_coef = len_tr_loader // 100
#tr_print_coef = len_val_loader // 10
#tr_save_coef = len_val_loader // 10
val_print_coef = len_val_loader // 3
print( "len( train_loader ):", len_tr_loader )
print( "len( val_loader ):", len_val_loader )
print( "tr_print_coef:", tr_print_coef )
print( "tr_save_coef:", tr_save_coef )
print( "val_print_coef:", val_print_coef )
#tr_print_coef = 1
#tr_save_coef = 1
#val_print_coef = 1
#train_length = len(train_loader)
#train_int = train_length // tr_print_coef
#print( train_int )
#print( train_length )
#val_length = len(val_loader)
#val_int = val_length // val_print_coef
#print( val_int )
#print( val_length )

history = {"len_tr_loader":[],"len_val_loader":[], "train_loss":[], "val_loss": [], "train_wer": [], "val_wer": [], "train_bleu": [], "val_bleu": [] }
history["len_tr_loader"].append( len_tr_loader )
history["len_val_loader"].append( len_val_loader )
with open("Diag_Mask6.pkl", "wb") as f:
    pickle.dump( history, f )      
n = 0
train_loss = 0
val_loss = 0


# 学習率の減衰やEarly stoppingの
# 判定を開始するエポック数
# (= 最低限このエポックまではどれだけ
# validation結果が悪くても学習を続ける)
lr_decay_start_epoch = 5

# 学習率を減衰する割合
# (減衰後学習率 <- 現在の学習率*lr_decay_factor)
# 1.0以上なら，減衰させない
lr_decay_factor = 0.5

# Early stoppingの閾値
# 最低損失値を更新しない場合が
# 何エポック続けば学習を打ち切るか
early_stop_threshold = 3

# 最も低い損失値，
# そのときのモデルとエポック数を記憶しておく
best_loss = -1
best_model = None
best_epoch = 0

# Early stoppingフラグ．Trueになると学習を打ち切る
early_stop_flag = False
# Early stopping判定用(損失値の最低値が
# 更新されないエポックが何回続いているか)のカウンタ
counter_for_early_stop = 0

fn = bleu_score.SmoothingFunction().method7

# AMP用のスケーラー
scaler = GradScaler(enabled=use_amp)

for epoch in range(epoch_num):
    # early stopフラグが立っている場合は，
    # 学習を打ち切る
    if early_stop_flag:
        print('    Early stopping.'\
            ' (early_stop_threshold = %d)' \
            % (early_stop_threshold))
        #log_file.write('\n    Early stopping.'\
        #        ' (early_stop_threshold = %d)' \
        #        % (early_stop_threshold))
        break

    with tqdm(train_loader) as pbar:
    #with tqdm(val_loader) as pbar:
        pbar.set_description(f'[Train エポック {epoch + 1}]')
    
        model.train()
        #scheduler.step(epoch)
        #print( "Train")
        train_loss = 0
        mean_error = 0
        mean_bleu = 0
        n3 = 0
        for i, ( text, target, text_len, target_len ) in enumerate( pbar ):
            optimizer.zero_grad()
            text = text.to(device)
            target = target.to(device).long()
            
            with autocast(str(device),enabled=use_amp):
                outputs = model( text )
                # 損失の計算
                loss = criterion(outputs.transpose(1,2) + eps, target)

            preds = torch.argmax( outputs, dim = 2 )
            #print( "preds:",preds[0])
            #print( "text:",text[0])
            #print( "target:", target[0] )
                
            # 誤差逆伝播
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            clip_grad_threshold = 5.0
            torch.nn.utils.clip_grad_norm_(\
                    model.parameters(),
                    clip_grad_threshold)
            # オプティマイザにより，パラメータを更新する
            scaler.step(optimizer)
            scaler.update()            
            
            scheduler.step()
            
            #lr = optimizer.param_groups[0]['lr']
            #print( "lr:", lr )

            total_error = 0
            total_token_length = 0
            total_bleu = 0
            n2 = 0       
            hypo_sentence = []
            ref_sentence = []
            for hypo_id, caption in zip( preds, target ):
                hypo = tokenizer.decode( hypo_id, skip_special_tokens = True )
                #print( "hypo_id:", hypo_id )
                hypo_list = tokenizer.tokenize( hypo )
                reference = tokenizer.decode( caption, skip_special_tokens = True )
                ref_list =  tokenizer.tokenize( reference )
                #print( "hypo:", hypo )
                #print( "hypo_list:", hypo_list )
                #print( "reference:", reference )
                #print( "ref_list:", ref_list )
                
                # 認識誤りを計算
                #print( "hypo_list:", hypo_list)
                #print( "ref_list:", ref_list )
                (error, substitute, 
                    delete, insert, ref_length) = \
                    levenshtein.calculate_error(hypo_list,ref_list)

                #print( "error:", error, "ref_length:", ref_length )
                bleu = bleu_score.sentence_bleu( [reference], hypo, smoothing_function=fn )
        
                total_bleu += bleu
    
                total_error += error
                total_token_length += ref_length

                #if n2 < 2 and ( i % tr_print_coef == tr_print_coef -1  or  i == len( train_loader ) -1 ) :
                if n2 < 2 and ( i % tr_print_coef == tr_print_coef -1 ) :
                    hypo_sentence.append( hypo )
                    ref_sentence.append( reference )
                    
                n2 += 1
                
            train_loss += loss.item()
            history["train_loss"].append( loss.item() )
            history["train_wer"].append( total_error/total_token_length * 100)
            mean_error += total_error/total_token_length * 100
            history["train_bleu"].append( total_bleu/ n2 * 100 )
            mean_bleu += total_bleu/ n2 * 100
            n3 += 1
            if i % tr_save_coef == tr_save_coef - 1:
                with open("Diag_Mask6.pkl", "wb") as f:
                    pickle.dump( history, f )            
            if i % tr_print_coef == tr_print_coef - 1:
                lr = optimizer.param_groups[0]['lr']
                #print(f"Train epoch:{epoch+1}  index:{i+1} loss:{train_loss/n3:.10f} WER:{mean_error / n3:.10f} BLEU:{mean_bleu / n3:.10f } lr:{lr}")
                print(f"Train epoch:{epoch+1}  index:{i+1}  loss:{train_loss/n3:.10f}   WER:{mean_error / n3:.10f} BLEU:{mean_bleu / n3 } lr:{lr:.10f}")
            #if i == len( train_loader ) - 1:
            for (hypo_s, refe_s ) in zip( hypo_sentence, ref_sentence ):
                print( "index:", i+1, "target:", refe_s)
                print( "index:", i+1, "hypo  :", hypo_s )
            pbar.set_postfix({
                    'loss': train_loss / n3,
                    'WER': mean_error / n3,
                    'BLEU': mean_bleu / n3
            })

    with tqdm(val_loader) as pbar:
        pbar.set_description(f'[検証]')
        model.eval()
        #for i, ( text, target, text_len, target_len ) in enumerate(val_loader):
        val_loss = 0
        mean_error = 0
        mean_bleu = 0
        n3 = 0
        for i, ( text, target, text_len, target_len ) in enumerate( pbar ):
            text = text.to(device)
            target = target.to(device).long()

            with torch.no_grad():
                outputs = model(text)
                preds = torch.argmax( outputs, dim = 2 )
                loss = criterion( outputs.transpose(1, 2) + eps, target )
           
            total_error = 0
            total_token_length = 0
            total_bleu = 0
            n2 = 0
            hypo_sentence = []
            ref_sentence = []
            for hypo_id, caption in zip( preds, target ):
                #hypo = tokenizer.decode( hypo_id )
                hypo = tokenizer.decode( hypo_id, skip_special_tokens = True )
                #print( "hypo_id:", hypo_id )
                hypo_list = tokenizer.tokenize( hypo )
                #reference = tokenizer.decode( caption )
                reference = tokenizer.decode( caption, skip_special_tokens = True )
                ref_list =  tokenizer.tokenize( reference )
                
                # 認識誤りを計算
                (error, substitute, 
                    delete, insert, ref_length) = \
                    levenshtein.calculate_error(hypo_list,ref_list)

                bleu = bleu_score.sentence_bleu( [reference], hypo, smoothing_function=fn )
        
                total_bleu += bleu
            
                total_error += error
                total_token_length += ref_length

                if n2 < 2 and ( i % val_print_coef == val_print_coef -1 ) :
                    hypo_sentence.append( hypo )
                    ref_sentence.append( reference )
                    
                n2 += 1
        
            val_loss += loss.item()
            history["val_loss"].append( loss.item() )
            history["val_wer"].append( total_error/total_token_length * 100)
            mean_error += total_error/total_token_length * 100
            history["val_bleu"].append( total_bleu / n2 * 100 )
            mean_bleu += total_bleu / n2 * 100
            n3 += 1
            if i % val_print_coef == val_print_coef - 1:
                lr = optimizer.param_groups[0]['lr']
                print(f"Val epoch:{epoch+1}  index:{i+1}  loss:{val_loss/n3:.10f}   WER:{mean_error / n3:.10f} BLEU:{mean_bleu / n3 } lr:{lr:.10f}")
                PATH = './Diag_Mask6_curr.pt'
                torch.save({'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'loss': loss,},
                     PATH)
                with open("Diag_Mask6.pkl", "wb") as f:
                    pickle.dump( history, f )
            for (hypo_s, refe_s ) in zip( hypo_sentence, ref_sentence ):
                print( "index:", i+1, "target:", refe_s)
                print( "index:", i+1, "hypo  :", hypo_s )
            pbar.set_postfix({
                    'loss': val_loss / n3,
                    'WER': mean_error/ n3,
                    'BLEU': mean_bleu / n3
                })

    epoch_loss = val_loss/n3
    if epoch == 0 or best_loss > epoch_loss:
        # 損失値が最低値を更新した場合は，
        # その時のモデルを保存する
        best_loss = epoch_loss
        torch.save(model.state_dict(), 
                    './best_model_Mask6.pt')
        best_epoch = epoch
        # Early stopping判定用の
        # カウンタをリセットする
        counter_for_early_stop = 0
    else:
        # 最低値を更新しておらず，
        if epoch+1 >= lr_decay_start_epoch:
            # かつlr_decay_start_epoch以上の
            # エポックに達している場合
            if counter_for_early_stop+1 \
                    >= early_stop_threshold:
                # 更新していないエポックが，
                # 閾値回数以上続いている場合，
                # Early stopping フラグを立てる
                early_stop_flag = True
            else:
                # Early stopping条件に
                # 達していない場合は
                # 学習率を減衰させて学習続行
                if lr_decay_factor < 1.0:
                    for i, param_group \
                            in enumerate(\
                            optimizer.param_groups):
                        if i == 0:
                            lr = param_group['lr']
                            dlr = lr_decay_factor \
                                * lr
                            print('    (Decay '\
                                'learning rate:'\
                                ' %f -> %f)' \
                                % (lr, dlr))
                        param_group['lr'] = dlr
                # Early stopping判定用の
                # カウンタを増やす
                counter_for_early_stop += 1
#torch.cuda.synchronize()
# Out:
# len( train_loader ): 2215
# len( val_loader ): 247
# tr_print_coef: 221
# tr_save_coef: 22
# val_print_coef: 82
#   0%|          | 0/2215 [00:00<?, ?it/s]
# Train epoch:1  index:221  loss:7.3673456848   WER:174.0606712955 BLEU:7.681044542170696 lr:0.0000099774
# index: 221 target: this report would undermine rather improve race.
# index: 221 hypo  :
# index: 221 target: there have been times within parliament when on social security were actually quite awkward.
# index: 221 hypo  :
# Train epoch:1  index:442  loss:5.4434230433   WER:133.9404583211 BLEU:3.853063383159605 lr:0.0000199549
# index: 442 target: mr president - in - of the council, firstly i would like to thank the - in - office of the council for their high level presence this house and for their positive attitude.
# index: 442 hypo  : in the, to the of the and.
# index: 442 target: we look forward a fruitful dialogue with you on this.
# index: 442 hypo  : to.
# Train epoch:1  index:663  loss:4.3972555045   WER:113.3481861828 BLEU:3.186496846086864 lr:0.0000299323
# index: 663 target: calls for design improvements in hull construction, especially double - hulled vessels, are sensible but take time to be implemented throughout the fleet.
# index: 663 hypo  : for in, -, to be the.
# index: 663 target: that be more productive and i do not like seeing the committee agendas that are over being again and again because of this kind of show - piece.
# index: 663 hypo  : that and i the that are and of this of -.
# Train epoch:1  index:884  loss:3.7709729766   WER:100.0588255880 BLEU:4.402804548030643 lr:0.0000399097
# index: 884 target: only, as mrs cechiold pointed out, in the end it does not fully achieve the legal certainty the council because various shortcomings have not been dealt with. they relate to minimum rules we are seeking to establish, the rules to a punish offence and in particular the application of the same criminal law norms all member including those that have not yet introduced the euro but where it could theoretically be counterfeited.
# index: 884 hypo  : , as, in the it not the the have not with. to the we are to, the to a and in the of the in all, that have not the but it be.
# index: 884 target: am sure that the situation will be just the same and, as far am concerned, in my current position i shall ensure that the contributions of your two representatives are listened to and respected throughout these negotiations.
# index: 884 hypo  : i that the will be the and, as as i, in, i that the of are to and.
# Train epoch:1  index:1105  loss:3.3376858550   WER:90.5652596170 BLEU:7.07093608276041 lr:0.0000498871
# index: 1105 target: i am aware that there may be views about nato s action the legitimacy of that action.
# index: 1105 hypo  : i am that there be about's and the of that.
# index: 1105 target: i think we have tabled sound proposal.
# index: 1105 hypo  : i we have a.
# Train epoch:1  index:1326  loss:3.0181856701   WER:83.2367517894 BLEU:10.72381561997332 lr:0.0000598646
# index: 1326 target: ( parliament adopted resolution )
# index: 1326 hypo  : ( parliament the )
# index: 1326 target: so that is quite some way off the shutdown date had mind.
# index: 1326 hypo  : so that is some way the we.
# Train epoch:1  index:1547  loss:2.7618950056   WER:77.2869741415 BLEU:15.009519801028677 lr:0.0000698420
# index: 1547 target: in the context of global and cultural current, europeanyl needs instruments that will allow it to strengthen its links communication channels with neighbouring regions particularly eastern and southern europe.
# index: 1547 hypo  : in the ofisation and which the situation, the european union that will it to its and with, particularly in and europe.
# index: 1547 target: i that the commission relying have been more pro - active on this score and could have also provided us with the which it had promised to give us and which we had requested.
# index: 1547 hypo  : i think that the commission could have been more - on this and could have also us with the which it had to give us and which we had.
# Train epoch:1  index:1768  loss:2.5512621833   WER:72.2661316576 BLEU:19.723484775783415 lr:0.0000798194
# index: 1768 target: cyprus cyprus satisfies the copenhagen criteria in passing glancing it should be said that there has been no progress in resolving the political partition of the island.
# index: 1768 hypo  : - the. in, it should be said that there has been no in the political of the.
# index: 1768 target: we need both a starting point and a final goal if we are to reverse the upward pollution.
# index: 1768 hypo  : we need both a point and a if we are to the in.
# Train epoch:1  index:1989  loss:2.3692916828   WER:68.0479949150 BLEU:24.210902458286622 lr:0.0000897968
# index: 1989 target: the fruits of ain intellect port science, which are intangible, are of inestimable. therefore, the european community should be more energetic in providing practical encouragement, not just through upholding patents but concessions and other forms support for scientists who areving the knowledge and experience they have acquired wrexham to give future something interceptions than that which they have today.
# index: 1989 hypo  : the of the and, which are, are of in importance. therefore, the european community should be more in, not just throughing but through and other of support for who are, through the and they have, to give future something better than that which they have today.
# index: 1989 target: and just what is mr cfsp doing?
# index: 1989 hypo  : and just what is mr doing?
# Train epoch:1  index:2210  loss:2.2154909961   WER:64.4108790512 BLEU:28.425782787752322 lr:0.0000997743
# index: 2210 target: the champions advantage the libertarian ideology never missik chance series novi demands more ludicrous the next, wrapped up sentiments.
# index: 2210 hypo  : the of the the to a whole of demands, each more than the next, all up in proper.
# index: 2210 target: this is also the caserong austria where otto von habsburg was required to deny his own identity and renounce rights belonging to him and members of his family to austria.
# index: 2210 hypo  : this is also the case for austria where was to his own and rights to and to members of his to austria.
#   0%|          | 0/247 [00:00<?, ?it/s]
# Val epoch:1  index:82  loss:2.1155501575   WER:43.8017875741 BLEU:35.31954036322815 lr:0.0001000000
# index: 82 target: on the one disguise wantlargement while, on the hand, they are not prepared pay for it.
# index: 82 hypo  : on the one they wantgement, on the, are not to for it.
# index: 82 target: they cannot have it both ways.
# index: 82 hypo  : they have it.
# Val epoch:1  index:164  loss:2.0926694303   WER:43.7337955490 BLEU:34.936491130466834 lr:0.0001000000
# index: 164 target: according to the information we have received from luxembourg authorities, the centre has been created within context of a cooperation between council of europe and the luxembourg authorities.
# index: 164 hypo  : according to the we have from the, the has been the of a cooperation agreement the of europe and the.
# index: 164 target: of course commission takes a favourable als of this because, given the importance of the european cultural network, the centre can make a positive contribution to improving the link between cultural heritage and cultural tourism on a european scale.
# index: 164 hypo  : of course, the commission a view of this, given the importance of the european, the can a to the and on a european.
# Val epoch:1  index:246  loss:2.0621861239   WER:43.6835924502 BLEU:35.021223694953896 lr:0.0001000000
# index: 246 target: the european union participated negotiations on economic issues before and during the minister's visit to the region from 17 21.
# index: 246 hypo  : the european union in on economic issues and during the's to the to.
# index: 246 target: british foreign secretary, in his presidential capacity, also the region from 15 to 18.
# index: 246 hypo  : the, in, also the to.
#   0%|          | 0/2215 [00:00<?, ?it/s]
# Train epoch:2  index:221  loss:0.7417906159   WER:29.4334871154 BLEU:72.33693187141314 lr:0.0000988914
# index: 221 target: that have been made will not improve the status成 culture in europe, on the contrary bismarck
# index: 221 hypo  : the that have been made will not improve the of culture in europe, on the contrary.
# index: 221 target: mr president, the chief aim of an internal electricity market must be play.
# index: 221 hypo  : mr president, the aim of an internal market must be fair play.
# Train epoch:2  index:442  loss:0.7082203149   WER:28.5661682390 BLEU:74.36016350109264 lr:0.0000977828
# index: 442 target: any event, for members not aware of the president s position, i will read the official communication and it thereby appear today's minutes :
# index: 442 hypo  : in any event, for those members who not aware of the president's position, i will read the communication and it will in today's minutes :
# index: 442 target: it concerns the implications of dam on access to fresh water in the region as a whole.
# index: 442 hypo  : it concerns the of the on access to water in the region as a whole.
# Train epoch:2  index:663  loss:0.6795556096   WER:27.8046521539 BLEU:76.26682735986178 lr:0.0000966742
# index: 663 target: we will have failed them we tackle racism and xenophobia in the european union.
# index: 663 hypo  : we will have failed them unless we racism and xenophobia in the european union.
# index: 663 target: theging of multilateral relations has not led sustained expansion, and the, social and human partnership is highly inadequate.
# index: 663 hypo  : the for of multi relations has not led to, and the cultural, social and human partnership is.
# Train epoch:2  index:884  loss:0.6531585367   WER:27.1122624822 BLEU:77.78217798620626 lr:0.0000955656
# index: 884 target: a second matter,, relating to the additional criteria, which should be taken consideration in selecting disadvantaged areas. here,, i am willing tobba greater flexibility to consider other relevant criteria in addition to community criteria given in point 11 of the guidance project.
# index: 884 hypo  : regarding a second matter, now, relating to the additional criteria, which should be taken into consideration in areas. here, too, i am to demonstrate greater flexibility and to consider other relevant criteria in addition to the community criteria given in point 11 of the project.
# index: 884 target: result : a court action and costs greater than the cost of the programme itself.
# index: 884 hypo  : result : a court action and costs greater than the cost of the programme itself.
# Train epoch:2  index:1105  loss:0.6308007668   WER:26.5516442419 BLEU:79.1174273196399 lr:0.0000944570
# index: 1105 target: i now like speak behalf of the socialist group, in this which what we to be a statement from the council on the geneva convention i will an initial comment explaining the reasons why my group tabled a resolution on same subject during the last session of 1999.
# index: 1105 hypo  : i would now like to speak, on behalf of the socialist group, in this debate which what we consider to be a statement from the council on the geneva convention. i will begin with an comment the reasons why my group tabled a resolution on this same subject during the last session of parliament in 1999.
# index: 1105 target: thereined too much staff - expenditure angie
# index: 1105 hypo  : there is too much staff - related expenditure.
# Train epoch:2  index:1326  loss:0.6124769220   WER:26.0171728024 BLEU:80.15019205481828 lr:0.0000933484
# index: 1326 target: i am sure that we agree on the strategic importance, which is crucial for the european union of its mediterranean influence ;, since, being neighbours, we are required build a relationship which goes beyond the constitution of a simple area ; economically because i am convinced opportunities for mutual benefit being created which we are not taking sufficient of ; also, socially, because the problems of the extent of economic inequalities and of the great pressures from migration require coordinated and structural solutions and, of course, we also have to mention the question of security.
# index: 1326 hypo  : i am sure that we all agree on the strategic importance, which is crucial for the european union, of its mediterranean influence ; politically, since, being, we are required to build a relationship which goes beyond the constitution of a simple free trade area ;, because i am convinced that opportunities for mutual benefit are being created which we are not taking sufficient advantage of ; also,, because the problems of the extent of economic ineities and of the great from require and structural and, of course, we also have to mention the question of security.
# index: 1326 target: cederschiold report ( a - 0020 / )
# index: 1326 hypo  : ce report ( a5 - 00 / 2000 )
# Train epoch:2  index:1547  loss:0.5955995663   WER:25.5660731060 BLEU:81.10134047384173 lr:0.0000922398
# index: 1547 target: mr, there is one positive thing that i would like to say to you, perhaps contrary to the opinion of some members, regarding the telegram that you sent to the austrian government.
# index: 1547 hypo  : mr prodi, there is one positive thing that i would like to say to you, perhaps contrary to the opinion of some members, regarding the that you sent to the austrian government.
# index: 1547 target: topical and urgent
# index: 1547 hypo  : and urgent debate
# Train epoch:2  index:1768  loss:0.5802482343   WER:25.1434703105 BLEU:81.94487883267172 lr:0.0000911312
# index: 1768 target: madam president, i absolutely agree with rapporteur's analysis and i would like to thank the of the committee on culture, mr gargan, for his praiseworthy work in a mediation that was also, considerably difficult
# index: 1768 hypo  : madam president, i absolutely agree with the rapporteur's analysis and i would also like to thank the chairman of the committee on culture, mri, for his work in a process that was also, considerably difficult.
# index: 1768 target: of course must turn our attention to this matter, although, as you are aware, commission's powers in area are rather limited.
# index: 1768 hypo  : of course, we must turn our attention to this matter, although, as you are aware, the commission's powers in this area are rather limited.
# Train epoch:2  index:1989  loss:0.5657727088   WER:24.7854567292 BLEU:82.70101807298445 lr:0.0000900226
# index: 1989 target: i would like to make it the council recommend to on the figure of 300 000 women falling victim to trafficking in europe given by the swiss foreign.
# index: 1989 hypo  : i would like to make it clear that the council does not wish to comment on the figure of 000 women to trafficking in europe given by the foreign minister.
# index: 1989 target: we shall all have tosi sufficiently banco to our political leaders to voluntarily women's participation in the political decision - making process.
# index: 1989 hypo  : we shall all have to be sufficiently strong to force our political leaders to impose women's participation in the political decision - making process.
# Train epoch:2  index:2210  loss:0.5524118489   WER:24.4199745589 BLEU:83.38183656799598 lr:0.0000889140
# index: 2210 target: it therefore important for this to establish a mandate for of the representing it and also to establish - and seems to be - political objectives this parliament will pursue by means of this charter of fundamental rights.
# index: 2210 hypo  : it is therefore important for this parliament to establish a mandate for the members of the delegation it and also to establish - and this seems to me to be essential - which political objectives this parliament will pursue by means of this charter of fundamental rights.
# index: 2210 target: the vote will take tomorrow morning.
# index: 2210 hypo  : the vote will take place tomorrow morning.
#   0%|          | 0/247 [00:00<?, ?it/s]
# Val epoch:2  index:82  loss:0.6445684033   WER:20.1114158669 BLEU:92.02405772880961 lr:0.0000888889
# index: 82 target: on the one disguise wantlargement while, on the hand, they are not prepared pay for it.
# index: 82 hypo  : on the one hand they want enlargement while, on the other hand, they are not prepared to pay for it.
# index: 82 target: they cannot have it both ways.
# index: 82 hypo  : they cannot have it both ways.
# Val epoch:2  index:164  loss:0.6259904391   WER:19.6050034364 BLEU:92.37643963545725 lr:0.0000888889
# index: 164 target: according to the information we have received from luxembourg authorities, the centre has been created within context of a cooperation between council of europe and the luxembourg authorities.
# index: 164 hypo  : according to the information we have received from the luxembourg authorities, the centre has been created within the context of a cooperation agreement between the council of europe and the luxembourg authorities.
# index: 164 target: of course commission takes a favourable als of this because, given the importance of the european cultural network, the centre can make a positive contribution to improving the link between cultural heritage and cultural tourism on a european scale.
# index: 164 hypo  : of course, the commission takes a favourable view of this initiative because, given the importance of the european cultural network, the centre can make a positive contribution to improving the link between cultural heritage and cultural tourism on a european scale.
# Val epoch:2  index:246  loss:0.6179615414   WER:19.4969039023 BLEU:92.18641600936725 lr:0.0000888889
# index: 246 target: the european union participated negotiations on economic issues before and during the minister's visit to the region from 17 21.
# index: 246 hypo  : the european union in negotiations on interim economic issues before and during the prime minister's visit to the region from 17 to 21 april.
# index: 246 target: british foreign secretary, in his presidential capacity, also the region from 15 to 18.
# index: 246 hypo  : the british foreign secretary, in his capacity, also visited the region from 15 to 18 march.
#   0%|          | 0/2215 [00:00<?, ?it/s]
# Train epoch:3  index:221  loss:0.4099312987   WER:20.7469723429 BLEU:90.05559834867762 lr:0.0000877803
# index: 221 target: we must reject what unacceptable, as our constituents demand.
# index: 221 hypo  : we must reject what is unacceptable, as our demand.
# index: 221 target: these recommendations, which, for the most part, are consistent with the guidelines in the portuguese presidency's work programme which will therefore be at the lisbon summit, have been rejected or distorted by the committee on economic and monetary affairs of this parliament, by abians which only managed to a fragile unity in its rejection of the idea of a european union which is on convergence national policies and just on the grouping together of markets.
# index: 221 hypo  : these recommendations, which, for the most part, are consistent with the guidelines in the portuguese presidency's work programme and which will therefore be discussed at the lisbon, have been rejected or by the committee on economic and monetary affairs of this parliament, by a majority which only managed to achieve a in its of the idea of a european union which is on the convergence of national policies and not just on the together of markets.
# Train epoch:3  index:442  loss:0.4035284913   WER:20.5668083306 BLEU:90.30924943697393 lr:0.0000866717
# index: 442 target: in other words there is loophole here which must be filled i will examine the solution advocated in the report in the interests of on.
# index: 442 hypo  : in other words, there is a here which must be and i will examine the solution in the report in the interests of moving things on.
# index: 442 target: theporteur has 止 hinted at this in no uncertain terms, namely, the issue of intereth relations.
# index: 442 hypo  : the rapporteur has already at this in no terms, namely, the issue of inter relations.
# Train epoch:3  index:663  loss:0.4005164253   WER:20.4762171780 BLEU:90.60443419323673 lr:0.0000855631
# index: 663 target: we are not going to enter into a debate.
# index: 663 hypo  : we are not going to enter into a debate now.
# index: 663 target: we should set our aims higher than the commission has done.
# index: 663 hypo  : we should set our aims higher than the commission has done.
# Train epoch:3  index:884  loss:0.3961487110   WER:20.4107640547 BLEU:90.71077329351716 lr:0.0000844545
# index: 884 target: belgian society is currently being rocked by athleticedo, and similar proceedings often on in our own.
# index: 884 hypo  : belgian society is currently being by pa, and similar proceedings often go on in our own countries.
# index: 884 target: what are the actions it is going to to reduce income discrepancies and to encourage the creation of infrastructures and the reviewing updating of trade agreements?
# index: 884 hypo  : what are the actions it is going to undertake to reduce income discrepancies and to encourage the creation of infrastructures and the and up of trade agreements?
# Train epoch:3  index:1105  loss:0.3905753329   WER:20.2880253534 BLEU:90.89281778438816 lr:0.0000833459
# index: 1105 target: believe that the universal service is a pillar and i am sure that my colleague be able to provide res to the appropriate committee.
# index: 1105 hypo  : we believe that the universal service is a pillar and i am sure that my colleague will be able to provide res to the appropriate parliamentary committee.
# index: 1105 target: let us proceed with the vote.
# index: 1105 hypo  : let us proceed with the vote.
# Train epoch:3  index:1326  loss:0.3865251965   WER:20.2093367284 BLEU:91.0210422436613 lr:0.0000822373
# index: 1326 target: the contribution that the projects supported by life the sustainability of social and economic activities and thus creation.
# index: 1326 hypo  : the contribution that the projects supported by life make to the sustainability of social and economic activities, and thus job creation.
# index: 1326 target: that is the political core of the and i think you have identified it before this house today
# index: 1326 hypo  : that is the political core of the challenge and i think you have identified it well before this house today.
# Train epoch:3  index:1547  loss:0.3820909988   WER:20.0810720032 BLEU:91.17451853305408 lr:0.0000811287
# index: 1547 target: can be told at eyelids request, and what reasons were given for withdrawing that?
# index: 1547 hypo  : can i be told at whose request, and what reasons were given for that?
# index: 1547 target: and so we now have no resources left to pay pensions.
# index: 1547 hypo  : and so we now have no resources left to pay pensions.
# Train epoch:3  index:1768  loss:0.3784779985   WER:19.9970061176 BLEU:91.31918038943755 lr:0.0000800201
# index: 1768 target: if the danish government had acted in the same way under present disp, it have been downright illegal and unconstitutional because the budget deficit 3. 9 % at that time.
# index: 1768 hypo  : if the danish government had in the same way under the present dispensation, it would have been down illegal and because the budget deficit was 3. 9 % at that time.
# index: 1768 target: there seem to be intractable technical but are definitely working on it.
# index: 1768 hypo  : there seem to be intra technical problems but we are definitely working on it.
# Train epoch:3  index:1989  loss:0.3761245932   WER:19.8908458240 BLEU:91.47715487390306 lr:0.0000789115
# index: 1989 target: therefore, question is whether you could examine the that some of the policies on microcredits, have brought results in cooperation, be applied to those women in severely less - favoured regions, who the odds stacked against them.
# index: 1989 hypo  : therefore, my is whether you could examine the possibility that some of the policies ons, which have brought results in cooperation, could be applied to those women in severely less - favoured regions, who have the against them.
# index: 1989 target: why - as discussed in okay committee - i have now tabled an amendment to amendment no 2 which contains no reference to the concept of'harmonisation '.
# index: 1989 hypo  : that is why - as discussed in the committee - i have now tabled an amendment to amendment no 2 which contains no reference to the concept of'harmonisation '.
# Train epoch:3  index:2210  loss:0.3737302862   WER:19.8050449139 BLEU:91.58107729897634 lr:0.0000778029
# index: 2210 target: we have failed to spread the and values learned from.
# index: 2210 hypo  : we have failed to spread the lessons and values learned from that conflict.
# index: 2210 target: this is, example, the position expressed by mr berthu.
# index: 2210 hypo  : this is, for example, the position expressed by mru.
#   0%|          | 0/247 [00:00<?, ?it/s]
# Val epoch:3  index:82  loss:0.6134729956   WER:18.8497469398 BLEU:93.49357466083109 lr:0.0000777778
# index: 82 target: on the one disguise wantlargement while, on the hand, they are not prepared pay for it.
# index: 82 hypo  : on the one hand they want enlargement while, on the other hand, they are not prepared to pay for it.
# index: 82 target: they cannot have it both ways.
# index: 82 hypo  : they cannot have it both ways.
# Val epoch:3  index:164  loss:0.5966466772   WER:18.2687025468 BLEU:93.78947281396239 lr:0.0000777778
# index: 164 target: according to the information we have received from luxembourg authorities, the centre has been created within context of a cooperation between council of europe and the luxembourg authorities.
# index: 164 hypo  : according to the information we have received from the luxembourg authorities, the centre has been created within the context of a cooperation agreement between the council of europe and the luxembourg authorities.
# index: 164 target: of course commission takes a favourable als of this because, given the importance of the european cultural network, the centre can make a positive contribution to improving the link between cultural heritage and cultural tourism on a european scale.
# index: 164 hypo  : of course, the commission takes a favourable view of this initiative because, given the importance of the european cultural network, the can make a positive contribution to improving the link between cultural heritage and cultural tourism on a european scale.
# Val epoch:3  index:246  loss:0.5911911075   WER:18.1840475105 BLEU:93.67281726643522 lr:0.0000777778
# index: 246 target: the european union participated negotiations on economic issues before and during the minister's visit to the region from 17 21.
# index: 246 hypo  : the european union in negotiations on interim economic issues before and during the prime minister's visit to the region from 17 to 21 april.
# index: 246 target: british foreign secretary, in his presidential capacity, also the region from 15 to 18.
# index: 246 hypo  : the british foreign secretary, in his presidential capacity, also visited the region from 15 to 18 march.
#   0%|          | 0/2215 [00:00<?, ?it/s]
# Train epoch:4  index:221  loss:0.3312160546   WER:18.9054527382 BLEU:92.79788652572006 lr:0.0000766692
# index: 221 target: grain legumes
# index: 221 hypo  : grain legumes
# index: 221 target: this relates in particular to the intended agenda, regards the amsterdam leftovers, which suggests that unacceptable inner cabinets will be created in the future. also areas relating the second third, which tend to be reflected in an undirable militaation of the union
# index: 221 hypo  : this relates in particular to the intended agenda, as regards the amsterdam left, which suggests that unacceptable will be created in the future. this also areas relating to the second and third pillars, which tend to be reflected in an undesirablerisation of the european union.
# Train epoch:4  index:442  loss:0.3308575180   WER:18.8313026892 BLEU:92.93386689663643 lr:0.0000755606
# index: 442 target: for its part, the commission published an initial on trafficking in women in, that is say the year immediately after beijing platform was adopted, it launched the stop programme annual budget eu 6. 5 million.
# index: 442 hypo  : for its part, the commission published an initial communication on trafficking in women and, in 1996, that is to say the year immediately after the beijing was adopted, it launched the stop programme, with an annual budget of eur 6. 5 million.
# index: 442 target: i want to be very candid : i have not seen much enthusiasm about conference or proposal to enge the powers of the eu.
# index: 442 hypo  : i want to be veryd : i have not seen much enthusiasm about that conference or the proposal to enlarge the powers of the eu.
# Train epoch:4  index:663  loss:0.3272068577   WER:18.6897370472 BLEU:92.9821352364661 lr:0.0000744520
# index: 663 target: may i add that, behalf of the commission, i mane with great interest the which have been made just now and i have great deal of for unease which underlies these pleas.
# index: 663 hypo  : may i add that, on behalf of the commission, i listened with great interest to the which have been made just now and that i have a great deal of sympathy for the which under these.
# index: 663 target: as us parliament, i would like to remind you of the code of conduct between the commission which was signed in may.
# index: 663 hypo  : as for us in parliament, i would like to remind you of the code of conduct between the commission and parliament which was signed in may.
# Train epoch:4  index:884  loss:0.3244232452   WER:18.5439781835 BLEU:93.11479856255637 lr:0.0000733434
# index: 884 target: my first question, which is a very direct one, is an historia issue which now have the opportunity to discuss with you for the first time as president - in - office council.
# index: 884 hypo  : my first question, which is a very direct one, is about an institutional issue which we now have the opportunity to discuss with you for the first time as president - in - office of the european council.
# index: 884 target: should like to thank commissioner kinnock for all his efforts so far.
# index: 884 hypo  : i should like to thank commissioner kinnock for all his efforts so far.
# Train epoch:4  index:1105  loss:0.3215940634   WER:18.4809360503 BLEU:93.11857099582386 lr:0.0000722348
# index: 1105 target: mr president, one cannot but feel disgust and indignation at the scenes of lynching, no, of moroccan day labourers which place in eljido.
# index: 1105 hypo  : mr president, one cannot but feel and indation at the ofing, no less, of day which took place in el ejido.
# index: 1105 target: let me in this, welcome the presence the visitors'of mrs javette - le besque, spokesperson for the oil slick action group " maree noire ", made up men and women from the french department of morbihan.
# index: 1105 hypo  : let me, in this connection, welcome the presence in the'gallery of mrste - le be, for the oil slick action group "ee ", made up of men and women from the french department of.
# Train epoch:4  index:1326  loss:0.3213137964   WER:18.4625755671 BLEU:93.16977920840952 lr:0.0000711262
# index: 1326 target: the report states modernisation does not mean a reduction in the level of social protection,, better use of resources.
# index: 1326 hypo  : the report states that modernisation does not mean a reduction in the level of social protection but, rather, better use of available resources.
# index: 1326 target: as rampage by the rapport, the effects of the structural measures, on other hand, are minimal far as employment is concerned.
# index: 1326 hypo  : as indicated by the rapporteur, the effects of the structural measures, on the other hand, are as far as employment is concerned.
# Train epoch:4  index:1547  loss:0.3203129758   WER:18.4078483909 BLEU:93.25432407299783 lr:0.0000700176
# index: 1547 target: this is already the fourth in a row within a short space of time in connection with the chechen tragedy.
# index: 1547 hypo  : this resolution is already the fourth in a within a short space of time in connection with the chechen tragedy.
# index: 1547 target: the council's position improve road safety considerably, and the directive should enter into force as soon as possible
# index: 1547 hypo  : the council's common position will improve road safety considerably, and the directive should enter into force as soon as possible.
# Train epoch:4  index:1768  loss:0.3197852677   WER:18.3914254249 BLEU:93.29673515020323 lr:0.0000689090
# index: 1768 target: of course, it does not in itself ensure product.
# index: 1768 hypo  : of course, it does not in itself ensure product safety.
# index: 1768 target: i call on the to act on the rapid accession of east timor to lome convention as one means, amongst others, of promoting eradication of poverty accelerating its economic, cultural and social development, order to strengthen its internal democratisation.
# index: 1768 hypo  : i call on the commission to act on the rapid accession of east timor to the lome convention as one means, amongst others, of promoting the eradication of poverty and its economic, cultural and social development, in order to strengthen its internal democratisation.
# Train epoch:4  index:1989  loss:0.3186090381   WER:18.3347504781 BLEU:93.38138706290523 lr:0.0000678004
# index: 1989 target: firstly, when i came to this parliament many years ago i was told that if you had difficult job you gave it a liberal.
# index: 1989 hypo  : firstly, when i came to this parliament many years ago i was told that if you had a difficult job you gave it to a liberal.
# index: 1989 target: thirdly the life budget has been reduced in real termseles not kept up with the enormous dynamism and under of demand.
# index: 1989 hypo  : thirdly, the life budget has been reduced in real terms has not kept up with the enormous dmism and of demand.
# Train epoch:4  index:2210  loss:0.3179089257   WER:18.3240199398 BLEU:93.38090594714778 lr:0.0000666917
# index: 2210 target: the importance of enabling destroyers numbers of women become involved in politics is, however, recognised
# index: 2210 hypo  : the importance of enabling greater numbers of to become involved in politics is,, recognised.
# index: 2210 target: in of this, waste management according to the law of the immediate cost is not acceptable. the waste treatment industry, employs tens of thousands of people and makes billions of flourishing due to this growing need.
# index: 2210 hypo  : in view of this, waste management according to the law of the least immediate cost is not acceptable. the waste treatment industry, which tens of thousands of people and makes billions of euros, is due to this growing need.
#   0%|          | 0/247 [00:00<?, ?it/s]
# Val epoch:4  index:82  loss:0.5830738254   WER:17.9110142413 BLEU:94.28892827422834 lr:0.0000666667
# index: 82 target: on the one disguise wantlargement while, on the hand, they are not prepared pay for it.
# index: 82 hypo  : on the one hand they want enlargement while, on the other hand, they are not prepared to pay for it.
# index: 82 target: they cannot have it both ways.
# index: 82 hypo  : they cannot have it both ways.
# Val epoch:4  index:164  loss:0.5655758230   WER:17.2995335002 BLEU:94.73434822332987 lr:0.0000666667
# index: 164 target: according to the information we have received from luxembourg authorities, the centre has been created within context of a cooperation between council of europe and the luxembourg authorities.
# index: 164 hypo  : according to the information we have received from the luxembourg authorities, the centre has been created within the context of a cooperation agreement between the council of europe and the luxembourg authorities.
# index: 164 target: of course commission takes a favourable als of this because, given the importance of the european cultural network, the centre can make a positive contribution to improving the link between cultural heritage and cultural tourism on a european scale.
# index: 164 hypo  : of course, the commission takes a favourable view of this initiative because, given the importance of the european cultural network, the centre can make a positive contribution to improving the link between cultural heritage and cultural tourism on a european scale.
# Val epoch:4  index:246  loss:0.5628347921   WER:17.2568492818 BLEU:94.5465997548316 lr:0.0000666667
# index: 246 target: the european union participated negotiations on economic issues before and during the minister's visit to the region from 17 21.
# index: 246 hypo  : the european union participated in negotiations on interim economic issues before and during the prime minister's visit to the region from 17 to 21 april.
# index: 246 target: british foreign secretary, in his presidential capacity, also the region from 15 to 18.
# index: 246 hypo  : the british foreign secretary, in his presidential capacity, also visited the region from 15 to 18 march.
#   0%|          | 0/2215 [00:00<?, ?it/s]
# Train epoch:5  index:221  loss:0.2897276276   WER:17.7825900472 BLEU:94.20799614259661 lr:0.0000655581
# index: 221 target: and that is why we to the reached yesterday. that why we sustain that conclusion we continue to the values and the law
# index: 221 hypo  : and that is why we came to the conclusion we reached yesterday morning. that is why we that conclusion as we continue to uphold the values and the law.
# index: 221 target: it should be noted the regulation on social security systems does at present refer to the question of early retirement and the commission has proposed certain amendments to the regulation which are, however, still before the council.
# index: 221 hypo  : it should be noted that the current regulation on social security systems does not at present refer to the question of early retirement and the commission has proposed certain amendments to the regulation which are, however, still pending before the council.
# Train epoch:5  index:442  loss:0.2917003923   WER:17.7726638599 BLEU:94.08616149933616 lr:0.0000644495
# index: 442 target: the commission is always accusing member states of not transposing its decisions and directives into their national legislation, while is exactly thing on international level.
# index: 442 hypo  : the commission is always member states of not transposing its decisions and directives into their national legislation, while it is doing exactly the same thing on an international level.
# index: 442 target:
# index: 442 hypo  :
# Train epoch:5  index:663  loss:0.2916624119   WER:17.7742249315 BLEU:94.05848128575475 lr:0.0000633409
# index: 663 target: question no 37 by ★ h - 0029 / 00 ) :
# index: 663 hypo  : question no 37 by ( h - 00 / 00 ) :
# index: 663 target: the objectives of life : must have as its main objective sustainable development, in close association the pilot projects carried out under initiative, on which i have had the opportunity to speak elsewhere ;
# index: 663 hypo  : the objectives of life : this must have as its main objective sustainable urban development, in close association with the pilot projects carried out under the urban initiative, on which i have had the opportunity to speak elsewhere ;
# Train epoch:5  index:884  loss:0.2909498450   WER:17.8187252144 BLEU:94.02103452060756 lr:0.0000622323
# index: 884 target: it is particularly good that mrhope has also stated that everything has the appearance of being child pornography shall also be included under this definition
# index: 884 hypo  : it is particularly good that mr kirkhope has also stated that everything that has the of being child pornography shall also be included under this definition.
# index: 884 target: i welcome the renewed in relations between the greek and turkish government.
# index: 884 hypo  : i welcome the renewed in relations between the greek government and the turkish government.
# Train epoch:5  index:1105  loss:0.2903376244   WER:17.7590055707 BLEU:94.00390709494664 lr:0.0000611237
# index: 1105 target: since the time allocated to questions to the commission has elapsed, questions 46 to 68 will be replied to in writing
# index: 1105 hypo  : since the time to questions to the commission has elapsed, questions 46 to 68 will be replied to in writing.
# index: 1105 target: i must also stress that once again commission, in, skirting the issue of practical action on equal opportunities.
# index: 1105 hypo  : i must also stress that once again the commission is, in fact,ing the issue of practical action on equal opportunities.
# Train epoch:5  index:1326  loss:0.2899322630   WER:17.7496789362 BLEU:93.9821667340607 lr:0.0000600150
# index: 1326 target: mrs schroedter's report marks a further step towards the transparency and effectiveness of structural aid.
# index: 1326 hypo  : mrs schroedter's report marks a further step towards the transparency and effectiveness of structural aid.
# index: 1326 target: but when comes to penalties and the word'harmonisation'a good many people in this 1869 a start - on the left and on the right of this house, both those higher up and those lower down.
# index: 1326 hypo  : but when it comes to penalties and the word'harmonisation'a good many people in this room give a start - on the left and on the right of this house, both those higher up and those lower down.
# Train epoch:5  index:1547  loss:0.2900065788   WER:17.7525870814 BLEU:93.99538725928709 lr:0.0000589064
# index: 1547 target: in an area where pitfalls peekedound, in a where every word and every gesture is weighed to assay its implements meaning, in jordan, israel and the territories the supreme pontiff has found right way to discuss persistent problems between the communities
# index: 1547 hypo  : in an area where ab, in a context where every word and every gesture is to ass its symbolic meaning, in, israel and the palestinian territories the pont has found the right way to discuss persistent problems the communities.
# index: 1547 target: we have armed forces, we have all got experience of training community police officers.
# index: 1547 hypo  : we have armed forces, we have all got experience of training community police officers.
# Train epoch:5  index:1768  loss:0.2900820591   WER:17.7437632898 BLEU:93.97231130595847 lr:0.0000577978
# index: 1768 target: example, it has not defined.
# index: 1768 hypo  : for example, it has not been defined.
# index: 1768 target: it is never easy working on comitology.
# index: 1768 hypo  : it is never easy working on comitology.
# Train epoch:5  index:1989  loss:0.2903680919   WER:17.6984692957 BLEU:94.01839864204796 lr:0.0000566892
# index: 1989 target: farming, fishing, oyster farming and fish farming are seriously affected, for the effects experience the oil slick have compounded by the storm damage affecting many areas
# index: 1989 hypo  : shellfish farming, fishing, farming and fish farming are today seriously affected, for the effects of the oil slick have been compounded by the storm damage affecting many areas.
# index: 1989 target: i would to take opportunity to reiterate to mr turmes for his work.
# index: 1989 hypo  : i would like to take this opportunity to reiterate my thanks to mr turmes for his work.
# Train epoch:5  index:2210  loss:0.2895183383   WER:17.6448441450 BLEU:94.04050553628836 lr:0.0000555806
# index: 2210 target: at the same time, however, we shut our eyes to the union's own to the violence, inequality, and fourth world reality, which is of everyday in the eu.
# index: 2210 hypo  : at the same time, however, we shut our eyes to the union's own problems : to the violence, inequality, and fourth world reality, which is part of everyday life in the eu.
# index: 2210 target: mr president, commissioner, firstly i too would neighbouring to thank the rapporteur.
# index: 2210 hypo  : mr president, commissioner, firstly i too would like to thank the rapporteur.
#   0%|          | 0/247 [00:00<?, ?it/s]
# Val epoch:5  index:82  loss:0.5955825317   WER:17.4400978587 BLEU:94.63114509576315 lr:0.0000555556
# index: 82 target: on the one disguise wantlargement while, on the hand, they are not prepared pay for it.
# index: 82 hypo  : on the one hand they want enlargement while, on the other hand, they are not prepared to pay for it.
# index: 82 target: they cannot have it both ways.
# index: 82 hypo  : they cannot have it both ways.
# Val epoch:5  index:164  loss:0.5776998557   WER:16.9045599445 BLEU:95.05066067518385 lr:0.0000555556
# index: 164 target: according to the information we have received from luxembourg authorities, the centre has been created within context of a cooperation between council of europe and the luxembourg authorities.
# index: 164 hypo  : according to the information we have received from the luxembourg authorities, the centre has been created within the context of a cooperation agreement between the council of europe and the luxembourg authorities.
# index: 164 target: of course commission takes a favourable als of this because, given the importance of the european cultural network, the centre can make a positive contribution to improving the link between cultural heritage and cultural tourism on a european scale.
# index: 164 hypo  : of course, the commission takes a favourable view of this initiative because, given the importance of the european cultural network, the centre can make a positive contribution to improving the link between cultural heritage and cultural tourism on a european scale.
# Val epoch:5  index:246  loss:0.5758694334   WER:16.9122155868 BLEU:94.81441211224083 lr:0.0000555556
# index: 246 target: the european union participated negotiations on economic issues before and during the minister's visit to the region from 17 21.
# index: 246 hypo  : the european union participated in negotiations on interim economic issues before and during the prime minister's visit to the region from 17 to 21 april.
# index: 246 target: british foreign secretary, in his presidential capacity, also the region from 15 to 18.
# index: 246 hypo  : the british foreign secretary, in his presidential capacity, also visited the region from 15 to 18 march.
#     (Decay learning rate: 0.000056 -> 0.000028)
#   0%|          | 0/2215 [00:00<?, ?it/s]
# Train epoch:6  index:221  loss:0.2729600422   WER:17.2049862760 BLEU:94.30167737475838 lr:0.0000544470
# index: 221 target: they could meet a regular basis to the promotion of human rights in short and long term.
# index: 221 hypo  : they could meet on a regular basis to the promotion of human rights in the short and long term.
# index: 221 target: i have 194ed secure the wide support for the report.
# index: 221 hypo  : i have endeavoured to secure the widest possible support for the report.
# Train epoch:6  index:442  loss:0.2743794773   WER:17.3297545791 BLEU:94.39846352414229 lr:0.0000533383
# index: 442 target: among others, it calling for equal rights of all matthews between same - sex couples and traditional family, together lowering the age consent for same - relations.
# index: 442 hypo  : among others, it is calling for equal rights of all kinds between same - sex couples and the traditional family, together with lowering the age of consent for same - sex relations.
# index: 442 target: the item is the statements by the council the commission the existence of an artificial intelligence system allowing the united states of to intercept and monitor all telephone and within the union, system called'echelon '.
# index: 442 hypo  : the next item is the statements by the council and the commission on the existence of an artificial intelligence system allowing the united states of america to intercept and monitor all telephone and electronic communications within the european union, a system called'echelon '.
# Train epoch:6  index:663  loss:0.2710775885   WER:17.2701806278 BLEU:94.45909505787986 lr:0.0000522297
# index: 663 target: - ( pt ) mr president, ladies and, the guidelines for thetila budgetary procedure as laid down in the haug report are a starting point for a debate on the european union for 2001 which to be both arduous and heated throughout the year.
# index: 663 hypo  : - ( pt ) mr president, ladies and gentlemen, the guidelines for the 2001 budgetary procedure as laid down in the haug report are a starting point for a debate on the european union budget for 2001 which promises to be both arduous and throughout the year.
# ...
# Train epoch:8  index:884  loss:0.2466169944   WER:16.7306028163 BLEU:94.85831144292841 lr:0.0000288989
# index: 884 target: if i too agree with the contents of amendments nos 79 and 106, these go beyond the commitments ospar, andmay cannot therefore approve these amendments.
# index: 884 hypo  : even if i too agree with the contents of amendments nos and 106, these go beyond the commitments under ospar, and i cannot therefore approve these amendments.
# index: 884 target: principle in amendment no 16 is also acceptable.
# index: 884 hypo  : the principle in amendment no 16 is also acceptable.
# Train epoch:8  index:1105  loss:0.2465830576   WER:16.7124907134 BLEU:94.8692618063346 lr:0.0000277903
# index: 1105 target: convinced that you share my wish that it should be possible to adopt regulation as soon as possible especially in view of the fact that there are great expectations in the member states haggard in countries, especially among the which are now being given the opportunity to participate in life.
# index: 1105 hypo  : i am convinced that you share my wish that it should be possible to adopt the regulation as soon as possible, especially in view of the fact that there are great expectations in the member states and in other countries, especially among the applicant states which are now being given the opportunity to participate in life.
# index: 1105 target: greater transparency will help to achieve public acceptance decisions to competition policy.
# index: 1105 hypo  : greater transparency will also help to achieve public acceptance of decisions relating to competition policy.
# Train epoch:8  index:1326  loss:0.2470250551   WER:16.6776848947 BLEU:94.88414626983538 lr:0.0000266817
# index: 1326 target: then, for example, will think before transporting oil in a tanker that is about to fall apart.
# index: 1326 hypo  : then, for example, people will think twice before transporting oil in a tanker that is about to fall apart.
# index: 1326 target: it will not be tolerated and immediately.
# index: 1326 hypo  : it will not be tolerated, and must stop immediately.
# Train epoch:8  index:1547  loss:0.2478415696   WER:16.7037370202 BLEU:94.84647020655436 lr:0.0000255731
# index: 1547 target: we can but share the concern of the council and the commission to the european union, after the single and after the, finallyquipping itself with a political project that is accessible to all its citizens, but the new governance of which you are - in my opinion unfairly - priding yourselves lacks the democratic and participatory ambition to which nascent european civil society aspires.
# index: 1547 hypo  : we can but share the concern of the council and the commission to see the european union, after the single market and after the euro, finally equipping itself with a political project that is accessible to all its citizens, but the new governance of which you are - in my opinion unfairly - priding yourselves lacks the democratic and participatory ambition to which nas european civil society aspires.
# index: 1547 target: it considered that without these changes undesbly costs in collection of could be incurred in member states and that there could be serious of confidentiality.
# index: 1547 hypo  : it is considered that without these changes undesirably high costs in the collection of data could be incurred in member states and that there could also be serious problems of confidentiality.
# Train epoch:8  index:1768  loss:0.2479556793   WER:16.7056306169 BLEU:94.81964422724036 lr:0.0000244645
# index: 1768 target: the vote will take place tomorrow at p. m.
# index: 1768 hypo  : the vote will take place tomorrow at 12 p. m.
# index: 1768 target: can you please do something about it?
# index: 1768 hypo  : can you please do something about it?
# Train epoch:8  index:1989  loss:0.2484932794   WER:16.7029806570 BLEU:94.85021317877083 lr:0.0000233559
# index: 1989 target: if we supplement the macmick report this direction, the parliament will have done in the eyes of the consumer.
# index: 1989 hypo  : if we supplement the maccormick report in this direction, the european parliament will have done a good job in the eyes of the consumer.
# index: 1989 target: i also want to point out that while speeches the principle are of course interesting, we to have the to talk about the
# index: 1989 hypo  : i also want to point out that while speeches on the principle are of course interesting, we have to have the courage to talk about the facts.
# Train epoch:8  index:2210  loss:0.2482227598   WER:16.6882052829 BLEU:94.88376467767507 lr:0.0000222473
# index: 2210 target: it is clear a radical overhaul of the philanthropist is long overdue.
# index: 2210 hypo  : it is clear that a radical overhaul of the commission is long overdue.
# index: 2210 target: the commission has suggested adopting the content these with certain changes in the wording.
# index: 2210 hypo  : the commission has suggested adopting the content of these, with certain changes in the wording.
#   0%|          | 0/247 [00:00<?, ?it/s]
# Val epoch:8  index:82  loss:0.5721660155   WER:17.2800899777 BLEU:94.87665945319785 lr:0.0000222222
# index: 82 target: on the one disguise wantlargement while, on the hand, they are not prepared pay for it.
# index: 82 hypo  : on the one hand they want enlargement while, on the other hand, they are not prepared to pay for it.
# index: 82 target: they cannot have it both ways.
# index: 82 hypo  : they cannot have it both ways.
# Val epoch:8  index:164  loss:0.5554680706   WER:16.7722429538 BLEU:95.23327270002187 lr:0.0000222222
# index: 164 target: according to the information we have received from luxembourg authorities, the centre has been created within context of a cooperation between council of europe and the luxembourg authorities.
# index: 164 hypo  : according to the information we have received from the luxembourg authorities, the centre has been created within the context of a cooperation agreement between the council of europe and the luxembourg authorities.
# index: 164 target: of course commission takes a favourable als of this because, given the importance of the european cultural network, the centre can make a positive contribution to improving the link between cultural heritage and cultural tourism on a european scale.
# index: 164 hypo  : of course, the commission takes a favourable view of this initiative because, given the importance of the european cultural network, the centre can make a positive contribution to improving the link between cultural heritage and cultural tourism on a european scale.
# Val epoch:8  index:246  loss:0.5534571499   WER:16.7541128918 BLEU:94.99103380394607 lr:0.0000222222
# index: 246 target: the european union participated negotiations on economic issues before and during the minister's visit to the region from 17 21.
# index: 246 hypo  : the european union participated in negotiations on interim economic issues before and during the prime minister's visit to the region from 17 to 21 april.
# index: 246 target: british foreign secretary, in his presidential capacity, also the region from 15 to 18.
# index: 246 hypo  : the british foreign secretary, in his presidential capacity, also visited the region from 15 to 18 march.
#     (Decay learning rate: 0.000022 -> 0.000011)
#   0%|          | 0/2215 [00:00<?, ?it/s]
# Train epoch:9  index:221  loss:0.2398463875   WER:16.4668152866 BLEU:94.63751279653806 lr:0.0000211136
# index: 221 target: basically, as as we are concerned, we need to adopt macroeconomic political measures which are based pepsi stimulating demand, public investment onל for improved public. these measures should be geared towards full employment and guarantee rate of employment around 75 % by 2010.
# index: 221 hypo  : basically, as far as we are concerned, we need to adopt macroeconomic political measures which are based on stimulating demand, on public investment and on respect for improved public services. these measures should be geared towards full employment and guarantee a rate of employment of around 75 % by 2010.
# index: 221 target: after the debacle in seattle, our duty from now on is to spin concerted and ensure that the of world trade develop and are used₤ fight poverty.
# index: 221 hypo  : after the debacle in seattle, our duty from now on is to adopt a concerted position and ensure that the rules of world trade develop and are used to fight poverty.
# Train epoch:9  index:442  loss:0.2405339261   WER:16.4831097975 BLEU:94.94239400409671 lr:0.0000200050
# index: 442 target: three comments : the first is based on the fact that women are able.
# index: 442 hypo  : three comments : the first is based on the fact that women are able.
# index: 442 target: is a substance as poisonous as cyani really to be used in the mining industry in the production of metals
# index: 442 hypo  : is a substance as as cyanide really to be used in the mining industry and in the production of metals?
# Train epoch:9  index:663  loss:0.2426433105   WER:16.4668375224 BLEU:94.99419411029712 lr:0.0000188964
# index: 663 target: what are the main priorities that you hope to at the next summit meetings
# index: 663 hypo  : what are the main priorities that you hope to achieve at the next summit meetings?
# index: 663 target: bouwman.
# index: 663 hypo  : bouwman.
# Train epoch:9  index:884  loss:0.2419735959   WER:16.4653098608 BLEU:95.1212552770823 lr:0.0000177878
# index: 884 target: nothing less than a major shift from reliance on landfill to more integrated waste management willffice normally
# index: 884 hypo  : nothing less than a major shift from on landfill sites to more integrated waste management plans will suffice.
# index: 884 target: the high representative preparedж say qualifying what extent this unit, which has been strongly supported by the committee of which i and titley are members, assisted in providing early information, analysis and an indication of the options open to yourselves?
# index: 884 hypo  : would the high representative be prepared to say to what extent this unit, which has been strongly supported by the committee of which i and mr titley are members, assisted in providing early information, analysis and an indication of the policy planning options open to yourselves?
# Train epoch:9  index:1105  loss:0.2422259541   WER:16.5063105940 BLEU:95.04170609506474 lr:0.0000166792
# index: 1105 target: , for the basque citizens whom i represent can be metal excuses based on internal affairs or on politicalport.
# index: 1105 hypo  : finally, for the basque citizens whom i represent, there can be no based on internal affairs or on political opportunism.
# index: 1105 target: the world programme relies eu ; a result, echo must now provide 80 % of the food originally intended as supplementary aid.
# index: 1105 hypo  : the world food programme relies on the eu ; as a result, echo must now provide 80 % of the food aid originally intended as supplementary aid.
# Train epoch:9  index:1326  loss:0.2418298684   WER:16.5335938035 BLEU:95.02899694621374 lr:0.0000155706
# index: 1326 target: thank youopsis mrs kinnock.
# index: 1326 hypo  : thank you, mrs kinnock.
# index: 1326 target: i think that very tough demands should be made of the car.
# index: 1326 hypo  : i think that very tough demands should be made of the car industry.
# Train epoch:9  index:1547  loss:0.2412101864   WER:16.5306405559 BLEU:95.01191259575023 lr:0.0000144620
# index: 1547 target: we do have this reproductive system in the european union - what call legal certainty.
# index: 1547 hypo  : but we do have this unfortunate system in the european union - what you call legal certainty.
# index: 1547 target: am convinced that the tributary's nationality has played a certain role, which should not be in this parliament.
# index: 1547 hypo  : i am convinced that the rapporteur's nationality has played a certain role, which should not be of relevance in this parliament.
# Train epoch:9  index:1768  loss:0.2414234849   WER:16.5143073651 BLEU:94.99958993319933 lr:0.0000133534
# index: 1768 target: i believe that over time, the council of the union has clearly demonstrated that is not how it sees this issue.
# index: 1768 hypo  : i believe that, over time, the council of the european union has clearly demonstrated that this is not how it sees this issue.
# index: 1768 target: first, on the presidential elections in peru the peruvian authorities invited both the eu presidency the commission to send observers to the elections.
# index: 1768 hypo  : first, on the presidential elections in peru, the authorities invited both the eu presidency and the commission to send observers to the elections.
# Train epoch:9  index:1989  loss:0.2408803588   WER:16.5271116907 BLEU:94.98206015407776 lr:0.0000122448
# index: 1989 target: interre must also to the development of a european research
# index: 1989 hypo  : interreg resources must also contribute to the development of a european research area.
# index: 1989 target: this creates ground for the rise in of racism.
# index: 1989 hypo  : all this creates ground for the rise in forms of racism.
# Train epoch:9  index:2210  loss:0.2413202550   WER:16.5334693405 BLEU:95.00265755383795 lr:0.0000111362
# index: 2210 target: in fact spain accounts for 90 % all eu legume production.
# index: 2210 hypo  : in fact spain accounts for 90 % of all eu grain legume production.
# index: 2210 target: in the wake of groner and mrs roure, who tackled this phenomenon, i want mention the upsurg in prostitution fingertips strasbourg and brussels during parliament's part - sessions.
# index: 2210 hypo  : in the wake of mrs groner and mrs roure, who tackled this phenomenon, i want to mention the upse in prostitution in strasbourg and brussels during this parliament's part - sessions.
#   0%|          | 0/247 [00:00<?, ?it/s]
# Val epoch:9  index:82  loss:0.5700652283   WER:17.1870050543 BLEU:94.93924801285996 lr:0.0000111111
# index: 82 target: on the one disguise wantlargement while, on the hand, they are not prepared pay for it.
# index: 82 hypo  : on the one hand they want enlargement while, on the other hand, they are not prepared to pay for it.
# index: 82 target: they cannot have it both ways.
# index: 82 hypo  : they cannot have it both ways.
# Val epoch:9  index:164  loss:0.5532929823   WER:16.7048893404 BLEU:95.27829192758294 lr:0.0000111111
# index: 164 target: according to the information we have received from luxembourg authorities, the centre has been created within context of a cooperation between council of europe and the luxembourg authorities.
# index: 164 hypo  : according to the information we have received from the luxembourg authorities, the centre has been created within the context of a cooperation agreement between the council of europe and the luxembourg authorities.
# index: 164 target: of course commission takes a favourable als of this because, given the importance of the european cultural network, the centre can make a positive contribution to improving the link between cultural heritage and cultural tourism on a european scale.
# index: 164 hypo  : of course, the commission takes a favourable view of this initiative because, given the importance of the european cultural network, the centre can make a positive contribution to improving the link between cultural heritage and cultural tourism on a european scale.
# Val epoch:9  index:246  loss:0.5509732929   WER:16.6811569584 BLEU:95.0306256735589 lr:0.0000111111
# index: 246 target: the european union participated negotiations on economic issues before and during the minister's visit to the region from 17 21.
# index: 246 hypo  : the european union participated in negotiations on interim economic issues before and during the prime minister's visit to the region from 17 to 21 april.
# index: 246 target: british foreign secretary, in his presidential capacity, also the region from 15 to 18.
# index: 246 hypo  : the british foreign secretary, in his presidential capacity, also visited the region from 15 to 18 march.
#     Early stopping. (early_stop_threshold = 3)

# %%
print( torch.__version__ )
