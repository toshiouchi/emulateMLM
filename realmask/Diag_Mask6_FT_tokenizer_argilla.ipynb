# %%
# -*- coding: utf-8 -*-

#
# Pytorchで用いるDatasetの定義
#

#!pip install janome

# sysモジュールをインポート
import sys
import os

import matplotlib.pyplot as plt
import pandas as pd
import torch
import random
from torch import nn, Tensor
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import numpy as np
import math
import janome
from janome.tokenizer import Tokenizer
from collections import Counter
from torch.utils.data.sampler import SubsetRandomSampler
import time
import levenshtein
import pickle
from timm.scheduler import CosineLRScheduler
from nltk import bleu_score
#from tqdm import tqdm
from tqdm.notebook import tqdm
from torch import autocast, GradScaler
from typing import Sequence, Dict, Tuple, Union
from transformers import  get_linear_schedule_with_warmup, BertTokenizer
from sklearn.metrics import accuracy_score
from datasets import load_dataset

#device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device = torch.device( "cpu")
use_amp = False
use_saved_pth = True

# %%
path = "../../python_image_recognition-main/6_img_captioning/6_7_ImgCap_pre_trained_Feature_extractor/CLIP_ENCODER/models--google-bert--bert-large-uncased/snapshots/6da4b6a26a1877e173fca3225479512db81a5e5b"
tokenizer = BertTokenizer.from_pretrained(pretrained_model_name_or_path = path)

vocab_size = len(tokenizer)
print(vocab_size)
# Out:
# 30522

# %%
class MyDataset(Dataset):
    def __init__(self, mode, tokenizer, pad_token_id, max_length ):

        #dataset = load_dataset("yelp_review_full") 
        #dataset = load_dataset("imdb")
        #dataset = load_dataset("kunishou/databricks-dolly-15k-ja")  
        # Dataset id from huggingface.co/dataset
        dataset_id = "argilla/synthetic-domain-text-classification"
        dataset = load_dataset(dataset_id, split='train')
 
        ## Load raw dataset
        #train_dataset = load_dataset(dataset_id, split='train')
        
        if mode == "train":
            dataset = dataset[:900]
        elif mode == "val":
            dataset = dataset[900:950]
        else:
            #dataset = dataset[950:1000]
            dataset = dataset[2:1000:20]
        self.dataset = dataset
        #print( "self.dataset[1]:", self.dataset['label'][1])
            
        #self.encoded_texts = [ tokenizer.encode(text, max_length = max_length, truncation = True ) for text in dataset['text']]
        self.encoded_texts = [ tokenizer.encode(text ) for text in dataset['text']]
        
        if max_length is None:
            self.max_length = self._longest_encoded_length()
        else:
            self.max_length = max_length
            # Truncate sequences if they are longer than max_length
            self.encoded_texts = [
                encoded_text[:self.max_length]
                for encoded_text in self.encoded_texts
            ]

        # Pad sequences to the longest sequence
        self.encoded_texts = [
            encoded_text + [pad_token_id] * (self.max_length - len(encoded_text))
            for encoded_text in self.encoded_texts
        ]
        
    def __getitem__(self, index):
        encoded = self.encoded_texts[index]
        label = self.dataset["label"][index]
        return (
            torch.tensor(encoded, dtype=torch.long),
            torch.tensor(label, dtype=torch.long)
        )

    def __len__(self):
        return len(self.encoded_texts)

    def _longest_encoded_length(self):
        max_length = 0
        for encoded_text in self.encoded_texts:
            encoded_length = len(encoded_text)
            if encoded_length > max_length:
                max_length = encoded_length
        return max_length
        # Note: A more pythonic version to implement this method
        # is the following, which is also used in the next chapter:
        # return max(len(encoded_text) for encoded_text in self.encoded_texts)

# %%
train_dataset = MyDataset(
    mode="train",
    tokenizer=tokenizer,
    pad_token_id = tokenizer.pad_token_id,
    max_length=None,
)

print(train_dataset.max_length)
print( len( train_dataset ))
# Out:
# 408
# 900

# %%
val_dataset = MyDataset(
    mode="val",
    tokenizer=tokenizer,
    pad_token_id = tokenizer.pad_token_id,
    max_length=512,
)
test_dataset = MyDataset(
    mode="test",
    tokenizer=tokenizer,
    pad_token_id = tokenizer.pad_token_id,
    max_length=512,
)

# %%
#num_workers = 0 if device == torch.device( 'cpu' ) else 8
num_workers = 0 if device == torch.device( 'cpu' ) else 8
batch_size = 4

train_loader = DataLoader(train_dataset,
                            batch_size=batch_size,
                            shuffle=True,
                            num_workers=num_workers,
                            pin_memory=True,)
                            #collate_fn = collate_func_lambda)
print( "train_loader defiend" )
# 開発データのDataLoaderを呼び出す
# 開発データはデータはシャッフルしない
val_loader = DataLoader(val_dataset,
                        batch_size=batch_size,
                        shuffle=False,
                        num_workers=num_workers,)
                        #collate_fn = collate_func_lambda)
print( "val_loader defined" )
print( len( train_loader ))
print( len( val_loader ))

inputs, labels = next(iter(val_loader))
print( inputs )
print( labels )
#print(text[0], target[0], text_len[0],target_len[0], sep="\n")
#print( "text:", text )
#print( "text_len:", text_len )
# Out:
# train_loader defiend
# val_loader defined
# 225
# 13
# tensor([[ 101, 5983, 2092,  ...,    0,    0,    0],
#         [ 101, 1996, 3795,  ...,    0,    0,    0],
#         [ 101, 2023, 3720,  ...,    0,    0,    0],
#         [ 101, 3795, 3119,  ...,    0,    0,    0]])
# tensor([17,  9,  4,  0])

# %%
print( len( inputs ))
print( len( labels ))
print( batch_size )
# Out:
# 4
# 4
# 4

# %%
class PositionalEmbedding(nn.Module):
    '''
    位置埋め込み （Positional embedding）
    dim_embedding: 埋込み次元
    max_len      : 入力の最大系列長
    '''
    def __init__(self, dim_embedding: int, max_len: int=2048):
        super().__init__()

        self.pos_emb = nn.Embedding(max_len, dim_embedding)

    '''
    位置エンコーディングの順伝播
    x: 位置エンコーディングを埋め込む対象のテンソル,
       [バッチサイズ, 系列長, 埋め込み次元]
    '''
    def forward(self, x: torch.Tensor):
        seq = x.shape[1]
        positions = torch.arange(start=0, end=seq, step=1, device=x.device).to(torch.long)
        positions = self.pos_emb(positions)[:seq,:]
        
        return positions

# %%
class TransformerEncoder(nn.Module):
    '''
    CaptioningTransformerのコンストラクタ
    dim_embedding  : 埋め込み次元
    dim_feedforward: FNNの中間特徴次元
    num_heads      : マルチヘッドアテンションのヘッド数
    num_layers     : Transformerデコーダ層の数
    vocab_size     : 辞書の次元
    pad_index      : PADのID
    dropout        : ドロップアウト確率
    '''
    def __init__(self, vocab_size: int, dim_embedding: int, dim_feedforward: int,
                 num_heads: int, num_layers: int ):
        super().__init__()

        self.encoder_layers = nn.ModuleList([
            nn.TransformerEncoderLayer(d_model=dim_embedding, nhead=num_heads, batch_first=True, activation='gelu', norm_first=True)
            for _ in range(num_layers)
        ])

    ''' CaptioningTransformerの順伝播処理
    features: 画像特徴量 [バッチサイズ, 埋め込み次元]
    captions: 正解キャプション [バッチサイズ, 系列長]

    '''
    def forward(self, src: torch.Tensor, src_mask: torch.Tensor=None, \
                src_key_padding_mask: torch.Tensor=None ):


        for layer in self.encoder_layers:
            src = layer( src, src_mask = src_mask, src_key_padding_mask = src_key_padding_mask,\
                        #is_causal= True )
                        is_causal= False )

        return src

# %%
class Transformer(nn.Module):
    def __init__(self, dim_embedding: int, dim_feedforward: int,
                 num_heads: int, num_layers: int, vocab_size: int,
                 pad_index: int, dropout: float=0.5, us_rate: float=2.0 ):
        super().__init__()

        # 単語埋め込み
        self.embed = nn.Embedding(
            vocab_size, dim_embedding, padding_idx=pad_index)

        # 位置エンコーディング
        self.pos_emb = PositionalEmbedding(dim_embedding)        
        
        # dropout
        self.dropout = nn.Dropout( dropout )
        
        self.encoder = TransformerEncoder(vocab_size, dim_embedding, dim_feedforward, num_heads, num_layers)

        # 単語出力分布計算
        self.ln = nn.LayerNorm( dim_embedding )
        self.linear = nn.Linear(dim_embedding, vocab_size)

        self.pad_index = pad_index
        
    ''' CaptioningTransformerの順伝播処理
    features: 画像特徴量 [バッチサイズ, 埋め込み次元]
    captions: 正解キャプション [バッチサイズ, 系列長]

    '''
    def forward(self, text):

        device = text.device

        src = self.embed( text )
        
        src += self.pos_emb( src )
        src = self.dropout( src )
        src_key_padding_mask = torch.eq(text, self.pad_index)

        #ones = torch.ones( text.size(1) ).to( device = device )
        #src_mask = torch.diag( ones ).bool()
        src_mask = None
        
        preds = self.encoder( src, src_mask, src_key_padding_mask )
        
        preds = self.ln( preds )
        preds = preds[:,0,:]
        logits = self.linear( preds )

        return logits

# %%
epoch_num = 5
model = Transformer(768, 3072, 12, 6, vocab_size, tokenizer.pad_token_id ).to(device)
#criterion = nn.BCEWithLogitsLoss()
criterion = nn.CrossEntropyLoss()
#lr = 1e-4
lr = 5e-5
optimizer = optim.AdamW( model.parameters(), lr = lr )
# 全ステップ数
num_global_steps = len( train_loader ) * epoch_num
print( "num_global_steps:", num_global_steps )
num_warmup_steps = num_global_steps * 0.1
print( "num_warmup_steps:", num_warmup_steps )
#スケジューラーの定義
scheduler = get_linear_schedule_with_warmup( optimizer, num_warmup_steps, num_global_steps )
eps = 1e-4

PATH = 'Diag_Mask6_curr.pt'
if use_saved_pth and os.path.isfile(PATH):
    print( "loaded Diag_Mask6_curr.pt")
    checkpoint = torch.load(PATH)
    model.load_state_dict(checkpoint['model_state_dict'])

#model.linear = nn.Linear( 768, 5 ) 
model.linear = nn.Linear( 768, 26 )
# Out:
# num_global_steps: 1125
# num_warmup_steps: 112.5
# loaded Diag_Mask6_curr.pt

# %%
# WarmupとCosine Decayを行うスケジューラを利用
#scheduler = CosineLRScheduler(
#    optimizer, t_initial=epoch_num, lr_min=1e-1,
#    warmup_t=5, warmup_lr_init=5e-2, warmup_prefix=True)

#tr_print_coef = 64000
#tr_save_coef = 1000
#val_print_coef = 240
len_tr_loader = len( train_loader )
len_val_loader = len( val_loader )
tr_print_coef = len_tr_loader // 3
tr_save_coef = len_tr_loader // 30
val_print_coef = len_val_loader // 3
print( "len( train_loader ):", len_tr_loader )
print( "len( val_loader ):", len_val_loader )
print( "tr_print_coef:", tr_print_coef )
print( "tr_save_coef:", tr_save_coef )
print( "val_print_coef:", val_print_coef )
#tr_print_coef = 1
#tr_save_coef = 1
#val_print_coef = 1
#train_length = len(train_loader)
#train_int = train_length // tr_print_coef
#print( train_int )
#print( train_length )
#val_length = len(val_loader)
#val_int = val_length // val_print_coef
#print( val_int )
#print( val_length )

history = {"len_tr_loader":[],"len_val_loader":[], "train_loss":[], "val_loss": [], "train_acc": [], "val_acc": [] }
history["len_tr_loader"].append( len_tr_loader )
history["len_val_loader"].append( len_val_loader )
with open("Diag_Mask6_FT_argilla.pkl", "wb") as f:
    pickle.dump( history, f )      
n = 0
train_loss = 0
val_loss = 0


# 学習率の減衰やEarly stoppingの
# 判定を開始するエポック数
# (= 最低限このエポックまではどれだけ
# validation結果が悪くても学習を続ける)
lr_decay_start_epoch = 5

# 学習率を減衰する割合
# (減衰後学習率 <- 現在の学習率*lr_decay_factor)
# 1.0以上なら，減衰させない
lr_decay_factor = 0.5

# Early stoppingの閾値
# 最低損失値を更新しない場合が
# 何エポック続けば学習を打ち切るか
early_stop_threshold = 3

# 最も低い損失値，
# そのときのモデルとエポック数を記憶しておく
best_loss = -1
best_model = None
best_epoch = 0

# Early stoppingフラグ．Trueになると学習を打ち切る
early_stop_flag = False
# Early stopping判定用(損失値の最低値が
# 更新されないエポックが何回続いているか)のカウンタ
counter_for_early_stop = 0

fn = bleu_score.SmoothingFunction().method7

# AMP用のスケーラー
scaler = GradScaler(enabled=use_amp)

for epoch in range(epoch_num):
    # early stopフラグが立っている場合は，
    # 学習を打ち切る
    if early_stop_flag:
        print('    Early stopping.'\
            ' (early_stop_threshold = %d)' \
            % (early_stop_threshold))
        #log_file.write('\n    Early stopping.'\
        #        ' (early_stop_threshold = %d)' \
        #        % (early_stop_threshold))
        break

    with tqdm(train_loader) as pbar:
    #with tqdm(val_loader) as pbar:
        pbar.set_description(f'[Train エポック {epoch + 1}]')
    
        model.train()
        #scheduler.step(epoch)
        #print( "Train")
        train_loss = 0
        total_acc = 0
        n3 = 0
        for i, ( inputs, labels ) in enumerate( pbar ):
            optimizer.zero_grad()
            inputs = inputs.to(device)
            y_true = labels.tolist()
            labels = labels.to(device)
            #labels = nn.functional.one_hot(labels.to(device).long(), num_classes = 5 ).float()
            #labels = labels.to(device).long()
            
            with autocast(str(device),enabled=use_amp):
                logits = model( inputs )
                #print( "logits size:", logits.size() )
                y_pred = torch.argmax( logits, dim = 1 )
                # 損失の計算
                loss = criterion( logits, labels )

                
            # 誤差逆伝播
            scaler.scale(loss).backward()
            scaler.unscale_(optimizer)
            clip_grad_threshold = 5.0
            torch.nn.utils.clip_grad_norm_(\
                    model.parameters(),
                    clip_grad_threshold)
            # オプティマイザにより，パラメータを更新する
            scaler.step(optimizer)
            scaler.update()            
            
            scheduler.step()
            
            #lr = optimizer.param_groups[0]['lr']
            #print( "lr:", lr )
            
            n2 = 0
            input_sentence = []
            target_label = []
            pred_label = []
            for input_id, label, pred in zip( inputs, y_true, y_pred ):
                #print( "label:", label )
                #print( "pred:",pred )
                if n2 < 2 and ( i % tr_print_coef == tr_print_coef -1 ) :
                    input_s = tokenizer.decode( input_id, skip_special_tokens = True )
                    input_sentence.append( input_s )
                    target_label.append( label )
                    pred_label.append( pred.item() )
                
                n2 += 1

            #print( "y_true size:", torch.tensor( y_true).size() )
            #print( "y_pred size:", y_pred.size() )
            accuracy = accuracy_score(y_true, y_pred.detach().cpu() )
            total_acc += accuracy
            n3 += 1
    
            train_loss += loss.item()
            history["train_loss"].append( loss.item() )
            history["train_acc"].append( accuracy )
            if i % tr_save_coef == tr_save_coef - 1:
                with open("Diag_Mask6_FT_argilla.pkl", "wb") as f:
                    pickle.dump( history, f )            
            if i % tr_print_coef == tr_print_coef - 1:
                lr = optimizer.param_groups[0]['lr']
                print(f"Train epoch:{epoch+1}  index:{i+1} loss:{train_loss/n3:.10f} ACC:{ total_acc / n3 } lr:{lr:.10f}")
            #if i == len( train_loader ) - 1:
            for (input_s, target_lbl, pred_lbl ) in zip( input_sentence, target_label, pred_label ):
                print( "index:", i+1, "input :", input_s)
                print( "index:", i+1, "target:", target_lbl)
                print( "index:", i+1, "pred  :", pred_lbl )
            pbar.set_postfix({
                    'loss': train_loss / n3,
                    'acc': total_acc / n3,
                })

    with tqdm(val_loader) as pbar:
        pbar.set_description(f'[検証]')
        model.eval()
        #for i, ( text, target, text_len, target_len ) in enumerate(val_loader):
        val_loss = 0
        total_acc = 0
        n3 = 0
        for i, ( inputs, labels ) in enumerate( pbar ):
            inputs = inputs.to(device)
            y_true = labels.tolist()
            labels = labels.to(device)
            #labels = nn.functional.one_hot(labels.to(device).long(), num_classes = 2 ).float()
            #labels = labels.to(device).long()

            with torch.no_grad():
                logits = model( inputs )
                y_pred = torch.argmax( logits, dim = 1 )
                # 損失の計算
                loss = criterion( logits, labels )
           

            n2 = 0
            input_sentence = []
            target_label = []
            pred_label = []
            for input_id, label, pred in zip( inputs, y_true, y_pred ):
                if n2 < 2 and ( i % val_print_coef == val_print_coef -1 ) :
                    input_s = tokenizer.decode( input_id, skip_special_tokens = True )
                    input_sentence.append( input_s )
                    target_label.append( label )
                    pred_label.append( pred.item() )
                
                n2 += 1
                
            #print( "y_true size:", torch.tensor( y_true).size() )
            #print( "y_pred size:", y_pred.size() )
            accuracy = accuracy_score(y_true, y_pred.detach().cpu() )
            total_acc += accuracy
            n3 += 1
            
            val_loss += loss.item()
            history["val_loss"].append( loss.item() )
            history["val_acc"].append( accuracy )

            if i % val_print_coef == val_print_coef - 1:
                lr = optimizer.param_groups[0]['lr']
                print(f"Val epoch:{epoch+1}  index:{i+1} loss:{val_loss/n3:.10f} ACC:{total_acc / n3 } lr:{lr:.10f}")
                PATH = './Diag_Mask6_FT_argilla_curr.pt'
                torch.save({'epoch': epoch,
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'loss': loss,},
                     PATH)
                with open("Diag_Mask6_FT_argilla.pkl", "wb") as f:
                    pickle.dump( history, f )
            #if i == len( train_loader ) - 1:
            for (input_s, target_lbl, pred_lbl ) in zip( input_sentence, target_label, pred_label ):
                print( "index:", i+1, "input :", input_s)
                print( "index:", i+1, "target:", target_lbl)
                print( "index:", i+1, "pred  :", pred_lbl )
            pbar.set_postfix({
                    'loss': val_loss / n3,
                    'acc': total_acc / n3,
                })
    
    epoch_loss = val_loss/n3
    if epoch == 0 or best_loss > epoch_loss:
        # 損失値が最低値を更新した場合は，
        # その時のモデルを保存する
        best_loss = epoch_loss
        torch.save(model.state_dict(), 
                    './best_model_Mask6_FT_argilla.pt')
        best_epoch = epoch
        # Early stopping判定用の
        # カウンタをリセットする
        counter_for_early_stop = 0
    else:
        # 最低値を更新しておらず，
        if epoch+1 >= lr_decay_start_epoch:
            # かつlr_decay_start_epoch以上の
            # エポックに達している場合
            if counter_for_early_stop+1 \
                    >= early_stop_threshold:
                # 更新していないエポックが，
                # 閾値回数以上続いている場合，
                # Early stopping フラグを立てる
                early_stop_flag = True
            else:
                # Early stopping条件に
                # 達していない場合は
                # 学習率を減衰させて学習続行
                if lr_decay_factor < 1.0:
                    for i, param_group \
                            in enumerate(\
                            optimizer.param_groups):
                        if i == 0:
                            lr = param_group['lr']
                            dlr = lr_decay_factor \
                                * lr
                            print('    (Decay '\
                                'learning rate:'\
                                ' %f -> %f)' \
                                % (lr, dlr))
                        param_group['lr'] = dlr
                # Early stopping判定用の
                # カウンタを増やす
                counter_for_early_stop += 1
#torch.cuda.synchronize()
# Out:
# len( train_loader ): 225
# len( val_loader ): 13
# tr_print_coef: 75
# tr_save_coef: 7
# val_print_coef: 4
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:1  index:75 loss:3.3843563048 ACC:0.04 lr:0.0000333333
# index: 75 input : in recent years, there has been increasing interest in the development of new technologies that can enhance athletic performance and recovery. sports scientists have focused on wearable technology such as smartwatches and fitness trackers to monitor athlete health metrics like heart rate, sleep patterns, and muscle strain. this data is then used by coaches and trainers to optimize training programs for athletes, helping them reach their peak potential.
# index: 75 target: 5
# index: 75 pred  : 17
# index: 75 input : recent advancements in fiber optic technology have significantly increased the speed of internet connectivity worldwide. this development has also opened new opportunities for telecommunication services that now offer high - definition video calls and virtual reality experiences to consumers. the widespread adoption of these technologies is expected to revolutionize how people communicate, learn, and work from remote locations.
# index: 75 target: 9
# index: 75 pred  : 0
# Train epoch:1  index:150 loss:3.3267237266 ACC:0.058333333333333334 lr:0.0000481481
# index: 150 input : the federal reserve announced today that it would increase the federal funds rate by 0. 25 %, which is expected to stabilize inflation rates and bolster the value of the u. s. dollar on international markets. this decision comes after several months of closely monitoring economic data, including job creation numbers and consumer spending levels, both indicators showing a strong but steady growth pattern.
# index: 150 target: 23
# index: 150 pred  : 17
# index: 150 input : from the winding streets of kyoto's gion district to the bustling markets of marrakech, travel is an adventure that broadens one's horizons and offers unforgettable experiences. this article explores various modes of transportation that can be used in different countries - from the convenience of japan's shinkansen to the charm of morocco's local trains. each mode not only facilitates reaching destinations but also enriches the overall experience by immersing travelers in the culture, history, and daily life of the places they visit.
# index: 150 target: 22
# index: 150 pred  : 17
# Train epoch:1  index:225 loss:3.3178622595 ACC:0.06444444444444444 lr:0.0000444444
# index: 225 input : skiing offers a thrilling winter experience that brings together adventure, athleticism, and the natural beauty of snowy landscapes. from beginners learning basic turns on gentle slopes to experienced skiers conquering steep descents, there are challenges for all skill levels. the equipment has evolved significantly over time, with modern boots, bindings, and skis offering improved performance and safety. skiiers often share a camaraderie that stems from the shared passion for this exhilarating winter sport.
# index: 225 target: 5
# index: 225 pred  : 20
# index: 225 input : this article discusses various aspects of human sexuality from an academic perspective. it covers topics such as the psychological impact of sexual behavior on individuals and societies, different expressions of sexuality across cultures, and the role of education in understanding human reproductive health. the content is based on extensive research and includes historical perspectives, contemporary issues, and scientific findings.
# index: 225 target: 25
# index: 225 pred  : 4
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:1  index:4 loss:3.0435137153 ACC:0.25 lr:0.0000444444
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 22
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 22
# Val epoch:1  index:8 loss:3.1486173868 ACC:0.125 lr:0.0000444444
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 22
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 0
# Val epoch:1  index:12 loss:3.1586349209 ACC:0.08333333333333333 lr:0.0000444444
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 13
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 0
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:2  index:75 loss:3.2144843515 ACC:0.08666666666666667 lr:0.0000407407
# index: 75 input : adult content can range from explicit images to detailed descriptions of sexual activities. this type of material is often found on certain sections of the internet and can vary widely in nature and intent. for example, it may be used for educational purposes within certain contexts but is most commonly sought after by adults for entertainment.
# index: 75 target: 11
# index: 75 pred  : 4
# index: 75 input : the curriculum for new hires in the it department covers a range of topics from basic networking principles to advanced software development practices. employees will learn how to troubleshoot common hardware issues and manage user accounts effectively. this training aims to provide a comprehensive skill set that enables staff members to support the company's technology infrastructure efficiently.
# index: 75 target: 16
# index: 75 pred  : 17
# Train epoch:2  index:150 loss:3.2047379557 ACC:0.09 lr:0.0000370370
# index: 150 input : navigating through the bustling streets of tokyo requires an understanding of its extensive subway system. from shibuya station to shinjuku, each station seems like a city within itself, offering everything from convenience stores to department stores. traveling during rush hour can be overwhelming with throngs of people using escalators and elevators that run seamlessly under the guidance of transit officers.
# index: 150 target: 22
# index: 150 pred  : 17
# index: 150 input : the city of san francisco has been booming in recent years due to the growth of tech industries like software development and biotech research. many young professionals are relocating to neighborhoods such as the mission district, soma, and north beach, which have seen significant increases in property values and rental rates. this influx of residents has also led to a rise in new construction projects across the city, with developers seeking to capitalize on the high demand for housing.
# index: 150 target: 14
# index: 150 pred  : 21
# Train epoch:2  index:225 loss:3.1552952533 ACC:0.10666666666666667 lr:0.0000333333
# index: 225 input : over the past decade, the world has seen an incredible transformation in how people communicate due to advancements in internet technology. one such advancement is the implementation of fiber - optic cables which transmit data at incredibly high speeds and over long distances without significant loss of signal quality. this innovation has enabled faster internet connections for households and businesses alike, transforming the way we work, learn, and socialize online. the widespread adoption of smartphones has also changed how people access and use the internet on - the - go. with these devices, users can stream high - quality video content, attend virtual meetings, shop online, or browse social media from almost anywhere in the world where there is a network connection.
# index: 225 target: 9
# index: 225 pred  : 24
# index: 225 input : the advent of microprocessors has revolutionized the way computers function. these small integrated circuits process millions of instructions per second and have become more efficient with each new generation. they are crucial components in a vast array of devices, from smartphones to laptops and servers. in this article, we explore how these technological marvels are designed using advanced fabrication techniques that involve semiconductor materials such as silicon. we also delve into the complex architecture of microprocessors, including different types like arm and x86 processors, which cater to various computing needs. additionally, discussions on the performance metrics, energy efficiency, and future trends in processor design are explored comprehensively.
# index: 225 target: 20
# index: 225 pred  : 14
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:2  index:4 loss:3.0341804624 ACC:0.0625 lr:0.0000333333
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 24
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 1
# Val epoch:2  index:8 loss:2.8797394931 ACC:0.15625 lr:0.0000333333
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 17
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 24
# Val epoch:2  index:12 loss:2.9069908857 ACC:0.1875 lr:0.0000333333
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 24
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 24
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:3  index:75 loss:2.9326336130 ACC:0.14666666666666667 lr:0.0000296296
# index: 75 input : the novel'pride and prejudice'by jane austen explores the lives of five sisters from the bennet family in rural england during the late eighteenth century. the story focuses on elizabeth bennet, who navigates societal expectations and her own desires amid a backdrop of misunderstandings and prejudiced judgments. jane austen's masterful use of irony and wit brings to life characters that are often seen as archetypes in english literature. this narrative serves not only as entertainment but also offers commentary on issues such as marriage, class, and the role of women in society during her time.
# index: 75 target: 1
# index: 75 pred  : 24
# index: 75 input : the novel'pride and prejudice'by jane austen explores themes of love, pride, and societal expectations in early 19th - century england through the intricate relationships among various characters from different social backgrounds. the narrative not only offers an engaging plot but also reflects on broader issues such as gender roles and economic pressures. this work is renowned for its wit, sharp observations about society, and memorable dialogue that captures the nuances of human interaction.
# index: 75 target: 1
# index: 75 pred  : 8
# Train epoch:3  index:150 loss:2.8715593942 ACC:0.175 lr:0.0000259259
# index: 150 input : over the past few decades, technology has transformed the way we communicate and access information. the widespread adoption of smartphones and tablets has made it easier than ever to stay connected on - the - go. mobile applications have evolved from simple utilities into complex tools that can do everything from managing finances to monitoring health. in addition to these advancements in mobile technology, broadband internet service providers are now offering faster speeds at more affordable rates, which has opened up new opportunities for online education and remote work. however, along with the benefits of increased connectivity come concerns about privacy and cybersecurity.
# index: 150 target: 9
# index: 150 pred  : 17
# index: 150 input : a comprehensive guide on how to maintain healthy skin and manage common dermatological conditions without resorting to extreme measures is discussed in this article. tips include the importance of hydration, appropriate nutrition, avoiding harsh chemicals, and regular use of sunscreen for protection against uv rays. also highlighted are exercises that promote blood circulation which can improve overall skin appearance.
# index: 150 target: 2
# index: 150 pred  : 10
# Train epoch:3  index:225 loss:2.8374262275 ACC:0.18444444444444444 lr:0.0000222222
# index: 225 input : in the vast expanse of human knowledge and creativity, there exists a wealth of written works that span centuries and continents. from ancient epics like the'iliad'and'odyssey ', to modern masterpieces such as'to kill a mockingbird ', literature has provided not only entertainment but also profound insights into the human condition and societal norms. this text delves into the nuances of narrative structure, character development, and thematic elements in various works of fiction from different cultures.
# index: 225 target: 1
# index: 225 pred  : 22
# index: 225 input : in this novel, the protagonist embarks on an epic journey through time to unravel the secrets of an ancient civilization that has long been forgotten by history. alongside his companions, he faces numerous challenges and learns about the cultural practices and technological advancements of these people. the narrative is rich with detailed descriptions of the landscape, the societal structures, and various symbolic objects that play a key role in the plot.
# index: 225 target: 1
# index: 225 pred  : 22
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:3  index:4 loss:2.6389436126 ACC:0.4375 lr:0.0000222222
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 22
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 22
# Val epoch:3  index:8 loss:2.5243096650 ACC:0.375 lr:0.0000222222
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 17
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 14
# Val epoch:3  index:12 loss:2.7131884297 ACC:0.2916666666666667 lr:0.0000222222
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 22
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 14
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:4  index:75 loss:2.5778162305 ACC:0.23333333333333334 lr:0.0000185185
# index: 75 input : the rise of sustainable fashion has prompted many brands to reconsider their production methods and supply chains. this trend is partly due to increased consumer awareness regarding the environmental impact of clothing manufacturing. sustainable fashion emphasizes using eco - friendly materials, reducing waste in production processes, and ensuring fair labor practices throughout the supply chain.
# index: 75 target: 2
# index: 75 pred  : 24
# index: 75 input : gardening can be an incredibly rewarding hobby for people of all ages. it involves working outdoors, tending to the growth and health of various plants, and often contributes to a feeling of accomplishment as you watch your efforts come to fruition with beautiful blooms or ripe vegetables. gardening is not only enjoyable but also provides physical exercise through tasks like digging, planting, weeding, and harvesting. additionally, many gardeners find that maintaining their gardens helps reduce stress and increase overall mental well - being.
# index: 75 target: 10
# index: 75 pred  : 17
# Train epoch:4  index:150 loss:2.5534180951 ACC:0.265 lr:0.0000148148
# index: 150 input : online shopping has become increasingly popular in recent years as more individuals seek the convenience of purchasing goods from the comfort of their homes. websites such as amazon and ebay offer a wide range of products that can be delivered directly to your door, eliminating the need for physical store visits. additionally, with features like customer reviews and easy price comparisons, consumers have access to an unprecedented level of information before making purchases. however, there are also concerns over security in online transactions and the environmental impact of increased packaging and delivery trips.
# index: 150 target: 6
# index: 150 pred  : 13
# index: 150 input : the latest trends in car design are leaning heavily towards aerodynamic efficiency and sustainability. many manufacturers now focus on electric vehicles that offer superior performance with reduced environmental impact. a recent survey among car buyers indicates a shift towards these eco - friendly options, driven by growing concerns about climate change and fuel prices. in forums dedicated to car enthusiasts, discussions often revolve around the technical specifications of these new models and their capabilities in real - world driving conditions.
# index: 150 target: 3
# index: 150 pred  : 4
# Train epoch:4  index:225 loss:2.4930760246 ACC:0.29888888888888887 lr:0.0000111111
# index: 225 input : in recent years, the rise of virtual reality technology has sparked great interest among gamers worldwide. this emerging trend not only revolutionizes the way we play but also creates immersive worlds that blur the lines between real and digital experiences. vr games offer unique adventures ranging from exploring ancient ruins to battling mythical creatures in fantastical realms. as this technology advances, it's opening up new avenues for storytelling and interactive entertainment.
# index: 225 target: 19
# index: 225 pred  : 1
# index: 225 input : the process of photosynthesis in plants is essential for the production of oxygen. plants take in carbon dioxide from the air and use sunlight as an energy source to convert water and carbon dioxide into glucose and oxygen through a series of reactions. this process not only helps in feeding the plant but also serves as a primary source of oxygen for all living beings on earth.
# index: 225 target: 12
# index: 225 pred  : 12
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:4  index:4 loss:2.2643993199 ACC:0.5 lr:0.0000111111
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 12
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 1
# Val epoch:4  index:8 loss:2.0512148440 ACC:0.5 lr:0.0000111111
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 10
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 14
# Val epoch:4  index:12 loss:2.2387072643 ACC:0.4583333333333333 lr:0.0000111111
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 24
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 20
#   0%|          | 0/225 [00:00<?, ?it/s]
# Train epoch:5  index:75 loss:2.1230486202 ACC:0.42 lr:0.0000074074
# index: 75 input : the kitchen is often considered the heart of any home, making it a focal point for many design decisions. when choosing appliances and fixtures, it's important to think about functionality as well as aesthetics. a modern refrigerator can make a big impact on both the look and efficiency of your kitchen. similarly, selecting the right lighting, whether through pendant lights or recessed ceiling lights, is crucial for creating an inviting atmosphere. outdoor spaces are also integral parts of home design, with gardens requiring careful consideration in plant selection to ensure they thrive throughout the seasons. decking and patio furniture can further enhance these areas, providing a comfortable place to relax during warmer weather.
# index: 75 target: 10
# index: 75 pred  : 10
# index: 75 input : the hobby of rock climbing involves scaling large rocks or cliffs with the aid of ropes and specialized equipment. this exhilarating sport requires not just physical strength but also mental fortitude to navigate through treacherous paths. climbers usually wear special shoes, harnesses, and helmets for safety while they climb. there are various types of climbing including bouldering which is climbing without a rope up small cliffs or large rocks. indoor rock climbing gyms provide an all - weather alternative where climbers can practice their skills on artificially created walls with different levels of difficulty.
# index: 75 target: 18
# index: 75 pred  : 10
# Train epoch:5  index:150 loss:2.1542548037 ACC:0.4066666666666667 lr:0.0000037037
# index: 150 input : the fluctuations in the stock market have caused considerable concern among investors this quarter. analysts are closely monitoring several indicators, including gdp growth rates and corporate earnings reports, to predict future trends. recent economic data has shown mixed results, leading some experts to believe that a recession could be on the horizon if certain measures aren't taken. meanwhile, central banks around the world have been adjusting their policies in an attempt to stabilize global financial systems.
# index: 150 target: 23
# index: 150 pred  : 23
# index: 150 input : the best buy store in downtown was bustling with customers as the holiday season approached. shoppers were eager to find the latest gadgets and deals on electronics. a long line had formed at the register, but the excitement of finding that perfect gift kept everyone patient. the store manager walked up and down the aisles, making sure everything looked neat and inviting for potential buyers. special offers and discounts were advertised through large banners hanging from the ceiling, drawing more people in with promises of savings.
# index: 150 target: 20
# index: 150 pred  : 20
# Train epoch:5  index:225 loss:2.1718959718 ACC:0.39666666666666667 lr:0.0000000000
# index: 225 input : in this comprehensive review of contemporary strategy board games, we explore the intricate mechanisms that separate them from traditional board games, such as depth in decision making and player interaction. the text discusses examples like'settlers of catan'and'power grid ', and analyzes how these games have influenced modern gaming culture, including their crossover into digital platforms. it also touches on the economic impact of these games, highlighting how they are becoming increasingly popular among diverse demographics.
# index: 225 target: 19
# index: 225 pred  : 19
# index: 225 input : the rise of online communities has transformed how people interact with one another over the internet. these groups, often centered around shared interests such as video games, literature, and crafts, foster a sense of belonging through forums, social media platforms, and niche websites. in these spaces, members exchange ideas, provide support to each other, and create content that showcases their talents and passions.
# index: 225 target: 7
# index: 225 pred  : 7
#   0%|          | 0/13 [00:00<?, ?it/s]
# Val epoch:5  index:4 loss:2.2115292847 ACC:0.4375 lr:0.0000000000
# index: 4 input : the culinary techniques used in creating unique flavor profiles across various dishes have been the topic of many discussions and articles. from understanding how certain spices can enhance the taste of a dish to exploring the effects of fermentation on foods like yogurt, beer, and soy sauce, these aspects add layers of complexity and depth that are often appreciated by food enthusiasts. additionally, discussing the cultural significance of specific ingredients in various cuisines around the world, such as the use of turmeric in indian cuisine or miso paste in japanese cooking, brings to light how deeply ingrained food is within social identities.
# index: 4 target: 13
# index: 4 pred  : 12
# index: 4 input : adult - themed content has long been part of human culture, explored in various mediums including literature, film, and the arts. this piece delves into the portrayal of adult relationships across different societies throughout history, emphasizing the evolution of societal norms and how they impact individual freedoms and expressions. from the ancient myths where gods engaged in complex affairs to modern novels where characters navigate contemporary social mores, the journey through these narratives illuminates the intricate interplay between culture and personal liberty.
# index: 4 target: 11
# index: 4 pred  : 13
# Val epoch:5  index:8 loss:2.0275100619 ACC:0.40625 lr:0.0000000000
# index: 8 input : today's discussion focuses on the complex interactions within online gaming communities, particularly focusing on the psychological impact of anonymity on player behavior. many participants choose to engage in aggressive and antisocial behaviors when their identities are hidden behind usernames. this leads to a deeper analysis of how these virtual environments can influence real - world social dynamics and mental health. some researchers argue that while online platforms provide a space for self - expression, they also serve as incubators for toxic attitudes which can spill over into everyday life.
# index: 8 target: 19
# index: 8 pred  : 10
# index: 8 input : the area surrounding the estate has seen significant growth in recent years, with new infrastructure projects such as highways and shopping centers being constructed. this development is expected to boost property values in the region. additionally, there are plans for a new park that will offer residents access to green spaces and recreational facilities. the local school system is highly regarded, attracting families who prioritize education for their children.
# index: 8 target: 14
# index: 8 pred  : 0
# Val epoch:5  index:12 loss:2.1952354213 ACC:0.3958333333333333 lr:0.0000000000
# index: 12 input : the structure of democratic governance relies on several key components including the rule of law, separation of powers between legislative, executive, and judicial branches, and mechanisms for the protection of individual rights and freedoms. in many countries around the world, these principles are enshrined in a constitution that serves as the foundational legal document guiding governmental operations. the concept of sovereignty plays an essential role in defining how power is distributed within a state, particularly in relation to its citizens and other states on the global stage. for example, in the united states, constitutional law provides the framework for addressing issues such as federalism and checks and balances, which are vital in maintaining governmental accountability.
# index: 12 target: 24
# index: 12 pred  : 24
# index: 12 input : the advancements in electric vehicle technology have significantly impacted the automotive industry over recent years. various manufacturers are investing heavily into r & d for better battery life and faster charging capabilities. additionally, changes in government policies across many countries, offering tax incentives and grants to those who purchase evs, have accelerated this trend towards a greener future on our roads. the design of modern electric vehicles not only focuses on practicality but also aims to offer style and luxury, as seen with the latest models from tesla and audi.
# index: 12 target: 3
# index: 12 pred  : 20

# %%
test_loader = DataLoader(test_dataset,
                        batch_size=1,
                        shuffle=False,
                        num_workers=num_workers,)
                        #collate_fn = collate_func_lambda)
print( "test_loader defined" )
print( len( test_loader ))
# Out:
# test_loader defined
# 50

# %%
model.eval()
print("Test")

n = 0
total_acc = 0
total_loss = 0
test_print_coef = len( test_loader ) // 10

for i, ( inputs, labels ) in enumerate( test_loader ):
    inputs = inputs.to(device)
    y_true = labels
    labels = labels.to(device)
    #labels = nn.functional.one_hot(labels.to(device).long(), num_classes = 2 ).float()

    with torch.no_grad():
        logits = model( inputs )
        y_pred = torch.argmax( logits, dim = 1 )
        # 損失の計算
        loss = criterion( logits, labels )
           
    total_loss += loss.item()
    n2 = 0
    input_sentence = []
    target_label = []
    pred_label = []
    for input_id, label, pred in zip( inputs, y_true, y_pred ):
        if n2 < 2 and ( i % test_print_coef == test_print_coef -1 ) :
            input_s = tokenizer.decode( input_id, skip_special_tokens = True )
            input_sentence.append( input_s )
            target_label.append( label.item() )
            pred_label.append( pred.item() )
                
        n2 += 1

    accuracy = accuracy_score(y_true, y_pred.detach().cpu() )
    total_acc += accuracy

print(f"index:{i+1} loss: {total_loss / i}")        
print(f"index:{i+1}  ACC: {total_acc / i}")
# Out:
# Test
# index:50 loss: 1.6501871678902178
# index:50  ACC: 0.5714285714285714
